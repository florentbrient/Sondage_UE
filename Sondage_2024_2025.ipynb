# %%
import matplotlib as mpl
from matplotlib import cm
import matplotlib.pyplot as plt
import pylab as plt
import pandas as pd
import numpy as np
import os


def colorFader(c1,c2,mix=0): #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1=np.array(mpl.colors.to_rgb(c1))
    c2=np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)

def _savefig(fig,ax,name='',title='',fts=10,xsize=(10,10),zmax=None):
    plt.xticks(size=fts)
    plt.yticks(size=fts)
    plt.title(title)
    fig.set_size_inches(xsize)
    fig.savefig(name + '.png')#,dpi='figure')
    fig.savefig(name + '.pdf', dpi=1000)
    plt.close()
    
def func(pct, allvals):
    absolute = int(round(pct/100.*np.sum(allvals)))
    return "{:.1f}%\n({:d} r)".format(pct, absolute)

def _mkdir(path):
    print('path : ',path)
    print(os.path.exists(path))
    if not(os.path.exists(path)):
      os.mkdir(path)

Semestre = 5 #4 #5 #1
Sem_ch   = str(Semestre)

#For S6 only
complementaire = True

pathini = '/Users/fbrient/'
#pathini = '/home/fbrient/'
path    = pathini+'Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S'+Sem_ch+'/'

fileadd = []
file    = 'Responses_S'+Sem_ch+'_2024_2025.xlsx' #'Sondage UE Sciences de la Terre - Semestre '+str(Semestre)+'.csv'


#if Semestre == 4:
#  file  = 'Sondage UE Sciences de la Terre - Semestre '+str(Semestre)+' - v2.csv'
#elif Semestre == 5: 
#  fileadd   = []
  #fileadd   = 'Sondage UE Sciences de la Terre - Ressources.csv'
  #fileadd   = 'Sondage UE Sciences de la Terre - Océanographie.csv'
#  fileadd   = 'Sondage UE Sciences de la Terre - Biodiversité et Paléobiodiversité.csv'
   #[ 'Sondage UE Sciences de la Terre - Ressources.csv'
             #,'Sondage UE Sciences de la Terre - Océanographie.csv'
             #,'Sondage UE Sciences de la Terre - Biodiversité et Paléobiodiversité.csv']
#if Semestre == 6 and complementaire: 
#    file   = 'Responses_S'+Sem_ch+'_2021_2022_complementaires.xlsx'

suffix = ''
#if len(fileadd)>0:
#    suffix = '_'+fileadd.split(' ')[-1].split('.')[0] 
#    file   = fileadd
#print(file,fileadd,suffix)

file   = path+file
print('file : ',file)

pathfig0 = path #'/Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/'
pathfig  = pathfig0+'d_figures/'
_mkdir(pathfig)

#df1    = pd.read_csv(file)
df1    = pd.read_excel(file)
#print(type(df1))
if len(fileadd)>0:
    for tmp in fileadd:
        print(tmp)
        df_tmp = pd.read_excel(path+tmp)
        #print(df_tmp)
        df1 = pd.concat([df1,df_tmp], axis=1) #, sort=False )#ignore_index=True) #, sort=False)
#df_eng = pd.read_excel('translate_FR.xlsx', header=1,encoding='latin1')
#df_eng = df_eng.set_axis(df_fr.columns.values.tolist(),axis='columns')
#df     = df_fr.append(df_eng, ignore_index=True, sort=False)

df     = df1
#print(df)

questions=df.columns.values
print(questions)
# Out:
# file :  /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/Responses_S5_2024_2025.xlsx
# path :  /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/
# True
# ['Submission Date' 'Quelle formation suivez-vous ?'
#  'Quel UE avez-vous suivi ?'
#  'Quel est votre ressenti général de ce semestre ?'
#  "Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés"
#  "Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  'Les enseignements de cette UE vous ont intéressé ?'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE ?'
#  "Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.1"
#  "Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.1"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.1"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.1"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.1"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.1"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.1"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.1"
#  'Les enseignements de cette UE vous ont intéressé'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE ?.1'
#  "Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.2"
#  "Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.2"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.2"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.2"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.2"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.2"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.2"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.2"
#  'Les enseignements de cette UE vous ont intéressé.1'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE ?.2'
#  "Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.3"
#  "Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.3"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.3"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.3"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.3"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.3"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.3"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.3"
#  'Les enseignements de cette UE vous ont intéressé.2'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?'
#  "Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés"
#  "Que diriez-vous des objectifs de l'UE? >> Vous les avez compris"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.4"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.4"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.4"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.4"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.4"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.4"
#  "Contenu de l'UE >> Les méthodes pédagogiques (alternance cours, activités,questionnements, TD, TP, devoirs...) favorisent mon apprentissage"
#  'Les enseignements de cette UE vous ont intéressé.3'
#  "Combien d'heures par semaine ai-je consacré à cet enseignement ?"
#  'Quels sont, selon vous, les points forts du cours ?'
#  'Quels sont, selon vous, les points du cours à améliorer ?'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.1'
#  "Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés.1"
#  "Que diriez-vous des objectifs de l'UE? >> Vous les avez compris.1"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.5"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.5"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.5"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.5"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.5"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.5"
#  'Les enseignements de cette UE vous ont intéressé.4'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.2'
#  "Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés.2"
#  "Que diriez-vous des objectifs de l'UE? >> Vous les avez compris.2"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.6"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.6"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.6"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.6"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.6"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.6"
#  'Les enseignements de cette UE vous ont intéressé.5'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.3'
#  "Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés.3"
#  "Que diriez-vous des objectifs de l'UE? >> Vous les avez compris.3"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.7"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.7"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.7"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.7"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.7"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.7"
#  'Les enseignements de cette UE vous ont intéressé.6'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.4'
#  "Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés.4"
#  "Que diriez-vous des objectifs de l'UE? >> Vous les avez compris.4"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.8"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.8"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.8"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.8"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.8"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.8"
#  'Les enseignements de cette UE vous ont intéressé.7'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.5'
#  "Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés.5"
#  "Que diriez-vous des objectifs de l'UE? >> Vous les avez compris.5"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.9"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.9"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.9"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.9"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.9"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.9"
#  'Les enseignements de cette UE vous ont intéressé.8'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.6'
#  "Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés.6"
#  "Que diriez-vous des objectifs de l'UE? >> Vous les avez compris.6"
#  "Contenu de l'UE (commune aux autres UE) >> Le cours est adapté à vos connaissances et compétences préalables"
#  "Contenu de l'UE (commune aux autres UE) >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "Contenu de l'UE (commune aux autres UE) >> Il y a une bonne cohérence entre les différentes parties de cette UE"
#  "Contenu de l'UE (commune aux autres UE) >> Les documents de l'UE sont utiles"
#  "Contenu de l'UE (commune aux autres UE) >> Les documents de l'UE sont en quantité suffisante"
#  "Contenu de l'UE (spécial OIP) >> La forme des évaluations a permis une appréciation correcte de mes connaissances et compétences"
#  "Contenu de l'UE (spécial OIP) >> Le barème de l'évaluation globale et de chaque partie de l'évaluation est clair et adapté"
#  'Contenu de l\'UE (spécial OIP) >> Les séances "recherche documentaire / identité numérique" organisées par les bibliothèques sont utiles'
#  "Contenu de l'UE (spécial OIP) >> L'encadrement et la gestion de mon groupe par l'enseignant référent est efficace"
#  'Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> CV'
#  'Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> Dossier métier'
#  'Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> Sensibilisation à l’identité numérique'
#  'Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> Projet professionnel'
#  'Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> Bibliographie'
#  "Les enseignements de l'UE OIP vous ont intéressé"
#  'Quel est le point de satisfaction majeure et le point faible à améliorer en priorité ? (optionnel)'
#  "Avez-vous des commentaires à rajouter l'UE OIP ?"
#  'Avez-vous des commentaires à rajouter sur le semestre 5 de votre licence Sciences de la Terre ?']

# %%
# Formation

pies     = [1]
New_name = ['Formation?']

c1='#1f77b4' #blue
c2='red' #green
n=4
colors2 = [colorFader(c1,c2,x/2)for x in range(2)]
colors4 = [colorFader(c1,c2,x/4)for x in range(4)]

#print(df[questions[pies[0]]])
formation = df[questions[pies[0]]]#.squeeze(axis=1)
if len(formation.shape)>1:
    print(formation.shape)
    print(formation.iloc[:,[0]])
    formation=formation.iloc[:,[0]].squeeze()
print(formation.shape)

print(type(formation))
labels0 = formation.unique()
print(labels0)
#['Majeure' 'Mineure Geosciences' 'Monodisciplinaire Sciences de la Terre'
# 'Bi-disciplinaire : Biologie - Mineure Sciences de la Terre (MEEF)']
    

colors  = ['royalblue','red','gold','green','purple','cyan']
colors_save = colors

figsize = (8, 5)

for ij,nbpie in enumerate(pies): 
    fig, ax = plt.subplots(1,figsize=figsize)

    #data = df[questions[nbpie]].value_counts()#normalize=True)
    data = formation.value_counts()#normalize=True)
    print(data)
    for ik in data.index:
       data = data.rename(index={ik:ik.split(' ')[0]})
    print(data)
    
    labels  = data.index #[ij.split(' ')[0] for ij in labels0 if ij in data.index]  
    print(labels,data.index)#,dcolors)
    
        
    gcolors = dict()
    keys    = labels
    for ik,key in enumerate(keys):
        print(ik, key)
        gcolors[key]=colors[ik]
    print(gcolors)
    labels = [ik for ik in gcolors if ik in data.index]
    data   = data.reindex(labels)
    print(labels)
    
    wedges, texts, autotexts = ax.pie(data,labels=labels
                                  ,autopct=lambda pct: func(pct, data)
                                  ,colors=[gcolors[i] for i in data.index]
                                  ,textprops=dict(color="k"),startangle=90
                                  ,pctdistance=0.7, labeldistance=1.2
                                 )
    print(ax.xaxis.get_label())
    ax.legend(wedges, labels,
          loc="upper right",
          bbox_to_anchor=(1, 1, 0.5, -0.5))
          #title=questions[1],
    plt.setp(autotexts, size=10, weight="bold")

    title = New_name[ij]
    ax.set_title(title)
    
    name_file = pathfig+title.split('?')[0]+'_Semestre'+Sem_ch+suffix
    print(title,name_file)
#plt.show()
    _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# (39,)
# <class 'pandas.core.series.Series'>
# ['Mono' 'L4' 'Majeure' 'Mineure' 'Double Majeure']
# Quelle formation suivez-vous ?
# Mono              12
# Majeure           11
# Mineure           11
# Double Majeure     4
# L4                 1
# Name: count, dtype: int64
# Quelle formation suivez-vous ?
# Mono       12
# Majeure    11
# Mineure    11
# Double      4
# L4          1
# Name: count, dtype: int64
# Index(['Mono', 'Majeure', 'Mineure', 'Double', 'L4'], dtype='object', name='Quelle formation suivez-vous ?') Index(['Mono', 'Majeure', 'Mineure', 'Double', 'L4'], dtype='object', name='Quelle formation suivez-vous ?')
# 0 Mono
# 1 Majeure
# 2 Mineure
# 3 Double
# 4 L4
# {'Mono': 'royalblue', 'Majeure': 'red', 'Mineure': 'gold', 'Double': 'green', 'L4': 'purple'}
# ['Mono', 'Majeure', 'Mineure', 'Double', 'L4']
# Text(0.5, 0, '')
# Formation? /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/Formation_Semestre5

# %%
# Ressenti

pies     = [3]
New_name = ['Ressenti?']
colors5 = [colorFader(c1,c2,x/4)for x in range(5)]
colors  =  colors5 #['royalblue','red','gold','green','purple','cyan']


#print(df[questions[pies[0]]])
formation = df[questions[pies[0]]]#.squeeze(axis=1)
if len(formation.shape)>1:
    print(formation.shape)
    print(formation.iloc[:,[0]])
    formation=formation.iloc[:,[0]].squeeze()
print(formation.shape)

print(type(formation))
labels0 = formation.unique()
print(labels0)
    

#colors_save = colors
#ci1=c2
#ci2='green'
#colors_save = [colorFader(ci1,ci2,x/4)for x in range(5)]
#colors = colors_save

cmap = plt.cm.coolwarm_r
NL   = 5 
colors = cmap(np.linspace(0., 0.95, NL))
colors_save = colors

figsize = (8, 5)

for ij,nbpie in enumerate(pies): 
    fig, ax = plt.subplots(1,figsize=figsize)

    #data = df[questions[nbpie]].value_counts()#normalize=True)
    data = formation.value_counts()#normalize=True)
    print(data)
    #for ik in data.index:
    #   data = data.rename(index={ik:ik.split(' ')[0]})
    mean = formation.mean()
    
    labels  = data.index #[ij.split(' ')[0] for ij in labels0 if ij in data.index]  
    print(labels,data.index)#,dcolors)
    
        
    gcolors = dict()
    keys_ressenti = [1,2,3,4,5]
    keys    = keys_ressenti #labels
    for ik,key in enumerate(keys):
        print(ik, key)
        gcolors[key]=colors[ik]
    print(gcolors)
    labels = [ik for ik in gcolors if ik in data.index]
    data   = data.reindex(labels)
    print(labels)
    
    wedges, texts, autotexts = ax.pie(data,labels=labels
                                  ,autopct=lambda pct: func(pct, data)
                                  ,colors=[gcolors[i] for i in data.index]
                                  ,textprops=dict(color="k"),startangle=90
                                  ,pctdistance=0.7, labeldistance=1.2
                                 )
    print(ax.xaxis.get_label())
    ax.legend(wedges, labels,
          loc="upper right",
          bbox_to_anchor=(1, 1, 0.5, -0.5))
          #title=questions[1],
    plt.setp(autotexts, size=10, weight="bold")

    title = New_name[ij]+' ('+"{:.2f}".format(mean)+'/5)'
    ax.set_title(title)
    
    name_file = pathfig+title.split('?')[0]+'_Semestre'+Sem_ch+suffix
    print(title,name_file)
#plt.show()
    _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# (39,)
# <class 'pandas.core.series.Series'>
# [4 3 5 2]
# Quel est votre ressenti général de ce semestre ?
# 4    21
# 5    10
# 3     6
# 2     2
# Name: count, dtype: int64
# Index([4, 5, 3, 2], dtype='int64', name='Quel est votre ressenti général de ce semestre ?') Index([4, 5, 3, 2], dtype='int64', name='Quel est votre ressenti général de ce semestre ?')
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5
# {1: array([0.70567316, 0.01555616, 0.15023281, 1.        ]), 2: array([0.95125379, 0.57879939, 0.45940781, 1.        ]), 3: array([0.89181689, 0.85197328, 0.82908527, 1.        ]), 4: array([0.60316207, 0.73152748, 0.99956528, 1.        ]), 5: array([0.28527278, 0.38012942, 0.82346855, 1.        ])}
# [2, 3, 4, 5]
# Text(0.5, 0, '')
# Ressenti? (4.00/5) /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/Ressenti_Semestre5

# %%
#Find UEs
import itertools

if Semestre == 3:
    UEs = ['LU2ST031','LU2ST032','LU2ST033','LU2ST034',\
           'LU2ST035','LU2ST301','LU2ST302','LU2ST303',\
           'LU2ST304','RQEE']
if Semestre == 4:
    UEs = ['LU2ST041','LU2ST042','LU2ST043','LU2ST044',\
           'LU2ST045','LU2ST421','LU2ST401','LU2ST402',\
           'LU2ST403S','LU2ST403T','LU2ST404']
if Semestre == 5:
    UEs = ['LU3ST053','LU3ST055','LU3ST056','LU3ST057',\
           'LU3ST058','LU3ST059','LU3ST501','LU3ST502',\
           'LU3ST507G','LU3ST507S','LU3STOIP']
if Semestre == 6:
    UEs = ['LU3ST060','LU3ST061','LU3ST062','LU3ST063',\
           'LU3ST066','LU3ST068','LU3ST069','LU3ST603',\
           'LU3ST605','LU3ST606','LU3ST607','LU3ST608',\
           'LU3ST609','LU3ST613','LU3ST614','LU3ST615',\
           'LU3ST621']
print(UEs)

# Find start of each UE
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présenté
sentence = "Que diriez-vous des objectifs de l'UE"
word     = "résenté" # Présenté ou présenté
UEs0 = [(ij,question.replace(' ?','').split(' ')[-1]) for ij,question in enumerate(questions) if ((sentence in question) and (word in question))]
print(UEs0)
# Out:
# ['LU3ST053', 'LU3ST055', 'LU3ST056', 'LU3ST057', 'LU3ST058', 'LU3ST059', 'LU3ST501', 'LU3ST502', 'LU3ST507G', 'LU3ST507S', 'LU3STOIP']
# [(4, 'présentés'), (14, 'présentés.1'), (24, 'présentés.2'), (34, 'présentés.3'), (44, 'présentés'), (58, 'présentés.1'), (68, 'présentés.2'), (78, 'présentés.3'), (88, 'présentés.4'), (98, 'présentés.5'), (108, 'présentés.6')]

# %%
#UE_idx   = [ij[0] for ij in UEs] #[1,2,3,4,5,6,8,17,18]
#UE_names = [ij[1].strip("()?") for ij in UEs] #['Profession?', 'Permanent?', 'Site?', 'Climaction?','Stratégie?','Quel objectif?',
#            #'Individuel ou collectif?','Calculateur?','Influence recherche?'].replace('(','').replace(')','')

#UE_idx   = range(len(UEs))
UE_idx   = [ij[0] for ij in UEs0] 
UE_names = UEs

print(UE_idx,UE_names)
#colors2 = ['red', 'blue']
#a       = np.random.random(4)
#cs      = cm.Set1(np.arange(4)/4.)

keys1 = ['OUI','NON']
#keys2 = ['Tout à fait d\'accord','Plutôt d\'accord','Plutôt pas d\'accord','Pas du tout d\'accord']
keys2 = ['Tout à fait d\'accord','Plutôt d\'accord','Plutôt pas d\'accord','Pas du tout d\'accord']

# Changing key for specific question
tabword = ['intéressé']
keys3   = keys_ressenti

# Changing for Mineralogie
tabword2 = ['heures']
keys5    = ['< 1','De 1h à 2h', 'De 2h à 3h','> 3h']

#Idx_change = [9]
#tabword = ['cohérence','lien entre']
#keys3 = ['Bonne','Plutôt bonne','Plutôt mauvaise','Mauvaise']

# Changing answers for specific question
#UE_change  = ['LU2ST034','LU2ST303','LU2ST352','LU2ST044','LU2ST402','LU3ST603','LU3ST602']
#keys4 = ['Très clair','Assez clair','Assez flou','Très flou']

# Changing answers for S1
#tabword2 = ['capsules']
#keys5 = ['Oui, beaucoup (> 10 vidéos)','Oui, certaines (5-10 vidéos)',\
#'Quelques unes (1-4 vidéos)','Non, mais je sais qu\'elles existaient',\
#'Non, car je ne savais pas qu\'il y avait des capsules vidéos de soutien']
#tabword3 = ['Ces vidéos']
#keys6 = ['Oui, le plus souvent','Oui, certaines',\
#         'Non, même si je les ai visionnées','Non, car pas visionnées']

# Changing answers for S6
#tabword4 = ['Vous sentez-vous','lien existant entre disciplines']
#keys7 = ['Oui','Pas d\'avis','Non']

#tabword5 = ['davantage de TP']
#keys8 = ['Davantage de TD et exercices “sur papier” encadrés',\
#         'Je ne changerais rien',\
#         'Davantage de TP en salle informatique',\
#        ]

# Changing answers for S5 (OIP)
tabword6 = ['avenir professionnel']
keys9 = ['Utile','Pas d\'avis particulier', 'Pas utile']

#keys6 = ['Oui, beaucoup (> 10 vidéos)','Oui, certaines (5-10 vidéos)',\
#'Quelques unes (1-4 vidéos)','Non, mais je sais qu\'elles existaient',\
#'Non, car je ne savais pas qu\'il y avait des capsules vidéos de soutien']

print(tabword)

# 9 questions !
Nb_questions = 15 #(UE_idx[1]-UE_idx[0])-1
ofs          = 4 # Nombre de questions non UE (avis general Licence, parcours, UE suivis)
if Semestre == 1:
    Nb_questions = 19
if Semestre == 5:
    Nb_questions = 17
if Semestre == 6:
    Nb_questions = 10
print(Nb_questions)

figsize = (8, 5)

for ij,idx in enumerate(UE_idx):
    UE = UE_names[ij]
    print('UE : ',UE)
    
    path_file = pathfig+UE+'/'
    print(path_file)
    _mkdir(path_file)
    
    for ik in range(Nb_questions):
      fig, ax = plt.subplots(1,figsize=figsize)

      # Offset + (NumUE*(NB questions+1)) +ik
      #idx1    = ofs+(idx*(Nb_questions+1))+ik
      idx1    = idx+ik
      data    = df[questions[idx1]]

      #data = data.replace('\\','')
      data = data.replace('Tout à fait d\\\'accord','Tout à fait d\'accord')
      data = data.replace('Plutôt d\\\'accord','Plutôt d\'accord')
      data = data.replace('Plutôt pas d\\\'accord','Plutôt pas d\'accord')
      data = data.replace('Pas du tout d\\\'accord','Pas du tout d\'accord')
      data = data.replace('Pas d\\\'avis particulier','Pas d\'avis particulier')

        
      #data = data.replace('d\\\'accord','d\\\'accord')
      #data = data.replace('è','\'e')
      #data = data.replace('Très','Tr\'es')
      data0 = data.value_counts() #normalize=True) 
                
      print('Data : ',data0)
      #colors = colors2 ; 
      changecolor = 0
      keys = keys1
      if ('OUI' in data0.keys()):
        keys = keys1
      else:
        keys = keys2
        #if ik in Idx_change:
        #print('tabword ',tabword,questions[idx1])
        print('tabword ',[ii in questions[idx1] for ii in tabword])
        if (any([ii in questions[idx1] for ii in tabword]) 
           and not(any([ii in questions[idx1] for ii in ['laboratoire'] ])) ):
        #if 'cohérence' in questions[idx+ik]:
            keys = keys3
            changecolor = 1 # cas intéressé
            #if UE in UE_change:
            #    keys = keys4
        elif any([ii in questions[idx1] for ii in tabword2]):
            keys = keys5
        #elif any([ii in questions[idx1] for ii in tabword3]):
        #    keys = keys6
      #if any([ii in questions[idx1] for ii in tabword4]):
      #      keys = keys7
      #if any([ii in questions[idx1] for ii in tabword5]):
      #      keys = keys8
      if any([ii in questions[idx1] for ii in tabword6]):
            keys = keys9
      print(UE,idx,keys,data0.index)

      #import difflib
      #output_list = [li for li in difflib.ndiff('c\'e','ce') if li[0] != ' ']
      #print(output_list)
        
      cmap = plt.cm.bwr
      colors = cmap(np.linspace(0., 0.95, len(keys)))
      if changecolor:
          colors = colors_save 
  
      gcolors=dict()
      for ij,key in enumerate(keys):
        gcolors[key]=colors[ij]
      labels = [ij for ij in gcolors if ij in data0.index]
      data0   = data0.reindex(labels)
      print(labels)
        
      wedges, texts, autotexts = ax.pie(data0,autopct=lambda pct: func(pct, data0)\
                                            ,colors=[gcolors[i] for i in data0.index]\
                                            ,textprops=dict(color="w") #, colors=color
                                            ,startangle=0)
    
      ax.legend(wedges, data0.index,loc="best",bbox_to_anchor=(1, 1, 0.5, -0.5))
      plt.setp(autotexts, size=10, weight="bold")
    
      title = questions[idx1].split('.')[0]
      if any([ii in questions[idx1] for ii in tabword]): # intéressé
          try:
            mean   = np.nanmean(data)
            title += ' ('+"{:.2f}".format(mean)+'/5)'
          except:
            pass

      ax.set_title(title)
      print(title)
    
      name_file = 'Question_'+str(ik)
      name_file = path_file + name_file
      print(name_file)
      _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# [4, 14, 24, 34, 44, 58, 68, 78, 88, 98, 108] ['LU3ST053', 'LU3ST055', 'LU3ST056', 'LU3ST057', 'LU3ST058', 'LU3ST059', 'LU3ST501', 'LU3ST502', 'LU3ST507G', 'LU3ST507S', 'LU3STOIP']
# ['intéressé']
# 17
# UE :  LU3ST053
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/
# path :  /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/
# True
# Data :  Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# OUI    9
# Name: count, dtype: int64
# LU3ST053 4 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés')
# ['OUI']
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_0
# Data :  Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# OUI    8
# NON    1
# Name: count, dtype: int64
# LU3ST053 4 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_1
# Data :  Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# Plutôt d'accord         7
# Tout à fait d'accord    2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST053 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord'], dtype='object', name='Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_2
# Data :  Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# Tout à fait d'accord    5
# Plutôt d'accord         4
# Name: count, dtype: int64
# tabword  [False]
# LU3ST053 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_3
# Data :  Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# Tout à fait d'accord    5
# Plutôt d'accord         3
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST053 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_4
# Data :  Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# Plutôt d'accord         4
# Tout à fait d'accord    3
# Pas du tout d'accord    1
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST053 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord', 'Pas du tout d'accord',
#        'Plutôt pas d'accord'],
#       dtype='object', name='Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_5
# Data :  Contenu de l'UE >> Les documents de l'UE sont utiles
# Tout à fait d'accord    6
# Plutôt d'accord         2
# Pas du tout d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST053 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Pas du tout d'accord'], dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont utiles')
# ["Tout à fait d'accord", "Plutôt d'accord", "Pas du tout d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont utiles
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_6
# Data :  Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# Plutôt d'accord         4
# Tout à fait d'accord    4
# Pas du tout d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST053 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord', 'Pas du tout d'accord'], dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante')
# ["Tout à fait d'accord", "Plutôt d'accord", "Pas du tout d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_7
# Data :  Les enseignements de cette UE vous ont intéressé ?
# 4.0    6
# 5.0    2
# 3.0    1
# Name: count, dtype: int64
# tabword  [True]
# LU3ST053 4 [1, 2, 3, 4, 5] Index([4.0, 5.0, 3.0], dtype='float64', name='Les enseignements de cette UE vous ont intéressé ?')
# [3, 4, 5]
# Les enseignements de cette UE vous ont intéressé ? (4.11/5)
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_8
# Data :  Avez-vous des commentaires à rajouter au sujet de cette UE ?
# l'UE était très intéressante mais il y a eu de gros problèmes d'organisation et peu de communication                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# L'UE était très intéressante et m'a apprise beaucoup de chose cependant l'organisation général de l'UE et la communication entre les professeur et les élèves doit être revu.                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# Gros manque de coordination et de communication des informations. Le CC2 n'a pas eu lieu car communication pas clair. En général les communications sont données tardivement (emploi du temps, sujets d'oraux)\n\nLe moodle pourrait être plus clair en séparant bien les cours de chaque prof : je pense surtout aux fichiers TD qui s'appellent tous différemment mais sans forcément d'infos sur le nom des profs ou le cours associé. Certaines corrections de TD était mal lisible. \n\nDeux petites évaluations dans le semestre + un oral + un gros contrôle c'est assez bien comme mode d'évaluation    1
# Comme d'autres étudiants, je suis globalement très satisfaite de l'enseignement reçu en sols et geomicrobiologie. Seul petit bémol serait le cours de chimie des solutions, mais je tiens a préciser que ce n'est pas contre l'enseignant mais plutôt envers nos connai qui n'étaient au niveau, rendant le compréhension du cours compliquée. J'ai sinon passée de très bon moments en cours !                                                                                                                                                                                                                 1
# Cette UE est très intéressante mais les nouveaux cours de chimie des solutions sont d'un niveau trop élevé pour des personnes n'ayant pas fait de chimie des solutions depuis le lycée, je n'ai pas compris ce qui était important dans ces cours.\nMais tous les professeurs sont pédagogues et répondent aux questions, les responsables de l'UE sont très gentils et leurs cours sont très clairs.\nL'organisation n'est pas parfaite mais elle est bien quand même.                                                                                                                                         1
# L UE est trop désorganisée, manque de communication. Il y a trop de prof avec chacun sa partie. On a eu un cc annulé                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# Le tout forme quelque chose de cohérent, les enseignants sont presque tous très pédagogues, le seul petit point peut-être à revoir c'est la partie chimie du début de semestre : trop d'informations d'un seul coup sans application avec le reste... Sans bases de chimie des solutions de L1 (qui n'ont pas forcément été acquises car il n'y a que 2 choix de matière au S2 de L1), c'était mal amené.                                                                                                                                                                                                       1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST053 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['l'UE était très intéressante mais il y a eu de gros problèmes d'organisation et peu de communication',
#        'L'UE était très intéressante et m'a apprise beaucoup de chose cependant l'organisation général de l'UE et la communication entre les professeur et les élèves doit être revu.',
#        'Gros manque de coordination et de communication des informations. Le CC2 n'a pas eu lieu car communication pas clair. En général les communications sont données tardivement (emploi du temps, sujets d'oraux)\n\nLe moodle pourrait être plus clair en séparant bien les cours de chaque prof : je pense surtout aux fichiers TD qui s'appellent tous différemment mais sans forcément d'infos sur le nom des profs ou le cours associé. Certaines corrections de TD était mal lisible. \n\nDeux petites évaluations dans le semestre + un oral + un gros contrôle c'est assez bien comme mode d'évaluation',
#        'Comme d'autres étudiants, je suis globalement très satisfaite de l'enseignement reçu en sols et geomicrobiologie. Seul petit bémol serait le cours de chimie des solutions, mais je tiens a préciser que ce n'est pas contre l'enseignant mais plutôt envers nos connai qui n'étaient au niveau, rendant le compréhension du cours compliquée. J'ai sinon passée de très bon moments en cours !',
#        'Cette UE est très intéressante mais les nouveaux cours de chimie des solutions sont d'un niveau trop élevé pour des personnes n'ayant pas fait de chimie des solutions depuis le lycée, je n'ai pas compris ce qui était important dans ces cours.\nMais tous les professeurs sont pédagogues et répondent aux questions, les responsables de l'UE sont très gentils et leurs cours sont très clairs.\nL'organisation n'est pas parfaite mais elle est bien quand même.',
#        'L UE est trop désorganisée, manque de communication. Il y a trop de prof avec chacun sa partie. On a eu un cc annulé',
#        'Le tout forme quelque chose de cohérent, les enseignants sont presque tous très pédagogues, le seul petit point peut-être à revoir c'est la partie chimie du début de semestre : trop d'informations d'un seul coup sans application avec le reste... Sans bases de chimie des solutions de L1 (qui n'ont pas forcément été acquises car il n'y a que 2 choix de matière au S2 de L1), c'était mal amené.'],
#       dtype='object', name='Avez-vous des commentaires à rajouter au sujet de cette UE ?')
# []
# Avez-vous des commentaires à rajouter au sujet de cette UE ?
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_9
# Data :  Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.1
# OUI    7
# Name: count, dtype: int64
# LU3ST053 4 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.1')
# ['OUI']
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_10
# Data :  Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.1
# OUI    7
# Name: count, dtype: int64
# LU3ST053 4 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.1')
# ['OUI']
# Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_11
# Data :  Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.1
# Tout à fait d'accord    6
# Plutôt d'accord         1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST053 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.1')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_12
# Data :  Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.1
# Tout à fait d'accord    6
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST053 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.1')
# ["Tout à fait d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_13
# Data :  Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.1
# Tout à fait d'accord    6
# Plutôt d'accord         1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST053 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.1')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_14
# Data :  Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.1
# Tout à fait d'accord    5
# Plutôt d'accord         2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST053 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.1')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_15
# Data :  Contenu de l'UE >> Les documents de l'UE sont utiles.1
# Tout à fait d'accord    5
# Plutôt d'accord         2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST053 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont utiles.1')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont utiles
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST053/Question_16
# UE :  LU3ST055
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/
# path :  /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/
# True
# Data :  Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.1
# OUI    7
# Name: count, dtype: int64
# LU3ST055 14 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.1')
# ['OUI']
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_0
# Data :  Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.1
# OUI    7
# Name: count, dtype: int64
# LU3ST055 14 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.1')
# ['OUI']
# Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_1
# Data :  Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.1
# Tout à fait d'accord    6
# Plutôt d'accord         1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST055 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.1')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_2
# Data :  Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.1
# Tout à fait d'accord    6
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST055 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.1')
# ["Tout à fait d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_3
# Data :  Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.1
# Tout à fait d'accord    6
# Plutôt d'accord         1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST055 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.1')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_4
# Data :  Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.1
# Tout à fait d'accord    5
# Plutôt d'accord         2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST055 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.1')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_5
# Data :  Contenu de l'UE >> Les documents de l'UE sont utiles.1
# Tout à fait d'accord    5
# Plutôt d'accord         2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST055 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont utiles.1')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont utiles
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_6
# Data :  Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.1
# Tout à fait d'accord    6
# Plutôt d'accord         1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST055 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.1')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_7
# Data :  Les enseignements de cette UE vous ont intéressé
# 5.0    5
# 4.0    2
# Name: count, dtype: int64
# tabword  [True]
# LU3ST055 14 [1, 2, 3, 4, 5] Index([5.0, 4.0], dtype='float64', name='Les enseignements de cette UE vous ont intéressé')
# [4, 5]
# Les enseignements de cette UE vous ont intéressé (4.71/5)
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_8
# Data :  Avez-vous des commentaires à rajouter au sujet de cette UE ?.1
# Très bon professeurs, sujets très intéressants                                                        1
# Très bon cours, ce serai bien d'avoir une sortie pour visiter certains sites industriels ou autres    1
# une matière très interessante                                                                         1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST055 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Très bon professeurs, sujets très intéressants',
#        'Très bon cours, ce serai bien d'avoir une sortie pour visiter certains sites industriels ou autres',
#        'une matière très interessante'],
#       dtype='object', name='Avez-vous des commentaires à rajouter au sujet de cette UE ?.1')
# []
# Avez-vous des commentaires à rajouter au sujet de cette UE ?
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_9
# Data :  Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.2
# OUI    13
# Name: count, dtype: int64
# LU3ST055 14 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.2')
# ['OUI']
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_10
# Data :  Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.2
# OUI    13
# Name: count, dtype: int64
# LU3ST055 14 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.2')
# ['OUI']
# Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_11
# Data :  Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.2
# Tout à fait d'accord    12
# Plutôt pas d'accord      1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST055 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.2')
# ["Tout à fait d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_12
# Data :  Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.2
# Tout à fait d'accord    11
# Plutôt d'accord          2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST055 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.2')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_13
# Data :  Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.2
# Tout à fait d'accord    11
# Plutôt d'accord          1
# Plutôt pas d'accord      1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST055 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.2')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_14
# Data :  Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.2
# Tout à fait d'accord    8
# Plutôt d'accord         3
# Plutôt pas d'accord     2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST055 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.2')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_15
# Data :  Contenu de l'UE >> Les documents de l'UE sont utiles.2
# Tout à fait d'accord    10
# Plutôt d'accord          3
# Name: count, dtype: int64
# tabword  [False]
# LU3ST055 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont utiles.2')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont utiles
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST055/Question_16
# UE :  LU3ST056
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/
# path :  /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/
# True
# Data :  Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.2
# OUI    13
# Name: count, dtype: int64
# LU3ST056 24 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.2')
# ['OUI']
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_0
# Data :  Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.2
# OUI    13
# Name: count, dtype: int64
# LU3ST056 24 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.2')
# ['OUI']
# Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_1
# Data :  Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.2
# Tout à fait d'accord    12
# Plutôt pas d'accord      1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST056 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.2')
# ["Tout à fait d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_2
# Data :  Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.2
# Tout à fait d'accord    11
# Plutôt d'accord          2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST056 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.2')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_3
# Data :  Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.2
# Tout à fait d'accord    11
# Plutôt d'accord          1
# Plutôt pas d'accord      1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST056 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.2')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_4
# Data :  Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.2
# Tout à fait d'accord    8
# Plutôt d'accord         3
# Plutôt pas d'accord     2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST056 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.2')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_5
# Data :  Contenu de l'UE >> Les documents de l'UE sont utiles.2
# Tout à fait d'accord    10
# Plutôt d'accord          3
# Name: count, dtype: int64
# tabword  [False]
# LU3ST056 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont utiles.2')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont utiles
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_6
# Data :  Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.2
# Tout à fait d'accord    10
# Plutôt d'accord          2
# Plutôt pas d'accord      1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST056 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.2')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_7
# Data :  Les enseignements de cette UE vous ont intéressé.1
# 5.0    8
# 4.0    3
# 3.0    1
# 2.0    1
# Name: count, dtype: int64
# tabword  [True]
# LU3ST056 24 [1, 2, 3, 4, 5] Index([5.0, 4.0, 3.0, 2.0], dtype='float64', name='Les enseignements de cette UE vous ont intéressé.1')
# [2, 3, 4, 5]
# Les enseignements de cette UE vous ont intéressé (4.38/5)
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_8
# Data :  Avez-vous des commentaires à rajouter au sujet de cette UE ?.2
# On manque d'évaluations et les CC sont notés assez durement                                                                                                                                                                                                                       1
# Une UE incroyable et un plaisir à suivre!                                                                                                                                                                                                                                         1
# Toutes les notes sont au maximum, je rajouterai juste que ce semestre de paléontologie était beaucoup plus théorique que ceux de L2, même si c'est un passage obligatoire, cela rendait parfois certains cours/TP/TD un peu long. Mais globalement très satisfaite de cette UE    1
# J'ai adoré cette UE. J'aurais peut être aimé un peu plus d'explications sur l'utilisation de la PBDB. \nLes TP sont en lien direct avec le cours qui m'a permis de comprendre certaines notions statistiques vues en cours. \nLes professeurs sont vraiment bien.                 1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST056 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['On manque d'évaluations et les CC sont notés assez durement',
#        'Une UE incroyable et un plaisir à suivre!',
#        'Toutes les notes sont au maximum, je rajouterai juste que ce semestre de paléontologie était beaucoup plus théorique que ceux de L2, même si c'est un passage obligatoire, cela rendait parfois certains cours/TP/TD un peu long. Mais globalement très satisfaite de cette UE',
#        'J'ai adoré cette UE. J'aurais peut être aimé un peu plus d'explications sur l'utilisation de la PBDB. \nLes TP sont en lien direct avec le cours qui m'a permis de comprendre certaines notions statistiques vues en cours. \nLes professeurs sont vraiment bien.'],
#       dtype='object', name='Avez-vous des commentaires à rajouter au sujet de cette UE ?.2')
# []
# Avez-vous des commentaires à rajouter au sujet de cette UE ?
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_9
# Data :  Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.3
# OUI    11
# Name: count, dtype: int64
# LU3ST056 24 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.3')
# ['OUI']
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_10
# Data :  Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.3
# OUI    10
# NON     1
# Name: count, dtype: int64
# LU3ST056 24 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.3')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_11
# Data :  Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.3
# Plutôt d'accord         5
# Tout à fait d'accord    4
# Plutôt pas d'accord     2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST056 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.3')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_12
# Data :  Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.3
# Tout à fait d'accord    7
# Plutôt d'accord         3
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST056 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.3')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_13
# Data :  Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.3
# Tout à fait d'accord    7
# Plutôt d'accord         3
# Pas du tout d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST056 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Pas du tout d'accord'], dtype='object', name='Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.3')
# ["Tout à fait d'accord", "Plutôt d'accord", "Pas du tout d'accord"]
# Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_14
# Data :  Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.3
# Tout à fait d'accord    7
# Plutôt d'accord         4
# Name: count, dtype: int64
# tabword  [False]
# LU3ST056 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.3')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_15
# Data :  Contenu de l'UE >> Les documents de l'UE sont utiles.3
# Tout à fait d'accord    7
# Plutôt d'accord         4
# Name: count, dtype: int64
# tabword  [False]
# LU3ST056 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont utiles.3')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont utiles
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST056/Question_16
# UE :  LU3ST057
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST057/
# path :  /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST057/
# True
# Data :  Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.3
# OUI    11
# Name: count, dtype: int64
# LU3ST057 34 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.3')
# ['OUI']
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST057/Question_0
# Data :  Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.3
# OUI    10
# NON     1
# Name: count, dtype: int64
# LU3ST057 34 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.3')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST057/Question_1
# Data :  Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.3
# Plutôt d'accord         5
# Tout à fait d'accord    4
# Plutôt pas d'accord     2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST057 34 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.3')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST057/Question_2
# Data :  Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.3
# Tout à fait d'accord    7
# Plutôt d'accord         3
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST057 34 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.3')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST057/Question_3
# Data :  Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.3
# Tout à fait d'accord    7
# Plutôt d'accord         3
# Pas du tout d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST057 34 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Pas du tout d'accord'], dtype='object', name='Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.3')
# ["Tout à fait d'accord", "Plutôt d'accord", "Pas du tout d'accord"]
# Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST057/Question_4
# Data :  Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.3
# Tout à fait d'accord    7
# Plutôt d'accord         4
# Name: count, dtype: int64
# tabword  [False]
# LU3ST057 34 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.3')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST057/Question_5
# Data :  Contenu de l'UE >> Les documents de l'UE sont utiles.3
# Tout à fait d'accord    7
# Plutôt d'accord         4
# Name: count, dtype: int64
# tabword  [False]
# LU3ST057 34 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont utiles.3')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont utiles
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST057/Question_6
# Data :  Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.3
# Tout à fait d'accord    7
# Plutôt d'accord         4
# Name: count, dtype: int64
# tabword  [False]
# LU3ST057 34 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.3')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST057/Question_7
# Data :  Les enseignements de cette UE vous ont intéressé.2
# 5.0    5
# 4.0    4
# 3.0    2
# Name: count, dtype: int64
# tabword  [True]
# LU3ST057 34 [1, 2, 3, 4, 5] Index([5.0, 4.0, 3.0], dtype='float64', name='Les enseignements de cette UE vous ont intéressé.2')
# [3, 4, 5]
# Les enseignements de cette UE vous ont intéressé (4.27/5)
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST057/Question_8
# Data :  Avez-vous des commentaires à rajouter au sujet de cette UE?
# C'était très intéressant mais beaucoup trop de corrélation avec l'UE géodynamique, ce qui fait qu'au bout d'un moment on retrouve plus autant la motivation du départ car on apprend pas beaucoup de nouvelles notions.\nEt puis certains points, notamment mathématiques pour les équations d'ondes sont seulement moi important et il faut bien les aborder pour qu'on les comprenne.                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# parfois difficile d'appréhender le fil conducteur pendant les premiers cours mais plus clair vers la fin du semestre                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# Je pense que la répartition des pourcentages sur les notes de tp, exposé et évaluation finale n'avantage pas.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# ...
#        'Plutôt pas d'accord'],
#       dtype='object', name='Contenu de l'UE (commune aux autres UE) >> Le cours est adapté à vos connaissances et compétences préalables')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE (commune aux autres UE) >> Le cours est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST507S/Question_12
# Data :  Contenu de l'UE (commune aux autres UE) >> La charge de travail est adéquate pour le nombre d'ECTS
# Tout à fait d'accord    11
# Plutôt d'accord          6
# Plutôt pas d'accord      4
# Name: count, dtype: int64
# tabword  [False]
# LU3ST507S 98 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE (commune aux autres UE) >> La charge de travail est adéquate pour le nombre d'ECTS')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE (commune aux autres UE) >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST507S/Question_13
# Data :  Contenu de l'UE (commune aux autres UE) >> Il y a une bonne cohérence entre les différentes parties de cette UE
# Tout à fait d'accord    15
# Plutôt d'accord          5
# Plutôt pas d'accord      1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST507S 98 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE (commune aux autres UE) >> Il y a une bonne cohérence entre les différentes parties de cette UE')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE (commune aux autres UE) >> Il y a une bonne cohérence entre les différentes parties de cette UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST507S/Question_14
# Data :  Contenu de l'UE (commune aux autres UE) >> Les documents de l'UE sont utiles
# Tout à fait d'accord    17
# Plutôt d'accord          4
# Name: count, dtype: int64
# tabword  [False]
# LU3ST507S 98 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE (commune aux autres UE) >> Les documents de l'UE sont utiles')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE (commune aux autres UE) >> Les documents de l'UE sont utiles
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST507S/Question_15
# Data :  Contenu de l'UE (commune aux autres UE) >> Les documents de l'UE sont en quantité suffisante
# Tout à fait d'accord    18
# Plutôt d'accord          3
# Name: count, dtype: int64
# tabword  [False]
# LU3ST507S 98 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE (commune aux autres UE) >> Les documents de l'UE sont en quantité suffisante')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE (commune aux autres UE) >> Les documents de l'UE sont en quantité suffisante
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3ST507S/Question_16
# UE :  LU3STOIP
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/
# path :  /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/
# True
# Data :  Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés.6
# OUI    21
# Name: count, dtype: int64
# LU3STOIP 108 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés.6')
# ['OUI']
# Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_0
# Data :  Que diriez-vous des objectifs de l'UE? >> Vous les avez compris.6
# OUI    21
# Name: count, dtype: int64
# LU3STOIP 108 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE? >> Vous les avez compris.6')
# ['OUI']
# Que diriez-vous des objectifs de l'UE? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_1
# Data :  Contenu de l'UE (commune aux autres UE) >> Le cours est adapté à vos connaissances et compétences préalables
# Tout à fait d'accord    18
# Plutôt d'accord          1
# Pas du tout d'accord     1
# Plutôt pas d'accord      1
# Name: count, dtype: int64
# tabword  [False]
# LU3STOIP 108 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Pas du tout d'accord',
#        'Plutôt pas d'accord'],
#       dtype='object', name='Contenu de l'UE (commune aux autres UE) >> Le cours est adapté à vos connaissances et compétences préalables')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE (commune aux autres UE) >> Le cours est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_2
# Data :  Contenu de l'UE (commune aux autres UE) >> La charge de travail est adéquate pour le nombre d'ECTS
# Tout à fait d'accord    11
# Plutôt d'accord          6
# Plutôt pas d'accord      4
# Name: count, dtype: int64
# tabword  [False]
# LU3STOIP 108 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE (commune aux autres UE) >> La charge de travail est adéquate pour le nombre d'ECTS')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE (commune aux autres UE) >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_3
# Data :  Contenu de l'UE (commune aux autres UE) >> Il y a une bonne cohérence entre les différentes parties de cette UE
# Tout à fait d'accord    15
# Plutôt d'accord          5
# Plutôt pas d'accord      1
# Name: count, dtype: int64
# tabword  [False]
# LU3STOIP 108 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE (commune aux autres UE) >> Il y a une bonne cohérence entre les différentes parties de cette UE')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE (commune aux autres UE) >> Il y a une bonne cohérence entre les différentes parties de cette UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_4
# Data :  Contenu de l'UE (commune aux autres UE) >> Les documents de l'UE sont utiles
# Tout à fait d'accord    17
# Plutôt d'accord          4
# Name: count, dtype: int64
# tabword  [False]
# LU3STOIP 108 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE (commune aux autres UE) >> Les documents de l'UE sont utiles')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE (commune aux autres UE) >> Les documents de l'UE sont utiles
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_5
# Data :  Contenu de l'UE (commune aux autres UE) >> Les documents de l'UE sont en quantité suffisante
# Tout à fait d'accord    18
# Plutôt d'accord          3
# Name: count, dtype: int64
# tabword  [False]
# LU3STOIP 108 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE (commune aux autres UE) >> Les documents de l'UE sont en quantité suffisante')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE (commune aux autres UE) >> Les documents de l'UE sont en quantité suffisante
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_6
# Data :  Contenu de l'UE (spécial OIP) >> La forme des évaluations a permis une appréciation correcte de mes connaissances et compétences
# Tout à fait d'accord    15
# Plutôt d'accord          5
# Plutôt pas d'accord      1
# Name: count, dtype: int64
# tabword  [False]
# LU3STOIP 108 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE (spécial OIP) >> La forme des évaluations a permis une appréciation correcte de mes connaissances et compétences')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE (spécial OIP) >> La forme des évaluations a permis une appréciation correcte de mes connaissances et compétences
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_7
# Data :  Contenu de l'UE (spécial OIP) >> Le barème de l'évaluation globale et de chaque partie de l'évaluation est clair et adapté
# Tout à fait d'accord    15
# Plutôt d'accord          5
# Plutôt pas d'accord      1
# Name: count, dtype: int64
# tabword  [False]
# LU3STOIP 108 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE (spécial OIP) >> Le barème de l'évaluation globale et de chaque partie de l'évaluation est clair et adapté')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE (spécial OIP) >> Le barème de l'évaluation globale et de chaque partie de l'évaluation est clair et adapté
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_8
# Data :  Contenu de l'UE (spécial OIP) >> Les séances "recherche documentaire / identité numérique" organisées par les bibliothèques sont utiles
# Plutôt d'accord         16
# Plutôt pas d'accord      4
# Tout à fait d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU3STOIP 108 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Plutôt pas d'accord', 'Tout à fait d'accord'], dtype='object', name='Contenu de l'UE (spécial OIP) >> Les séances "recherche documentaire / identité numérique" organisées par les bibliothèques sont utiles')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE (spécial OIP) >> Les séances "recherche documentaire / identité numérique" organisées par les bibliothèques sont utiles
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_9
# Data :  Contenu de l'UE (spécial OIP) >> L'encadrement et la gestion de mon groupe par l'enseignant référent est efficace
# Tout à fait d'accord    15
# Plutôt d'accord          5
# Plutôt pas d'accord      1
# Name: count, dtype: int64
# tabword  [False]
# LU3STOIP 108 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE (spécial OIP) >> L'encadrement et la gestion de mon groupe par l'enseignant référent est efficace')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE (spécial OIP) >> L'encadrement et la gestion de mon groupe par l'enseignant référent est efficace
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_10
# Data :  Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> CV
# Utile    21
# Name: count, dtype: int64
# tabword  [False]
# LU3STOIP 108 ['Utile', "Pas d'avis particulier", 'Pas utile'] Index(['Utile'], dtype='object', name='Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> CV')
# ['Utile']
# Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> CV
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_11
# Data :  Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> Dossier métier
# Utile                     14
# Pas d'avis particulier     4
# Pas utile                  3
# Name: count, dtype: int64
# tabword  [False]
# LU3STOIP 108 ['Utile', "Pas d'avis particulier", 'Pas utile'] Index(['Utile', 'Pas d'avis particulier', 'Pas utile'], dtype='object', name='Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> Dossier métier')
# ['Utile', "Pas d'avis particulier", 'Pas utile']
# Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> Dossier métier
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_12
# Data :  Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> Sensibilisation à l’identité numérique
# Utile                     12
# Pas d'avis particulier     5
# Pas utile                  4
# Name: count, dtype: int64
# tabword  [False]
# LU3STOIP 108 ['Utile', "Pas d'avis particulier", 'Pas utile'] Index(['Utile', 'Pas d'avis particulier', 'Pas utile'], dtype='object', name='Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> Sensibilisation à l’identité numérique')
# ['Utile', "Pas d'avis particulier", 'Pas utile']
# Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> Sensibilisation à l’identité numérique
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_13
# Data :  Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> Projet professionnel
# Utile                     18
# Pas d'avis particulier     2
# Pas utile                  1
# Name: count, dtype: int64
# tabword  [False]
# LU3STOIP 108 ['Utile', "Pas d'avis particulier", 'Pas utile'] Index(['Utile', 'Pas d'avis particulier', 'Pas utile'], dtype='object', name='Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> Projet professionnel')
# ['Utile', "Pas d'avis particulier", 'Pas utile']
# Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> Projet professionnel
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_14
# Data :  Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> Bibliographie
# Utile                     10
# Pas utile                  7
# Pas d'avis particulier     4
# Name: count, dtype: int64
# tabword  [False]
# LU3STOIP 108 ['Utile', "Pas d'avis particulier", 'Pas utile'] Index(['Utile', 'Pas utile', 'Pas d'avis particulier'], dtype='object', name='Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> Bibliographie')
# ['Utile', "Pas d'avis particulier", 'Pas utile']
# Quels documents à préparer vous semblent utiles pour votre avenir professionnel? >> Bibliographie
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_15
# Data :  Les enseignements de l'UE OIP vous ont intéressé
# 4.0    8
# 3.0    7
# 5.0    6
# Name: count, dtype: int64
# tabword  [True]
# LU3STOIP 108 [1, 2, 3, 4, 5] Index([4.0, 3.0, 5.0], dtype='float64', name='Les enseignements de l'UE OIP vous ont intéressé')
# [3, 4, 5]
# Les enseignements de l'UE OIP vous ont intéressé (3.95/5)
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S5/d_figures/LU3STOIP/Question_16
