# %%
import matplotlib as mpl
from matplotlib import cm
import matplotlib.pyplot as plt
import pylab as plt
import pandas as pd
import numpy as np
import os


def colorFader(c1,c2,mix=0): #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1=np.array(mpl.colors.to_rgb(c1))
    c2=np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)

def _savefig(fig,ax,name='',title='',fts=10,xsize=(10,10),zmax=None):
    plt.xticks(size=fts)
    plt.yticks(size=fts)
    plt.title(title)
    fig.set_size_inches(xsize)
    fig.savefig(name + '.png')#,dpi='figure')
    fig.savefig(name + '.pdf', dpi=1000)
    plt.close()
    
def func(pct, allvals):
    absolute = int(round(pct/100.*np.sum(allvals)))
    return "{:.1f}%\n({:d} r)".format(pct, absolute)

def _mkdir(path):
    print('path : ',path)
    print(os.path.exists(path))
    if not(os.path.exists(path)):
      os.mkdir(path)

Semestre = 6 #4 #5 #1
Sem_ch   = str(Semestre)

#For S6 only
complementaire = True

pathini = '/Users/florentbrient/'
pathini = '/home/fbrient/'
path    = pathini+'Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S'+Sem_ch+'/'

fileadd = []
file    = 'Responses_S'+Sem_ch+'_2023_2024.xlsx' #'Sondage UE Sciences de la Terre - Semestre '+str(Semestre)+'.csv'


#if Semestre == 4:
#  file  = 'Sondage UE Sciences de la Terre - Semestre '+str(Semestre)+' - v2.csv'
#elif Semestre == 5: 
#  fileadd   = []
  #fileadd   = 'Sondage UE Sciences de la Terre - Ressources.csv'
  #fileadd   = 'Sondage UE Sciences de la Terre - Océanographie.csv'
#  fileadd   = 'Sondage UE Sciences de la Terre - Biodiversité et Paléobiodiversité.csv'
   #[ 'Sondage UE Sciences de la Terre - Ressources.csv'
             #,'Sondage UE Sciences de la Terre - Océanographie.csv'
             #,'Sondage UE Sciences de la Terre - Biodiversité et Paléobiodiversité.csv']
#if Semestre == 6 and complementaire: 
#    file   = 'Responses_S'+Sem_ch+'_2021_2022_complementaires.xlsx'

suffix = ''
#if len(fileadd)>0:
#    suffix = '_'+fileadd.split(' ')[-1].split('.')[0] 
#    file   = fileadd
#print(file,fileadd,suffix)

file   = path+file
print('file : ',file)

pathfig0 = path #'/Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/'
pathfig  = pathfig0+'d_figures/'
_mkdir(pathfig)

#df1    = pd.read_csv(file)
df1    = pd.read_excel(file)
#print(type(df1))
if len(fileadd)>0:
    for tmp in fileadd:
        print(tmp)
        df_tmp = pd.read_excel(path+tmp)
        #print(df_tmp)
        df1 = pd.concat([df1,df_tmp], axis=1) #, sort=False )#ignore_index=True) #, sort=False)
#df_eng = pd.read_excel('translate_FR.xlsx', header=1,encoding='latin1')
#df_eng = df_eng.set_axis(df_fr.columns.values.tolist(),axis='columns')
#df     = df_fr.append(df_eng, ignore_index=True, sort=False)

df     = df1
#print(df)

questions=df.columns.values
print(questions)
# Out:
# file :  /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/Responses_S6_2023_2024.xlsx
# path :  /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/
# True
# ['Submission Date'
#  '[Sondage UE L3 Sciences de la Terre - Semestre S6] Quelle formation suivez-vous ?'
#  'Quelles UEs avez-vous suivi ?'
#  'Quel est votre ressenti général de ce semestre ?'
#  "[Climats et paléoclimats] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés"
#  "[Climats et paléoclimats] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris"
#  '* Etes-vous satisfait de l’évaluation des connaissances sous forme de contrôle continu?'
#  "[Climats et paléoclimats] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Climats et paléoclimats] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Climats et paléoclimats] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Climats et paléoclimats] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "[Climats et paléoclimats] Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "[Climats et paléoclimats] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  '* Choisir 2 thématiques que vous voudriez voir davantage abordées dans cette UE :'
#  'Les enseignements de cette UE vous ont intéressé ?'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE ?'
#  "[Biogéochimie Océan-Atmosphère] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés"
#  "[Biogéochimie Océan-Atmosphère] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris"
#  "[Biogéochimie Océan-Atmosphère] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Biogéochimie Océan-Atmosphère] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Biogéochimie Océan-Atmosphère] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Biogéochimie Océan-Atmosphère] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "[Biogéochimie Océan-Atmosphère] Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "[Biogéochimie Océan-Atmosphère] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  'Les enseignements de cette UE vous ont intéressé'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE ?.1'
#  "[Atelier Fablab] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés"
#  "[Atelier Fablab] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris"
#  "[Atelier Fablab] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Atelier Fablab] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Atelier Fablab] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Atelier Fablab] Contenu de l'UE >> Le lien entre l'UE Stage Fablab et les autres enseignements est cohérent"
#  "[Atelier Fablab] Contenu de l'UE >> L'organisation de l'atelier s'est bien passé"
#  'Les enseignements de cette UE vous ont intéressé.1'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE ?.2'
#  "[Projet Informatique] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés"
#  "[Projet Informatique] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris"
#  "[Projet Informatique] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Projet Informatique] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Projet Informatique] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Projet Informatique] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "[Projet Informatique] Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "[Projet Informatique] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  'Les enseignements de cette UE vous ont intéressé.2'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?'
#  "[Paléontologie et évolution] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés"
#  "[Paléontologie et évolution] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris"
#  "[Paléontologie et évolution] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Paléontologie et évolution] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Paléontologie et évolution] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Paléontologie et évolution] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "[Paléontologie et évolution] Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "[Paléontologie et évolution] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  'Les enseignements de cette UE vous ont intéressé.3'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.1'
#  "[Développement idées géosciences] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés"
#  "[Développement idées géosciences] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris"
#  "[Développement idées géosciences] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Développement idées géosciences] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Développement idées géosciences] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Développement idées géosciences] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "[Développement idées géosciences] Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "[Développement idées géosciences] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  'Les enseignements de cette UE vous ont intéressé.4'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.2'
#  "[Géophysique: Outils & Applications] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés"
#  "[Géophysique: Outils & Applications] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris"
#  "[Géophysique: Outils & Applications] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Géophysique: Outils & Applications] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Géophysique: Outils & Applications] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Géophysique: Outils & Applications] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "[Géophysique: Outils & Applications] Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "[Géophysique: Outils & Applications] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  'Les enseignements de cette UE vous ont intéressé.5'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.3'
#  "[Terrain 3] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés"
#  "[Terrain 3] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris"
#  "[Terrain 3] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Terrain 3] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Terrain 3] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Terrain 3] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "[Terrain 3] Contenu de l'UE >> Le lien entre le stage et les autres enseignements est cohérent"
#  "[Terrain 3] Contenu de l'UE >> L'organisation du stage s'est bien passé"
#  'Les enseignements de cette UE vous ont intéressé.6'
#  '* Quel stage terrain avez-vous suivi ?'
#  '* Quelles UE(s) vous a paru idéal pour suivre et apprécier le stage terrain?\xa0'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.4'
#  "[Pétrologie métamorphique] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés"
#  "[Pétrologie métamorphique] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris"
#  "[Pétrologie métamorphique] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Pétrologie métamorphique] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Pétrologie métamorphique] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Pétrologie métamorphique] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "[Pétrologie métamorphique] Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "[Pétrologie métamorphique] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  'Les enseignements de cette UE vous ont intéressé.7'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.5'
#  "[Caractérisation des matériaux Géotechnique & Géophysique] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés"
#  "[Caractérisation des matériaux Géotechnique & Géophysique] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris"
#  "[Caractérisation des matériaux Géotechnique & Géophysique] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Caractérisation des matériaux Géotechnique & Géophysique] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Caractérisation des matériaux Géotechnique & Géophysique] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Caractérisation des matériaux Géotechnique & Géophysique] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "[Caractérisation des matériaux Géotechnique & Géophysique] Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "[Caractérisation des matériaux Géotechnique & Géophysique] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  'Les enseignements de cette UE vous ont intéressé.8'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.6'
#  "[Géochimie Appliquée] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés"
#  "[Géochimie Appliquée] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris"
#  "[Géochimie Appliquée] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Géochimie Appliquée] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Géochimie Appliquée] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Géochimie Appliquée] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "[Géochimie Appliquée] Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "[Géochimie Appliquée] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  'Les enseignements de cette UE vous ont intéressé.9'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.7'
#  "[Géodynamique des bassins sédimentaires] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés"
#  "[Géodynamique des bassins sédimentaires] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris"
#  "[Géodynamique des bassins sédimentaires] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Géodynamique des bassins sédimentaires] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Géodynamique des bassins sédimentaires] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Géodynamique des bassins sédimentaires] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "[Géodynamique des bassins sédimentaires] Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "[Géodynamique des bassins sédimentaires] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  'Les enseignements de cette UE vous ont intéressé.10'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.8'
#  "[Stratigraphie] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés"
#  "[Stratigraphie] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris"
#  "[Stratigraphie] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Stratigraphie] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Stratigraphie] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Stratigraphie] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "[Stratigraphie] Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "[Stratigraphie] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  'Les enseignements de cette UE vous ont intéressé.11'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.9'
#  "[Approche Intégré en Géosciences] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés"
#  "[Approche Intégré en Géosciences] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris"
#  "[Approche Intégré en Géosciences] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Approche Intégré en Géosciences] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Approche Intégré en Géosciences] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Approche Intégré en Géosciences] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "[Approche Intégré en Géosciences] Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "[Approche Intégré en Géosciences] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  '[Approche Intégré en Géosciences] Questions spécifique UE >> Vous sentez-vous mieux préparé à l’analyse de documents variés?'
#  '[Approche Intégré en Géosciences] Questions spécifique UE >> Le travail en sous-groupe vous a-t-il permis d’enrichir vos connaissances propres lors du travail sur documents ?'
#  '[Approche Intégré en Géosciences] Questions spécifique UE >> Les présentations à l’oral et les conseils émis par les enseignant-e-s au cours du module, vous ont-elles permis d’acquérir une meilleure pratique de l’oral ?'
#  '[Approche Intégré en Géosciences] Questions spécifique UE >> A l’issu de ce module pensez-vous avoir mieux compris l’intérêt du travail pluridisciplinaire pour étudier un objet géologique ?'
#  'Les enseignements de cette UE vous ont intéressé.12'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.10'
#  "[Magmas, Fluides, Volcans] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés"
#  "[Magmas, Fluides, Volcans] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris"
#  "[Magmas, Fluides, Volcans] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Magmas, Fluides, Volcans] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Magmas, Fluides, Volcans] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Magmas, Fluides, Volcans] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "[Magmas, Fluides, Volcans] Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "[Magmas, Fluides, Volcans] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  'Les enseignements de cette UE vous ont intéressé.13'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.11'
#  "[Eau : Ressources et Risques] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés"
#  "[Eau : Ressources et Risques] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris"
#  "[Eau : Ressources et Risques] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Eau : Ressources et Risques] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Eau : Ressources et Risques] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Eau : Ressources et Risques] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "[Eau : Ressources et Risques] Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "[Eau : Ressources et Risques] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  "[Eau : Ressources et Risques] Contenu de l'UE >> * Vous êtes satisfait de l’évaluation des connaissances sous forme de contrôle continu"
#  "* Qu'avez-vous pensé de la présentation de projets sous forme de classe inversée?"
#  "* Qu'avez-vous pensé de l’intervention d’un professionnel dans l'UE?"
#  '* Quelles étaient vos connaissances sur les Objectifs de Développement Durable et l’Agenda 2030 avant ce cours :'
#  '* Au sujet des TP' 'Les enseignements de cette UE vous ont intéressé.14'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.12'
#  "[Physique du globe] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés"
#  "[Physique du globe] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris"
#  "[Physique du globe] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "[Physique du globe] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "[Physique du globe] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "[Physique du globe] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "[Physique du globe] Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "[Physique du globe] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  'Les enseignements de cette UE vous ont intéressé.15'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.13'
#  'Question finale: Avez-vous des commentaires à rajouter sur le semestre 6 de votre licence Sciences de la Terre ?']

# %%
# Formation

pies     = [1]
New_name = ['Formation?']

c1='#1f77b4' #blue
c2='red' #green
n=4
colors2 = [colorFader(c1,c2,x/2)for x in range(2)]
colors4 = [colorFader(c1,c2,x/4)for x in range(4)]

#print(df[questions[pies[0]]])
formation = df[questions[pies[0]]]#.squeeze(axis=1)
if len(formation.shape)>1:
    print(formation.shape)
    print(formation.iloc[:,[0]])
    formation=formation.iloc[:,[0]].squeeze()
print(formation.shape)

print(type(formation))
labels0 = formation.unique()
print(labels0)
#['Majeure' 'Mineure Geosciences' 'Monodisciplinaire Sciences de la Terre'
# 'Bi-disciplinaire : Biologie - Mineure Sciences de la Terre (MEEF)']
    

colors  = ['royalblue','red','gold','green','purple','cyan']
colors_save = colors

figsize = (8, 5)

for ij,nbpie in enumerate(pies): 
    fig, ax = plt.subplots(1,figsize=figsize)

    #data = df[questions[nbpie]].value_counts()#normalize=True)
    data = formation.value_counts()#normalize=True)
    print(data)
    for ik in data.index:
       data = data.rename(index={ik:ik.split(' ')[0]})
    print(data)
    
    labels  = data.index #[ij.split(' ')[0] for ij in labels0 if ij in data.index]  
    print(labels,data.index)#,dcolors)
    
        
    gcolors = dict()
    keys    = labels
    for ik,key in enumerate(keys):
        print(ik, key)
        gcolors[key]=colors[ik]
    print(gcolors)
    labels = [ik for ik in gcolors if ik in data.index]
    data   = data.reindex(labels)
    print(labels)
    
    wedges, texts, autotexts = ax.pie(data,labels=labels
                                  ,autopct=lambda pct: func(pct, data)
                                  ,colors=[gcolors[i] for i in data.index]
                                  ,textprops=dict(color="k"),startangle=90
                                  ,pctdistance=0.7, labeldistance=1.2
                                 )
    print(ax.xaxis.get_label())
    ax.legend(wedges, labels,
          loc="upper right",
          bbox_to_anchor=(1, 1, 0.5, -0.5))
          #title=questions[1],
    plt.setp(autotexts, size=10, weight="bold")

    title = New_name[ij]
    ax.set_title(title)
    
    name_file = pathfig+title.split('?')[0]+'_Semestre'+Sem_ch+suffix
    print(title,name_file)
#plt.show()
    _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# (45,)
# <class 'pandas.core.series.Series'>
# ['Majeure' 'Mono' 'Mineure' 'Double Majeure' 'L4']
# [Sondage UE L3 Sciences de la Terre - Semestre S6] Quelle formation suivez-vous ?
# Mono              20
# Mineure           10
# Majeure            9
# Double Majeure     3
# L4                 3
# Name: count, dtype: int64
# [Sondage UE L3 Sciences de la Terre - Semestre S6] Quelle formation suivez-vous ?
# Mono       20
# Mineure    10
# Majeure     9
# Double      3
# L4          3
# Name: count, dtype: int64
# Index(['Mono', 'Mineure', 'Majeure', 'Double', 'L4'], dtype='object', name='[Sondage UE L3 Sciences de la Terre - Semestre S6] Quelle formation suivez-vous ?') Index(['Mono', 'Mineure', 'Majeure', 'Double', 'L4'], dtype='object', name='[Sondage UE L3 Sciences de la Terre - Semestre S6] Quelle formation suivez-vous ?')
# 0 Mono
# 1 Mineure
# 2 Majeure
# 3 Double
# 4 L4
# {'Mono': 'royalblue', 'Mineure': 'red', 'Majeure': 'gold', 'Double': 'green', 'L4': 'purple'}
# ['Mono', 'Mineure', 'Majeure', 'Double', 'L4']
# Text(0.5, 0, '')
# Formation? /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/Formation_Semestre6

# %%
# Ressenti

pies     = [3]
New_name = ['Ressenti?']
colors5 = [colorFader(c1,c2,x/4)for x in range(5)]
colors  =  colors5 #['royalblue','red','gold','green','purple','cyan']


#print(df[questions[pies[0]]])
formation = df[questions[pies[0]]]#.squeeze(axis=1)
if len(formation.shape)>1:
    print(formation.shape)
    print(formation.iloc[:,[0]])
    formation=formation.iloc[:,[0]].squeeze()
print(formation.shape)

print(type(formation))
labels0 = formation.unique()
print(labels0)
    

#colors_save = colors
#ci1=c2
#ci2='green'
#colors_save = [colorFader(ci1,ci2,x/4)for x in range(5)]
#colors = colors_save

cmap = plt.cm.coolwarm_r
NL   = 5 
colors = cmap(np.linspace(0., 0.95, NL))
colors_save = colors

figsize = (8, 5)

for ij,nbpie in enumerate(pies): 
    fig, ax = plt.subplots(1,figsize=figsize)

    #data = df[questions[nbpie]].value_counts()#normalize=True)
    data = formation.value_counts()#normalize=True)
    print(data)
    #for ik in data.index:
    #   data = data.rename(index={ik:ik.split(' ')[0]})
    mean = formation.mean()
    
    labels  = data.index #[ij.split(' ')[0] for ij in labels0 if ij in data.index]  
    print(labels,data.index)#,dcolors)
    
        
    gcolors = dict()
    keys_ressenti = [1,2,3,4,5]
    keys    = keys_ressenti #labels
    for ik,key in enumerate(keys):
        print(ik, key)
        gcolors[key]=colors[ik]
    print(gcolors)
    labels = [ik for ik in gcolors if ik in data.index]
    data   = data.reindex(labels)
    print(labels)
    
    wedges, texts, autotexts = ax.pie(data,labels=labels
                                  ,autopct=lambda pct: func(pct, data)
                                  ,colors=[gcolors[i] for i in data.index]
                                  ,textprops=dict(color="k"),startangle=90
                                  ,pctdistance=0.7, labeldistance=1.2
                                 )
    print(ax.xaxis.get_label())
    ax.legend(wedges, labels,
          loc="upper right",
          bbox_to_anchor=(1, 1, 0.5, -0.5))
          #title=questions[1],
    plt.setp(autotexts, size=10, weight="bold")

    title = New_name[ij]+' ('+"{:.2f}".format(mean)+'/5)'
    ax.set_title(title)
    
    name_file = pathfig+title.split('?')[0]+'_Semestre'+Sem_ch+suffix
    print(title,name_file)
#plt.show()
    _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# (45,)
# <class 'pandas.core.series.Series'>
# [4 3 5]
# Quel est votre ressenti général de ce semestre ?
# 4    19
# 5    14
# 3    12
# Name: count, dtype: int64
# Index([4, 5, 3], dtype='int64', name='Quel est votre ressenti général de ce semestre ?') Index([4, 5, 3], dtype='int64', name='Quel est votre ressenti général de ce semestre ?')
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5
# {1: array([0.70567316, 0.01555616, 0.15023281, 1.        ]), 2: array([0.95125379, 0.57879939, 0.45940781, 1.        ]), 3: array([0.89181689, 0.85197328, 0.82908527, 1.        ]), 4: array([0.60316207, 0.73152748, 0.99956528, 1.        ]), 5: array([0.28527278, 0.38012942, 0.82346855, 1.        ])}
# [3, 4, 5]
# Text(0.5, 0, '')
# Ressenti? (4.04/5) /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/Ressenti_Semestre6

# %%
#Find UEs
import itertools

if Semestre == 3:
    UEs = ['LU2ST031','LU2ST032','LU2ST033','LU2ST034',\
           'LU2ST035','LU2ST301','LU2ST302','LU2ST303',\
           'LU2ST304','RQEE']
if Semestre == 4:
    UEs = ['LU2ST041','LU2ST042','LU2ST043','LU2ST044',\
           'LU2ST045','LU2ST421','LU2ST401','LU2ST402',\
           'LU2ST403S','LU2ST403T','LU2ST404']
if Semestre == 5:
    UEs = ['LU3ST053','LU3ST055','LU3ST056','LU3ST057',\
           'LU3ST058','LU3ST059','LU3ST501','LU3ST502',\
           'LU3ST507','LU3STOIP']
if Semestre == 6:
    UEs = ['LU3ST060','LU3ST061','LU3ST062','LU3ST063',\
           'LU3ST066','LU3ST068','LU3ST069','LU3ST603',\
           'LU3ST605','LU3ST606','LU3ST607','LU3ST608',\
           'LU3ST609','LU3ST613','LU3ST614','LU3ST615',\
           'LU3ST621']
print(UEs)

# Find start of each UE
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présenté
sentence = "Que diriez-vous des objectifs de l'UE"
word     = "résenté" # Présenté ou présenté
UEs0 = [(ij,question.replace(' ?','').split(' ')[-1]) for ij,question in enumerate(questions) if ((sentence in question) and (word in question))]
print(UEs0)
# Out:
# ['LU3ST060', 'LU3ST061', 'LU3ST062', 'LU3ST063', 'LU3ST066', 'LU3ST068', 'LU3ST069', 'LU3ST603', 'LU3ST605', 'LU3ST606', 'LU3ST607', 'LU3ST608', 'LU3ST069', 'LU3ST613', 'LU3ST614', 'LU3ST615', 'LU3ST621']
# [(4, 'présentés'), (16, 'présentés'), (26, 'présentés'), (35, 'présentés'), (45, 'présentés'), (55, 'présentés'), (65, 'présentés'), (75, 'présentés'), (87, 'présentés'), (97, 'présentés'), (107, 'présentés'), (117, 'présentés'), (127, 'présentés'), (137, 'présentés'), (151, 'présentés'), (161, 'présentés'), (176, 'présentés')]

# %%
#UE_idx   = [ij[0] for ij in UEs] #[1,2,3,4,5,6,8,17,18]
#UE_names = [ij[1].strip("()?") for ij in UEs] #['Profession?', 'Permanent?', 'Site?', 'Climaction?','Stratégie?','Quel objectif?',
#            #'Individuel ou collectif?','Calculateur?','Influence recherche?'].replace('(','').replace(')','')

#UE_idx   = range(len(UEs))
UE_idx   = [ij[0] for ij in UEs0] 
UE_names = UEs

print(UE_idx,UE_names)
#colors2 = ['red', 'blue']
#a       = np.random.random(4)
#cs      = cm.Set1(np.arange(4)/4.)

keys1 = ['OUI','NON']
#keys2 = ['Tout à fait d\'accord','Plutôt d\'accord','Plutôt pas d\'accord','Pas du tout d\'accord']
keys2 = ['Tout à fait d\'accord','Plutôt d\'accord','Plutôt pas d\'accord','Pas du tout d\'accord']

# Changing key for specific question
tabword = ['intéressé']
keys3   = keys_ressenti

# Changing for Mineralogie
tabword2 = ['heures']
keys5    = ['< 1','De 1h à 2h', 'De 2h à 3h','> 3h']

#Idx_change = [9]
#tabword = ['cohérence','lien entre']
#keys3 = ['Bonne','Plutôt bonne','Plutôt mauvaise','Mauvaise']

# Changing answers for specific question
#UE_change  = ['LU2ST034','LU2ST303','LU2ST352','LU2ST044','LU2ST402','LU3ST603','LU3ST602']
#keys4 = ['Très clair','Assez clair','Assez flou','Très flou']

# Changing answers for S1
#tabword2 = ['capsules']
#keys5 = ['Oui, beaucoup (> 10 vidéos)','Oui, certaines (5-10 vidéos)',\
#'Quelques unes (1-4 vidéos)','Non, mais je sais qu\'elles existaient',\
#'Non, car je ne savais pas qu\'il y avait des capsules vidéos de soutien']
#tabword3 = ['Ces vidéos']
#keys6 = ['Oui, le plus souvent','Oui, certaines',\
#         'Non, même si je les ai visionnées','Non, car pas visionnées']

# Changing answers for S6
#tabword4 = ['Vous sentez-vous','lien existant entre disciplines']
#keys7 = ['Oui','Pas d\'avis','Non']

#tabword5 = ['davantage de TP']
#keys8 = ['Davantage de TD et exercices “sur papier” encadrés',\
#         'Je ne changerais rien',\
#         'Davantage de TP en salle informatique',\
#        ]

# Changing answers for S5 (OIP)
tabword6 = ['avenir professionnel']
keys9 = ['Utile','Pas d\'avis particulier', 'Pas utile']

#keys6 = ['Oui, beaucoup (> 10 vidéos)','Oui, certaines (5-10 vidéos)',\
#'Quelques unes (1-4 vidéos)','Non, mais je sais qu\'elles existaient',\
#'Non, car je ne savais pas qu\'il y avait des capsules vidéos de soutien']

print(tabword)

# 9 questions !
Nb_questions = 15 #(UE_idx[1]-UE_idx[0])-1
ofs          = 4 # Nombre de questions non UE (avis general Licence, parcours, UE suivis)
if Semestre == 1:
    Nb_questions = 19
if Semestre == 5:
    Nb_questions = 17
if Semestre == 6:
    Nb_questions = 10
print(Nb_questions)

figsize = (8, 5)

for ij,idx in enumerate(UE_idx):
    UE = UE_names[ij]
    print('UE : ',UE)
    
    path_file = pathfig+UE+'/'
    print(path_file)
    _mkdir(path_file)
    
    for ik in range(Nb_questions):
      fig, ax = plt.subplots(1,figsize=figsize)

      # Offset + (NumUE*(NB questions+1)) +ik
      #idx1    = ofs+(idx*(Nb_questions+1))+ik
      idx1    = idx+ik
      data    = df[questions[idx1]]

      #data = data.replace('\\','')
      data = data.replace('Tout à fait d\\\'accord','Tout à fait d\'accord')
      data = data.replace('Plutôt d\\\'accord','Plutôt d\'accord')
      data = data.replace('Plutôt pas d\\\'accord','Plutôt pas d\'accord')
      data = data.replace('Pas du tout d\\\'accord','Pas du tout d\'accord')
      data = data.replace('Pas d\\\'avis particulier','Pas d\'avis particulier')

        
      #data = data.replace('d\\\'accord','d\\\'accord')
      #data = data.replace('è','\'e')
      #data = data.replace('Très','Tr\'es')
      data0 = data.value_counts() #normalize=True) 
                
      print('Data : ',data0)
      #colors = colors2 ; 
      changecolor = 0
      keys = keys1
      if ('OUI' in data0.keys()):
        keys = keys1
      else:
        keys = keys2
        #if ik in Idx_change:
        #print('tabword ',tabword,questions[idx1])
        print('tabword ',[ii in questions[idx1] for ii in tabword])
        if (any([ii in questions[idx1] for ii in tabword]) 
           and not(any([ii in questions[idx1] for ii in ['laboratoire'] ])) ):
        #if 'cohérence' in questions[idx+ik]:
            keys = keys3
            changecolor = 1 # cas intéressé
            #if UE in UE_change:
            #    keys = keys4
        elif any([ii in questions[idx1] for ii in tabword2]):
            keys = keys5
        #elif any([ii in questions[idx1] for ii in tabword3]):
        #    keys = keys6
      #if any([ii in questions[idx1] for ii in tabword4]):
      #      keys = keys7
      #if any([ii in questions[idx1] for ii in tabword5]):
      #      keys = keys8
      if any([ii in questions[idx1] for ii in tabword6]):
            keys = keys9
      print(UE,idx,keys,data0.index)

      #import difflib
      #output_list = [li for li in difflib.ndiff('c\'e','ce') if li[0] != ' ']
      #print(output_list)
        
      cmap = plt.cm.bwr
      colors = cmap(np.linspace(0., 0.95, len(keys)))
      if changecolor:
          colors = colors_save 
  
      gcolors=dict()
      for ij,key in enumerate(keys):
        gcolors[key]=colors[ij]
      labels = [ij for ij in gcolors if ij in data0.index]
      data0   = data0.reindex(labels)
      print(labels)
        
      wedges, texts, autotexts = ax.pie(data0,autopct=lambda pct: func(pct, data0)\
                                            ,colors=[gcolors[i] for i in data0.index]\
                                            ,textprops=dict(color="w") #, colors=color
                                            ,startangle=0)
    
      ax.legend(wedges, data0.index,loc="best",bbox_to_anchor=(1, 1, 0.5, -0.5))
      plt.setp(autotexts, size=10, weight="bold")
    
      title = questions[idx1].split('.')[0]
      if any([ii in questions[idx1] for ii in tabword]): # intéressé
          try:
            mean   = np.nanmean(data)
            title += ' ('+"{:.2f}".format(mean)+'/5)'
          except:
            pass

      ax.set_title(title)
      print(title)
    
      name_file = 'Question_'+str(ik)
      name_file = path_file + name_file
      print(name_file)
      _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# [4, 16, 26, 35, 45, 55, 65, 75, 87, 97, 107, 117, 127, 137, 151, 161, 176] ['LU3ST060', 'LU3ST061', 'LU3ST062', 'LU3ST063', 'LU3ST066', 'LU3ST068', 'LU3ST069', 'LU3ST603', 'LU3ST605', 'LU3ST606', 'LU3ST607', 'LU3ST608', 'LU3ST069', 'LU3ST613', 'LU3ST614', 'LU3ST615', 'LU3ST621']
# ['intéressé']
# 10
# UE :  LU3ST060
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST060/
# path :  /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST060/
# True
# Data :  [Climats et paléoclimats] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# OUI    9
# Name: count, dtype: int64
# LU3ST060 4 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='[Climats et paléoclimats] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés')
# ['OUI']
# [Climats et paléoclimats] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST060/Question_0
# Data :  [Climats et paléoclimats] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# OUI    9
# Name: count, dtype: int64
# LU3ST060 4 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='[Climats et paléoclimats] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris')
# ['OUI']
# [Climats et paléoclimats] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST060/Question_1
# Data :  * Etes-vous satisfait de l’évaluation des connaissances sous forme de contrôle continu?
# Oui                                                                                                     4
# J’aurais préféré le format control continu pour la partie atmosphère et océan puis un examen final.     1
# 2 contrôles sur 50 chacun c'est trop peu il aurait fallu faire des contrôles intermediaires             1
# Vous aurez préféré un examen final                                                                      1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST060 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Oui',
#        'J’aurais préféré le format control continu pour la partie atmosphère et océan puis un examen final. ',
#        '2 contrôles sur 50 chacun c'est trop peu il aurait fallu faire des contrôles intermediaires',
#        'Vous aurez préféré un examen final'],
#       dtype='object', name='* Etes-vous satisfait de l’évaluation des connaissances sous forme de contrôle continu?')
# []
# * Etes-vous satisfait de l’évaluation des connaissances sous forme de contrôle continu?
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST060/Question_2
# Data :  [Climats et paléoclimats] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# Tout à fait d'accord    4
# Plutôt d'accord         3
# Plutôt pas d'accord     2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST060 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='[Climats et paléoclimats] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# [Climats et paléoclimats] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST060/Question_3
# Data :  [Climats et paléoclimats] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# Tout à fait d'accord    7
# Plutôt d'accord         2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST060 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='[Climats et paléoclimats] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Climats et paléoclimats] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST060/Question_4
# Data :  [Climats et paléoclimats] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# Tout à fait d'accord    7
# Plutôt pas d'accord     1
# Plutôt d'accord         1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST060 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt pas d'accord', 'Plutôt d'accord'], dtype='object', name='[Climats et paléoclimats] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# [Climats et paléoclimats] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST060/Question_5
# Data :  [Climats et paléoclimats] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# Tout à fait d'accord    6
# Plutôt d'accord         3
# Name: count, dtype: int64
# tabword  [False]
# LU3ST060 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='[Climats et paléoclimats] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Climats et paléoclimats] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST060/Question_6
# Data :  [Climats et paléoclimats] Contenu de l'UE >> Les documents de l'UE sont utiles
# Tout à fait d'accord    7
# Plutôt d'accord         2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST060 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='[Climats et paléoclimats] Contenu de l'UE >> Les documents de l'UE sont utiles')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Climats et paléoclimats] Contenu de l'UE >> Les documents de l'UE sont utiles
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST060/Question_7
# Data :  [Climats et paléoclimats] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# Tout à fait d'accord    7
# Plutôt d'accord         2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST060 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='[Climats et paléoclimats] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Climats et paléoclimats] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST060/Question_8
# Data :  * Choisir 2 thématiques que vous voudriez voir davantage abordées dans cette UE :
# Le climat des autres planètes\nLes couplages et rétroactions du système climatique                                           4
# La dynamique de l’atmosphère et la variabilité climatique long terme\nLes couplages et rétroactions du système climatique    1
# Le climat des autres planètes\nLa dynamique de l’atmosphère et la variabilité climatique long terme                          1
# L’effet de serre et la température moyenne au cours des âges géologiques\nLes grands cycles (eau, carbone)                   1
# Les évidences géologiques et proxies utilisés en paléoclimatologie                                                           1
# Les évidences géologiques et proxies utilisés en paléoclimatologie\nLes grands cycles (eau, carbone)                         1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST060 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Le climat des autres planètes\nLes couplages et rétroactions du système climatique',
#        'La dynamique de l’atmosphère et la variabilité climatique long terme\nLes couplages et rétroactions du système climatique',
#        'Le climat des autres planètes\nLa dynamique de l’atmosphère et la variabilité climatique long terme',
#        'L’effet de serre et la température moyenne au cours des âges géologiques\nLes grands cycles (eau, carbone)',
#        'Les évidences géologiques et proxies utilisés en paléoclimatologie',
#        'Les évidences géologiques et proxies utilisés en paléoclimatologie\nLes grands cycles (eau, carbone)'],
#       dtype='object', name='* Choisir 2 thématiques que vous voudriez voir davantage abordées dans cette UE :')
# []
# * Choisir 2 thématiques que vous voudriez voir davantage abordées dans cette UE :
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST060/Question_9
# UE :  LU3ST061
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST061/
# path :  /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST061/
# True
# Data :  [Biogéochimie Océan-Atmosphère] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# OUI    5
# NON    2
# Name: count, dtype: int64
# LU3ST061 16 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='[Biogéochimie Océan-Atmosphère] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés')
# ['OUI', 'NON']
# [Biogéochimie Océan-Atmosphère] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST061/Question_0
# Data :  [Biogéochimie Océan-Atmosphère] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# OUI    4
# NON    3
# Name: count, dtype: int64
# LU3ST061 16 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='[Biogéochimie Océan-Atmosphère] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris')
# ['OUI', 'NON']
# [Biogéochimie Océan-Atmosphère] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST061/Question_1
# Data :  [Biogéochimie Océan-Atmosphère] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# Plutôt d'accord         2
# Pas du tout d'accord    2
# Tout à fait d'accord    2
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST061 16 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Pas du tout d'accord', 'Tout à fait d'accord',
#        'Plutôt pas d'accord'],
#       dtype='object', name='[Biogéochimie Océan-Atmosphère] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# [Biogéochimie Océan-Atmosphère] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST061/Question_2
# Data :  [Biogéochimie Océan-Atmosphère] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# Tout à fait d'accord    4
# Plutôt d'accord         2
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST061 16 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='[Biogéochimie Océan-Atmosphère] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# [Biogéochimie Océan-Atmosphère] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST061/Question_3
# Data :  [Biogéochimie Océan-Atmosphère] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# Plutôt pas d'accord     3
# Plutôt d'accord         2
# Pas du tout d'accord    1
# Tout à fait d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST061 16 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt pas d'accord', 'Plutôt d'accord', 'Pas du tout d'accord',
#        'Tout à fait d'accord'],
#       dtype='object', name='[Biogéochimie Océan-Atmosphère] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# [Biogéochimie Océan-Atmosphère] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST061/Question_4
# Data :  [Biogéochimie Océan-Atmosphère] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# Tout à fait d'accord    4
# Plutôt d'accord         2
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST061 16 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='[Biogéochimie Océan-Atmosphère] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# [Biogéochimie Océan-Atmosphère] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST061/Question_5
# Data :  [Biogéochimie Océan-Atmosphère] Contenu de l'UE >> Les documents de l'UE sont utiles
# Plutôt d'accord         3
# Tout à fait d'accord    2
# Plutôt pas d'accord     1
# Pas du tout d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST061 16 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord', 'Plutôt pas d'accord',
#        'Pas du tout d'accord'],
#       dtype='object', name='[Biogéochimie Océan-Atmosphère] Contenu de l'UE >> Les documents de l'UE sont utiles')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# [Biogéochimie Océan-Atmosphère] Contenu de l'UE >> Les documents de l'UE sont utiles
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST061/Question_6
# Data :  [Biogéochimie Océan-Atmosphère] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# Plutôt pas d'accord     4
# Tout à fait d'accord    2
# Pas du tout d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST061 16 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt pas d'accord', 'Tout à fait d'accord', 'Pas du tout d'accord'], dtype='object', name='[Biogéochimie Océan-Atmosphère] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante')
# ["Tout à fait d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# [Biogéochimie Océan-Atmosphère] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST061/Question_7
# Data :  Les enseignements de cette UE vous ont intéressé
# 5.0    4
# 3.0    2
# 1.0    1
# Name: count, dtype: int64
# tabword  [True]
# LU3ST061 16 [1, 2, 3, 4, 5] Index([5.0, 3.0, 1.0], dtype='float64', name='Les enseignements de cette UE vous ont intéressé')
# [1, 3, 5]
# Les enseignements de cette UE vous ont intéressé (3.86/5)
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST061/Question_8
# Data :  Avez-vous des commentaires à rajouter au sujet de cette UE ?.1
# La partie océan reprend des notions que nous avons déjà abordées maintes fois au cours de la licence comme si nous les découvrions. En revanche, la partie atmosphère n'est pas du tout adaptée au niveau en physique des étudiants en géologie, et d'autant plus pour ceux qui n'ont pas suivi l'UE météorologie. De plus, le professeur n'instaure pas un climat de confiance pour répondre aux questions pertinentes sur le cours, et au contraire nous rabaisse.     1
# Changement du prof de la partie atmosphère avec un prof qui est plus pédagogue et qui ne crie pas aux étudiants en cas de non compréhension du sujet                                                                                                                                                                                                                                                                                                                     1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST061 16 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['La partie océan reprend des notions que nous avons déjà abordées maintes fois au cours de la licence comme si nous les découvrions. En revanche, la partie atmosphère n'est pas du tout adaptée au niveau en physique des étudiants en géologie, et d'autant plus pour ceux qui n'ont pas suivi l'UE météorologie. De plus, le professeur n'instaure pas un climat de confiance pour répondre aux questions pertinentes sur le cours, et au contraire nous rabaisse. ', 'Changement du prof de la partie atmosphère avec un prof qui est plus pédagogue et qui ne crie pas aux étudiants en cas de non compréhension du sujet'], dtype='object', name='Avez-vous des commentaires à rajouter au sujet de cette UE ?.1')
# []
# Avez-vous des commentaires à rajouter au sujet de cette UE ?
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST061/Question_9
# UE :  LU3ST062
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST062/
# path :  /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST062/
# True
# Data :  [Atelier Fablab] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# OUI    8
# Name: count, dtype: int64
# LU3ST062 26 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='[Atelier Fablab] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés')
# ['OUI']
# [Atelier Fablab] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST062/Question_0
# Data :  [Atelier Fablab] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# OUI    8
# Name: count, dtype: int64
# LU3ST062 26 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='[Atelier Fablab] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris')
# ['OUI']
# [Atelier Fablab] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST062/Question_1
# Data :  [Atelier Fablab] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# Tout à fait d'accord    6
# Plutôt d'accord         2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST062 26 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='[Atelier Fablab] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Atelier Fablab] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST062/Question_2
# Data :  [Atelier Fablab] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# Tout à fait d'accord    7
# Plutôt d'accord         1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST062 26 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='[Atelier Fablab] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Atelier Fablab] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST062/Question_3
# Data :  [Atelier Fablab] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# Tout à fait d'accord    8
# Name: count, dtype: int64
# tabword  [False]
# LU3ST062 26 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord'], dtype='object', name='[Atelier Fablab] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE')
# ["Tout à fait d'accord"]
# [Atelier Fablab] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST062/Question_4
# Data :  [Atelier Fablab] Contenu de l'UE >> Le lien entre l'UE Stage Fablab et les autres enseignements est cohérent
# Plutôt d'accord         3
# Tout à fait d'accord    3
# Plutôt pas d'accord     2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST062 26 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord', 'Plutôt pas d'accord'], dtype='object', name='[Atelier Fablab] Contenu de l'UE >> Le lien entre l'UE Stage Fablab et les autres enseignements est cohérent')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# [Atelier Fablab] Contenu de l'UE >> Le lien entre l'UE Stage Fablab et les autres enseignements est cohérent
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST062/Question_5
# Data :  [Atelier Fablab] Contenu de l'UE >> L'organisation de l'atelier s'est bien passé
# Tout à fait d'accord    8
# Name: count, dtype: int64
# tabword  [False]
# LU3ST062 26 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord'], dtype='object', name='[Atelier Fablab] Contenu de l'UE >> L'organisation de l'atelier s'est bien passé')
# ["Tout à fait d'accord"]
# [Atelier Fablab] Contenu de l'UE >> L'organisation de l'atelier s'est bien passé
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST062/Question_6
# Data :  Les enseignements de cette UE vous ont intéressé.1
# 5.0    5
# 4.0    3
# Name: count, dtype: int64
# tabword  [True]
# LU3ST062 26 [1, 2, 3, 4, 5] Index([5.0, 4.0], dtype='float64', name='Les enseignements de cette UE vous ont intéressé.1')
# [4, 5]
# Les enseignements de cette UE vous ont intéressé (4.62/5)
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST062/Question_7
# Data :  Avez-vous des commentaires à rajouter au sujet de cette UE ?.2
# Il faudrait le rendre accessible pour les monos aussi !                                                                                                                                                                                                                                    1
# Profs super cool et très sympa                                                                                                                                                                                                                                                             1
# C'est une UE qui permet de mettre en pratique notre savoir de géologue, je pense qu'elle pourrait être proposée aux mono géol !                                                                                                                                                            1
# Cette UE m’a permis de découvrir le FabLab et de voir à quel point il était accessible ! 👍                                                                                                                                                                                                 1
# Super UE, très intéressante et qui nous permet de développer des compétences pratiques et différentes des autres cours. L'équipe pédagogique est à l'écoute et toujours prête à nous aider en cas de question ou de difficulté. Cette UE est une des plus intéressantes de ma licence !    1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST062 26 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Il faudrait le rendre accessible pour les monos aussi ! ',
#        'Profs super cool et très sympa ',
#        'C'est une UE qui permet de mettre en pratique notre savoir de géologue, je pense qu'elle pourrait être proposée aux mono géol !',
#        'Cette UE m’a permis de découvrir le FabLab et de voir à quel point il était accessible ! 👍',
#        'Super UE, très intéressante et qui nous permet de développer des compétences pratiques et différentes des autres cours. L'équipe pédagogique est à l'écoute et toujours prête à nous aider en cas de question ou de difficulté. Cette UE est une des plus intéressantes de ma licence !'],
#       dtype='object', name='Avez-vous des commentaires à rajouter au sujet de cette UE ?.2')
# []
# Avez-vous des commentaires à rajouter au sujet de cette UE ?
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST062/Question_8
# Data :  [Projet Informatique] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# OUI    8
# Name: count, dtype: int64
# LU3ST062 26 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='[Projet Informatique] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés')
# ['OUI']
# [Projet Informatique] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST062/Question_9
# UE :  LU3ST063
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST063/
# path :  /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST063/
# True
# Data :  [Projet Informatique] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# OUI    8
# Name: count, dtype: int64
# LU3ST063 35 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='[Projet Informatique] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés')
# ['OUI']
# [Projet Informatique] Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST063/Question_0
# Data :  [Projet Informatique] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# OUI    7
# NON    1
# Name: count, dtype: int64
# LU3ST063 35 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='[Projet Informatique] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris')
# ['OUI', 'NON']
# [Projet Informatique] Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST063/Question_1
# Data :  [Projet Informatique] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# Tout à fait d'accord    4
# Pas du tout d'accord    2
# Plutôt d'accord         2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST063 35 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Pas du tout d'accord', 'Plutôt d'accord'], dtype='object', name='[Projet Informatique] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables')
# ["Tout à fait d'accord", "Plutôt d'accord", "Pas du tout d'accord"]
# [Projet Informatique] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST063/Question_2
# Data :  [Projet Informatique] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# Plutôt d'accord         4
# Tout à fait d'accord    4
# Name: count, dtype: int64
# tabword  [False]
# LU3ST063 35 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord'], dtype='object', name='[Projet Informatique] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Projet Informatique] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST063/Question_3
# Data :  [Projet Informatique] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# Tout à fait d'accord    6
# Plutôt d'accord         2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST063 35 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='[Projet Informatique] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Projet Informatique] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST063/Question_4
# Data :  [Projet Informatique] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# Tout à fait d'accord    4
# Plutôt d'accord         2
# Pas du tout d'accord    1
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST063 35 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Pas du tout d'accord',
#        'Plutôt pas d'accord'],
#       dtype='object', name='[Projet Informatique] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# [Projet Informatique] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST063/Question_5
# Data :  [Projet Informatique] Contenu de l'UE >> Les documents de l'UE sont utiles
# Tout à fait d'accord    3
# Plutôt pas d'accord     3
# Plutôt d'accord         2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST063 35 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt pas d'accord', 'Plutôt d'accord'], dtype='object', name='[Projet Informatique] Contenu de l'UE >> Les documents de l'UE sont utiles')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# [Projet Informatique] Contenu de l'UE >> Les documents de l'UE sont utiles
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST063/Question_6
# Data :  [Projet Informatique] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# Plutôt pas d'accord     3
# Plutôt d'accord         3
# Tout à fait d'accord    2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST063 35 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt pas d'accord', 'Plutôt d'accord', 'Tout à fait d'accord'], dtype='object', name='[Projet Informatique] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# [Projet Informatique] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST063/Question_7
# Data :  Les enseignements de cette UE vous ont intéressé.2
# 5.0    3
# 3.0    2
# 4.0    2
# 2.0    1
# Name: count, dtype: int64
# tabword  [True]
# LU3ST063 35 [1, 2, 3, 4, 5] Index([5.0, 3.0, 4.0, 2.0], dtype='float64', name='Les enseignements de cette UE vous ont intéressé.2')
# [2, 3, 4, 5]
# Les enseignements de cette UE vous ont intéressé (3.88/5)
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST063/Question_8
# Data :  Avez-vous des commentaires à rajouter au sujet de cette UE?
# La précision : "pour les élèves à l'aise en informatique en L2" est justifiée voire un peu trop. L'UE est simple en apparence : améliorer un code déjà existant pour qu'il devienne plus rapide, plus performant ou qu'il fasse fasse de nouvelles choses. Cependant, le niveau demandé est selon moi trop haut, à tel point que je n'ai eu l'impression de ne rien faire. En effet, les seules avancées étaient effectuées par la prof sous nos yeux ébahis. Donc réexpliquer le programme (une partie des points de l'examen final) est plutôt compliqué. \nEnsuite, les attendus de l'UE ne sont pas réellement clair, certes il faut améliorer un programme, mais on ne sait pas ni comment, ni pourquoi, tout est fait à tâtons. De plus, les objectifs (en tout cas pour notre groupe) changeaient chaque semaine donc nos avancés d'une  semaine à l'autre devenaient quasiment obsolètes.\nCe qu'il faudrait faire pour améliorer l'UE et la rendre plus agréable pour tous serait tout d'abord que les profs aient des corrections et donc un but à nous faire atteindre. Ensuite, bien que l'idée de nous laisser réfléchir par nous même et chercher les solutions à nos problèmes soient bonne, je pense qu'il faudrait un petit peu plus d'accompagnement afin d'encore une fois nous faire comprendre le but de l'exercice.\nDurant cette UE je n'ai eu l'impression de rien apprendre à part m'énerver tout seul devant mon ordinateur, compétence que j'avais déjà acquise en L2. C'est dommage...    1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST063 35 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['La précision : "pour les élèves à l'aise en informatique en L2" est justifiée voire un peu trop. L'UE est simple en apparence : améliorer un code déjà existant pour qu'il devienne plus rapide, plus performant ou qu'il fasse fasse de nouvelles choses. Cependant, le niveau demandé est selon moi trop haut, à tel point que je n'ai eu l'impression de ne rien faire. En effet, les seules avancées étaient effectuées par la prof sous nos yeux ébahis. Donc réexpliquer le programme (une partie des points de l'examen final) est plutôt compliqué. \nEnsuite, les attendus de l'UE ne sont pas réellement clair, certes il faut améliorer un programme, mais on ne sait pas ni comment, ni pourquoi, tout est fait à tâtons. De plus, les objectifs (en tout cas pour notre groupe) changeaient chaque semaine donc nos avancés d'une  semaine à l'autre devenaient quasiment obsolètes.\nCe qu'il faudrait faire pour améliorer l'UE et la rendre plus agréable pour tous serait tout d'abord que les profs aient des corrections et donc un but à nous faire atteindre. Ensuite, bien que l'idée de nous laisser réfléchir par nous même et chercher les solutions à nos problèmes soient bonne, je pense qu'il faudrait un petit peu plus d'accompagnement afin d'encore une fois nous faire comprendre le but de l'exercice.\nDurant cette UE je n'ai eu l'impression de rien apprendre à part m'énerver tout seul devant mon ordinateur, compétence que j'avais déjà acquise en L2. C'est dommage...'], dtype='object', name='Avez-vous des commentaires à rajouter au sujet de cette UE?')
# []
# Avez-vous des commentaires à rajouter au sujet de cette UE?
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST063/Question_9
# UE :  LU3ST066
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST066/
# path :  /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST066/
# True
# Data :  [Paléontologie et évolution] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés
# OUI    17
# Name: count, dtype: int64
# LU3ST066 45 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='[Paléontologie et évolution] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés')
# ['OUI']
# [Paléontologie et évolution] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST066/Question_0
# Data :  [Paléontologie et évolution] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris
# OUI    15
# NON     2
# Name: count, dtype: int64
# LU3ST066 45 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='[Paléontologie et évolution] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris')
# ['OUI', 'NON']
# [Paléontologie et évolution] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST066/Question_1
# Data :  [Paléontologie et évolution] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# Plutôt d'accord         9
# Tout à fait d'accord    7
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST066 45 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord', 'Plutôt pas d'accord'], dtype='object', name='[Paléontologie et évolution] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# [Paléontologie et évolution] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST066/Question_2
# Data :  [Paléontologie et évolution] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# Tout à fait d'accord    11
# Plutôt d'accord          4
# Plutôt pas d'accord      2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST066 45 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='[Paléontologie et évolution] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# [Paléontologie et évolution] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST066/Question_3
# Data :  [Paléontologie et évolution] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# Tout à fait d'accord    10
# Plutôt d'accord          4
# Plutôt pas d'accord      2
# Pas du tout d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST066 45 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord',
#        'Pas du tout d'accord'],
#       dtype='object', name='[Paléontologie et évolution] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# [Paléontologie et évolution] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST066/Question_4
# Data :  [Paléontologie et évolution] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# Tout à fait d'accord    11
# Plutôt d'accord          3
# Plutôt pas d'accord      2
# Pas du tout d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST066 45 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord',
#        'Pas du tout d'accord'],
#       dtype='object', name='[Paléontologie et évolution] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# [Paléontologie et évolution] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST066/Question_5
# Data :  [Paléontologie et évolution] Contenu de l'UE >> Les documents de l'UE sont utiles
# Tout à fait d'accord    10
# Plutôt d'accord          7
# Name: count, dtype: int64
# tabword  [False]
# LU3ST066 45 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='[Paléontologie et évolution] Contenu de l'UE >> Les documents de l'UE sont utiles')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Paléontologie et évolution] Contenu de l'UE >> Les documents de l'UE sont utiles
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST066/Question_6
# Data :  [Paléontologie et évolution] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# Tout à fait d'accord    8
# Plutôt pas d'accord     5
# Plutôt d'accord         3
# Pas du tout d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST066 45 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt pas d'accord', 'Plutôt d'accord',
#        'Pas du tout d'accord'],
#       dtype='object', name='[Paléontologie et évolution] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# [Paléontologie et évolution] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST066/Question_7
# Data :  Les enseignements de cette UE vous ont intéressé.3
# 5.0    8
# 4.0    4
# 2.0    3
# 3.0    1
# 1.0    1
# Name: count, dtype: int64
# tabword  [True]
# LU3ST066 45 [1, 2, 3, 4, 5] Index([5.0, 4.0, 2.0, 3.0, 1.0], dtype='float64', name='Les enseignements de cette UE vous ont intéressé.3')
# [1, 2, 3, 4, 5]
# Les enseignements de cette UE vous ont intéressé (3.88/5)
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST066/Question_8
# Data :  Avez-vous des commentaires à rajouter au sujet de cette UE?.1
# Dans cette UE Paléontologie et Évolution, j'ai souvent cherché la paléontologie... Les cours portaient plutôt sur des principes de la licence de biologie qui sont essentiels pour la poursuite d'études en paléontologie, mais le manque d'applications à la paléontologie se fait malheureusement ressentir. Contrairement à la L2 ou nous observions, dessinions et apprenions à reconnaitre de nouveaux fossiles, ici beaucoup de théorie pour très peu de pratique. La partie que j'ai trouvé la plus intéressante a été celle sur les Hominidés qui justement regroupait théorie + pratique. C'est dommage parce qu'ajouter un petit peu plus de TP au lieu de TD nous donnerait moins l'impression d'une UE contre-la-montre pour rattraper les points essentiels à la paléontologie de deux années de biologie.\nJ'ajoute à cela des cours parfois assez mal structurés où l'on n'arrive pas à comprendre ce qu'il faut savoir (terrestrialisation par exemple).    1
# Pour l’exam de TP/TD (censé être uniquement sur les TP/TD) il y avait clairement une partie de l’évaluation sur la partie cours des hominidés (donc je n’avais pas révisé). Je n’ai pas trouvé le dm critique de vidéo très interessant. Par contre la grande majorité des cours étaient très intéressants et bien amenés. Enfin, c’est à mon avis une UE essentielle pour les personnes en mono geol, qui veulent ensuite faire de la pal.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# J’ai redécouvert la biologie avec cette UE, alors que je ne suis pas très « fan » de cette matière.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# Très peu de rapport avec les autres UE de paléontologie de L2. Beaucoup de cours qui ne m’ont pas intéressés et certains cours que j’avais déjà vu dans ma majeure biologie (même prof et même diapo)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# Comme les autres UEs de paléontologie, les cours de bonne qualité sont au rdv !\nSeul petit bémol ici : beaucoup de rappel sont fait pour les biologistes... Ils sont bien entendu necessaires pour ceux strictement géologues, mais peut être qu'il serait bon de prévenir les biologistes qu'ils risquent de revoir beaucoup de choses.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# ...
#        'Les TP de la partie hydromagmatisme pourraient s'étaler sur plus d'heures afin de permettre aux étudiants de comprendre toutes les notions et subtilités abordées. Mais définitivement la meilleure UE et la plus intéressante de la licence :)',
#        'Manque d'informations pour les attendues du contrôle continu',
#        'Le travail de documentation d articles scientifiques n est pas adapté aux deadlines des L4 qui font Barles (cas exceptionnel). Les modalités de ce travail n ont été réellement expliqué qu en fin de semestre. Le fait que celui ci était à rendre en anglais ne nous a été indiqué que le jour du rendu, sans décalage de la deadline.',
#        'Ce serait vraiment cool pour les années suivantes d’organiser mieux l’UE : on a eu aucune fiche de consigne pour les exposés, et les consignes ont changer 2 jours avant… également un planning clair des cours, avec la date et l’enseignant aurait été super et nous aurait éviter de venir pour rien par deux fois… ',
#        'Les cours étaient vraiment très intéressants, mais la charge de travail était un peu lourde (2 présentations orales avec travail de groupe + un exam). Après c'est aussi à nous de nous organiser correctement ! C'était faisable mais parfois peut-être bâclé.',
#        'pas assez de contrôle continu \n'],
#       dtype='object', name='Avez-vous des commentaires à rajouter au sujet de cette UE?.11')
# []
# Avez-vous des commentaires à rajouter au sujet de cette UE?
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST614/Question_9
# UE :  LU3ST615
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST615/
# path :  /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST615/
# True
# Data :  [Eau : Ressources et Risques] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés
# OUI    11
# Name: count, dtype: int64
# LU3ST615 161 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='[Eau : Ressources et Risques] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés')
# ['OUI']
# [Eau : Ressources et Risques] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST615/Question_0
# Data :  [Eau : Ressources et Risques] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris
# OUI    11
# Name: count, dtype: int64
# LU3ST615 161 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='[Eau : Ressources et Risques] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris')
# ['OUI']
# [Eau : Ressources et Risques] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST615/Question_1
# Data :  [Eau : Ressources et Risques] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# Tout à fait d'accord    8
# Plutôt d'accord         3
# Name: count, dtype: int64
# tabword  [False]
# LU3ST615 161 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='[Eau : Ressources et Risques] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Eau : Ressources et Risques] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST615/Question_2
# Data :  [Eau : Ressources et Risques] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# Tout à fait d'accord    8
# Plutôt d'accord         3
# Name: count, dtype: int64
# tabword  [False]
# LU3ST615 161 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='[Eau : Ressources et Risques] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Eau : Ressources et Risques] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST615/Question_3
# Data :  [Eau : Ressources et Risques] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# Tout à fait d'accord    8
# Plutôt d'accord         3
# Name: count, dtype: int64
# tabword  [False]
# LU3ST615 161 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='[Eau : Ressources et Risques] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Eau : Ressources et Risques] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST615/Question_4
# Data :  [Eau : Ressources et Risques] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# Tout à fait d'accord    7
# Plutôt d'accord         4
# Name: count, dtype: int64
# tabword  [False]
# LU3ST615 161 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='[Eau : Ressources et Risques] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Eau : Ressources et Risques] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST615/Question_5
# Data :  [Eau : Ressources et Risques] Contenu de l'UE >> Les documents de l'UE sont utiles
# Tout à fait d'accord    7
# Plutôt d'accord         4
# Name: count, dtype: int64
# tabword  [False]
# LU3ST615 161 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='[Eau : Ressources et Risques] Contenu de l'UE >> Les documents de l'UE sont utiles')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Eau : Ressources et Risques] Contenu de l'UE >> Les documents de l'UE sont utiles
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST615/Question_6
# Data :  [Eau : Ressources et Risques] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# Tout à fait d'accord    6
# Plutôt d'accord         5
# Name: count, dtype: int64
# tabword  [False]
# LU3ST615 161 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='[Eau : Ressources et Risques] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Eau : Ressources et Risques] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST615/Question_7
# Data :  [Eau : Ressources et Risques] Contenu de l'UE >> * Vous êtes satisfait de l’évaluation des connaissances sous forme de contrôle continu
# Tout à fait d'accord    9
# Plutôt d'accord         2
# Name: count, dtype: int64
# tabword  [False]
# LU3ST615 161 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='[Eau : Ressources et Risques] Contenu de l'UE >> * Vous êtes satisfait de l’évaluation des connaissances sous forme de contrôle continu')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Eau : Ressources et Risques] Contenu de l'UE >> * Vous êtes satisfait de l’évaluation des connaissances sous forme de contrôle continu
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST615/Question_8
# Data :  * Qu'avez-vous pensé de la présentation de projets sous forme de classe inversée?
# Elle est plus facile à réaliser en fin d’UE\nElle vous a plu\nVous avez appris des choses nouvelles      5
# Elle vous a plu\nVous avez appris des choses nouvelles                                                   2
# Elle devrait être réalisée plus tôt dans l’UE\nElle vous a plu\nVous avez appris des choses nouvelles    1
# Elle est plus facile à réaliser en fin d’UE\nVous avez appris des choses nouvelles                       1
# Je n' ai pas été a ce cours et ne peux donc pas répondre à cette question (L4 en stage a Barles )        1
# Elle est plus facile à réaliser en fin d’UE                                                              1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST615 161 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Elle est plus facile à réaliser en fin d’UE\nElle vous a plu\nVous avez appris des choses nouvelles',
#        'Elle vous a plu\nVous avez appris des choses nouvelles',
#        'Elle devrait être réalisée plus tôt dans l’UE\nElle vous a plu\nVous avez appris des choses nouvelles',
#        'Elle est plus facile à réaliser en fin d’UE\nVous avez appris des choses nouvelles',
#        'Je n' ai pas été a ce cours et ne peux donc pas répondre à cette question (L4 en stage a Barles )',
#        'Elle est plus facile à réaliser en fin d’UE'],
#       dtype='object', name='* Qu'avez-vous pensé de la présentation de projets sous forme de classe inversée?')
# []
# * Qu'avez-vous pensé de la présentation de projets sous forme de classe inversée?
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST615/Question_9
# UE :  LU3ST621
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST621/
# path :  /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST621/
# True
# Data :  [Physique du globe] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés
# NON    2
# OUI    1
# Name: count, dtype: int64
# LU3ST621 176 ['OUI', 'NON'] Index(['NON', 'OUI'], dtype='object', name='[Physique du globe] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés')
# ['OUI', 'NON']
# [Physique du globe] Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST621/Question_0
# Data :  [Physique du globe] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris
# NON    2
# OUI    1
# Name: count, dtype: int64
# LU3ST621 176 ['OUI', 'NON'] Index(['NON', 'OUI'], dtype='object', name='[Physique du globe] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris')
# ['OUI', 'NON']
# [Physique du globe] Que diriez-vous des objectifs de l'UE? >> Vous les avez compris
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST621/Question_1
# Data :  [Physique du globe] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# Plutôt d'accord    3
# Name: count, dtype: int64
# tabword  [False]
# LU3ST621 176 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord'], dtype='object', name='[Physique du globe] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables')
# ["Plutôt d'accord"]
# [Physique du globe] Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST621/Question_2
# Data :  [Physique du globe] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# Plutôt d'accord         2
# Tout à fait d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST621 176 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord'], dtype='object', name='[Physique du globe] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# [Physique du globe] Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST621/Question_3
# Data :  [Physique du globe] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# Plutôt d'accord        2
# Plutôt pas d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST621 176 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='[Physique du globe] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE')
# ["Plutôt d'accord", "Plutôt pas d'accord"]
# [Physique du globe] Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST621/Question_4
# Data :  [Physique du globe] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# Plutôt pas d'accord     2
# Tout à fait d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST621 176 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt pas d'accord', 'Tout à fait d'accord'], dtype='object', name='[Physique du globe] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent')
# ["Tout à fait d'accord", "Plutôt pas d'accord"]
# [Physique du globe] Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST621/Question_5
# Data :  [Physique du globe] Contenu de l'UE >> Les documents de l'UE sont utiles
# Plutôt pas d'accord     2
# Tout à fait d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST621 176 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt pas d'accord', 'Tout à fait d'accord'], dtype='object', name='[Physique du globe] Contenu de l'UE >> Les documents de l'UE sont utiles')
# ["Tout à fait d'accord", "Plutôt pas d'accord"]
# [Physique du globe] Contenu de l'UE >> Les documents de l'UE sont utiles
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST621/Question_6
# Data :  [Physique du globe] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# Plutôt pas d'accord    2
# Plutôt d'accord        1
# Name: count, dtype: int64
# tabword  [False]
# LU3ST621 176 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt pas d'accord', 'Plutôt d'accord'], dtype='object', name='[Physique du globe] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante')
# ["Plutôt d'accord", "Plutôt pas d'accord"]
# [Physique du globe] Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST621/Question_7
# Data :  Les enseignements de cette UE vous ont intéressé.15
# 4.0    1
# 3.0    1
# 5.0    1
# Name: count, dtype: int64
# tabword  [True]
# LU3ST621 176 [1, 2, 3, 4, 5] Index([4.0, 3.0, 5.0], dtype='float64', name='Les enseignements de cette UE vous ont intéressé.15')
# [3, 4, 5]
# Les enseignements de cette UE vous ont intéressé (4.00/5)
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST621/Question_8
# Data :  Series([], Name: count, dtype: int64)
# tabword  [False]
# LU3ST621 176 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index([], dtype='float64', name='Avez-vous des commentaires à rajouter au sujet de cette UE?.13')
# []
# Avez-vous des commentaires à rajouter au sujet de cette UE?
# /home/fbrient/Dropbox/Enseignements/2023_2024/Resp_Eval/Resultats/S6/d_figures/LU3ST621/Question_9
