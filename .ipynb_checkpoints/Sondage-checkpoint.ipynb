# %%
import matplotlib as mpl
from matplotlib import cm
import matplotlib.pyplot as plt
import pylab as plt
import pandas as pd
import numpy as np
import os


def colorFader(c1,c2,mix=0): #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1=np.array(mpl.colors.to_rgb(c1))
    c2=np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)

def _savefig(fig,ax,name='',title='',fts=10,xsize=(10,10),zmax=None):
    plt.xticks(size=fts)
    plt.yticks(size=fts)
    plt.title(title)
    fig.set_size_inches(xsize)
    fig.savefig(name + '.png')#,dpi='figure')
    fig.savefig(name + '.pdf', dpi=1000)
    plt.close()
    
def func(pct, allvals):
    absolute = int(round(pct/100.*np.sum(allvals)))
    return "{:.1f}%\n({:d} r)".format(pct, absolute)

def _mkdir(path):
    print('path : ',path)
    print(os.path.exists(path))
    if not(os.path.exists(path)):
      os.mkdir(path)

Semestre = 6 #5 #1
Sem_ch   = str(Semestre)

#For S6 only
complementaire = True

#pathini = '/Users/florentbrient/'
pathini = '/home/fbrient/'
path    = pathini+'Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S'+Sem_ch+'/'

fileadd = []
file    = 'Responses_S'+Sem_ch+'_2021_2022.xlsx' #'Sondage UE Sciences de la Terre - Semestre '+str(Semestre)+'.csv'


#if Semestre == 4:
#  file  = 'Sondage UE Sciences de la Terre - Semestre '+str(Semestre)+' - v2.csv'
#elif Semestre == 5: 
#  fileadd   = []
  #fileadd   = 'Sondage UE Sciences de la Terre - Ressources.csv'
  #fileadd   = 'Sondage UE Sciences de la Terre - Océanographie.csv'
#  fileadd   = 'Sondage UE Sciences de la Terre - Biodiversité et Paléobiodiversité.csv'
   #[ 'Sondage UE Sciences de la Terre - Ressources.csv'
             #,'Sondage UE Sciences de la Terre - Océanographie.csv'
             #,'Sondage UE Sciences de la Terre - Biodiversité et Paléobiodiversité.csv']
if Semestre == 6 and complementaire: 
    file   = 'Responses_S'+Sem_ch+'_2021_2022_complementaires.xlsx'

suffix = ''
#if len(fileadd)>0:
#    suffix = '_'+fileadd.split(' ')[-1].split('.')[0] 
#    file   = fileadd
#print(file,fileadd,suffix)

file   = path+file
print('file : ',file)

pathfig0 = path #'/Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/'
pathfig  = pathfig0+'d_figures/'
_mkdir(pathfig)

#df1    = pd.read_csv(file)
df1    = pd.read_excel(file)
#print(type(df1))
if len(fileadd)>0:
    for tmp in fileadd:
        print(tmp)
        df_tmp = pd.read_excel(path+tmp)
        #print(df_tmp)
        df1 = pd.concat([df1,df_tmp], axis=1) #, sort=False )#ignore_index=True) #, sort=False)
#df_eng = pd.read_excel('translate_FR.xlsx', header=1,encoding='latin1')
#df_eng = df_eng.set_axis(df_fr.columns.values.tolist(),axis='columns')
#df     = df_fr.append(df_eng, ignore_index=True, sort=False)

df     = df1
#print(df)

questions=df.columns.values
print(questions)
# Out:
# file :  /home/fbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S6/Responses_S6_2021_2022.xlsx
# path :  /home/fbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S6/d_figures/
# True
# Responses_S6_2021_2022_complementaires.xlsx
# ['Horodateur' 'Quelle formation avez-vous suivi ?'
#  "Avez-vous suivi l'UE Approche Intégrée en Géosciences (AIG) (LU3ST613) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous ont été présentés]'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris]'
#  "Contenu de l'UE [Les séances sont bien adapté à vos connaissances et compétences préalables]"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS]"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE]"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.]"
#  'La cohérence et la progression des séances de cette UE vous paraissent-elles ?'
#  'Les documents de cette UE vous semblent : [Utiles]'
#  'Les documents de cette UE vous semblent : [En quantité adaptée]'
#  'Vous sentez-vous mieux préparé.e à l’analyse de documents variés?'
#  'Ce module vous a-t-il permis de mieux comprendre le lien existant entre disciplines ?'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?'
#  "Avez-vous suivi l'UE Stratigraphie (LU3ST609) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés]'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].1'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.]"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].1"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].1"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.].1"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?'
#  'Les documents de cette UE vous semblent : [Utiles].1'
#  'Les documents de cette UE vous semblent : [En quantité adaptée].1'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.1'
#  "Avez-vous suivi l'UE Géochimie Appliquée (LU3ST607) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].1'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].2'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].1"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].2"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].2"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.].2"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.1'
#  'Les documents de cette UE vous semblent : [Utiles].2'
#  'Les documents de cette UE vous semblent : [En quantité adaptée].2'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.2'
#  "Avez-vous suivi l'UE Pétrologie métamorphique (LU3ST605) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].2'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].3'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].2"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].3"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].3"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.].3"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.2'
#  'Les documents de cette UE vous semblent : [Utiles].3'
#  'Les documents de cette UE vous semblent : [En quantité adaptée].3'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.3'
#  "Avez-vous suivi l'UE Eau : Ressources et Risques (LU3ST604) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].3'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].4'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].3"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].4"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].4"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.].4"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.3'
#  'Les documents de cette UE vous semblent : [Utiles].4'
#  'Les documents de cette UE vous semblent : [En quantité adaptée].4'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.4'
#  "Avez-vous suivi l'UE Caractérisation des matériaux pour la géotechnique et la géophysique (LU3ST606) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].4'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].5'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].4"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].5"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].5"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.].5"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.4'
#  'Les documents de cette UE vous semblent : [Utiles].5'
#  'Les documents de cette UE vous semblent : [En quantité adaptée].5'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.5'
#  "Avez-vous suivi l'UE Magmas, Fluides et Volcans (LU3ST614) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].5'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].6'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].5"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].6"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].6"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.].6"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.5'
#  'Les documents de cette UE vous semblent : [Utiles].6'
#  'Les documents de cette UE vous semblent : [En quantité adaptée].6'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.6'
#  "Avez-vous suivi l'UE Géodynamique des bassins sédimentaires (LU3ST608) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].6'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].7'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].6"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].7"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].7"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.].7"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.6'
#  'Les documents de cette UE vous semblent : [Utiles].7'
#  'Les documents de cette UE vous semblent : [En quantité adaptée].7'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.7'
#  "Avez-vous suivi l'UE Physique du globe (LU3ST621) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].7'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].8'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].7"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].8"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].8"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.].8"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.7'
#  'Les documents de cette UE vous semblent : [Utiles].8'
#  'Les documents de cette UE vous semblent : [En quantité adaptée].8'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.8'
#  "Avez-vous suivi l'UE Stage Terrain L3 (LU3ST603) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].8'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].9'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].8"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].9"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].9"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.].9"
#  "Contenu de l'UE [L'organisation du stage s'est bien passé]"
#  "Le lien entre l'UE Stage Labo et les autres enseignements du semestre vous parait-t-il?"
#  'Quel stage terrain avez-vous suivi?'
#  'Quelles UE(s) vous a paru idéal pour suivre et apprécier le stage terrain?'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.9'
#  "Avez-vous une remarque sur l'ensemble du Semestre 6 de la licence Sciences de la Terre?"
#  'Horodateur' 'Quelle formation avez-vous suivi ?'
#  "Avez-vous suivi l'UE Biogéochimie Océan - Atmosphère (LU3ST061)?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous ont été présentés]'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris]'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables]"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS]"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE]"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.]"
#  'La cohérence et la répartition entre les enseignements (cours, TD, TP) de cette UE vous paraissent elles ?'
#  'Les documents de cette UE vous semblent : [Utiles]'
#  'Les documents de cette UE vous semblent : [En quantité adaptée]'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?'
#  "Avez-vous suivi l'UE Projet informatique (LU3ST063) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés]'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].1'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.]"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].1"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].1"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.].1"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?'
#  'Les documents de cette UE vous semblent : [Utiles].1'
#  'Les documents de cette UE vous semblent : [En quantité adaptée].1'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.1'
#  "Avez-vous suivi l'UE Développement des idées en géosciences (LU3ST068) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].1'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].2'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].1"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].2"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].2"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.].2"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.1'
#  'Les documents de cette UE vous semblent : [Utiles].2'
#  'Les documents de cette UE vous semblent : [En quantité adaptée].2'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.2'
#  "Avez-vous suivi l'UE Climats et Paléoclimats (LU3ST060) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].2'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].3'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].2"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].3"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].3"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.].3"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.2'
#  'Les documents de cette UE vous semblent : [Utiles].3'
#  'Les documents de cette UE vous semblent : [En quantité suffisante]'
#  'Les exercices fournis vous ont-ils semblé en quantité suffisante ?'
#  'Si vous deviez choisir entre davantage de TP ou davantage de TD encadrés “sur papier”, que choisiriez-vous ?'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.3'
#  "Avez-vous suivi l'UE Paléontologie & évolution (LU3ST066) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].3'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].4'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].3"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].4"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].4"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.].4"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.3'
#  'Les documents de cette UE vous semblent : [Utiles].4'
#  'Les documents de cette UE vous semblent : [En quantité adaptée].3'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.4'
#  "Avez-vous suivi l'UE Géophysique : Outils & Applications (LU3ST069) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].4'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].5'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].4"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].5"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].5"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.].5"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.4'
#  'Les documents de cette UE vous semblent : [Utiles].5'
#  'Les documents de cette UE vous semblent : [En quantité adaptée].4'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.5'
#  "Avez-vous suivi l'UE Stage Fablab (LU3ST602) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].5'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].6'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].5"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].6"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].6"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.].6"
#  "Le lien entre l'UE Stage Fablab et les autres enseignements du semestre vous parait-t-il?"
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.6'
#  "Avez-vous une remarque sur l'ensemble du Semestre 6 de la licence Sciences de la Terre?"]

# %%
# Formation

pies     = [1]
New_name = ['Formation?']

c1='#1f77b4' #blue
c2='red' #green
n=4
colors2 = [colorFader(c1,c2,x/2)for x in range(2)]
colors4 = [colorFader(c1,c2,x/4)for x in range(4)]

#print(df[questions[pies[0]]])
formation = df[questions[pies[0]]]#.squeeze(axis=1)
if len(formation.shape)>1:
    print(formation.shape)
    print(formation.iloc[:,[0]])
    formation=formation.iloc[:,[0]].squeeze()
print(formation.shape)

print(type(formation))
labels0 = formation.unique()
print(labels0)
#['Majeure' 'Mineure Geosciences' 'Monodisciplinaire Sciences de la Terre'
# 'Bi-disciplinaire : Biologie - Mineure Sciences de la Terre (MEEF)']
    

colors  = ['royalblue','red','gold','green','purple']
colors_save = colors

figsize = (8, 5)

for ij,nbpie in enumerate(pies): 
    fig, ax = plt.subplots(1,figsize=figsize)

    #data = df[questions[nbpie]].value_counts()#normalize=True)
    data = formation.value_counts()#normalize=True)
    print(data)
    for ik in data.index:
       data = data.rename(index={ik:ik.split(' ')[0]})
    print(data)
    
    labels  = data.index #[ij.split(' ')[0] for ij in labels0 if ij in data.index]  
    print(labels,data.index)#,dcolors)
    
        
    gcolors = dict()
    keys    = labels
    for ik,key in enumerate(keys):
        print(ik, key)
        gcolors[key]=colors[ik]
    print(gcolors)
    labels = [ik for ik in gcolors if ik in data.index]
    data   = data.reindex(labels)
    print(labels)
    
    wedges, texts, autotexts = ax.pie(data,labels=labels
                                  ,autopct=lambda pct: func(pct, data)
                                  ,colors=[gcolors[i] for i in data.index]
                                  ,textprops=dict(color="k"),startangle=90
                                  ,pctdistance=0.7, labeldistance=1.2
                                 )
    print(ax.xaxis.get_label())
    ax.legend(wedges, labels,
          loc="upper right",
          bbox_to_anchor=(1, 1, 0.5, -0.5))
          #title=questions[1],
    plt.setp(autotexts, size=10, weight="bold")

    title = New_name[ij]
    ax.set_title(title)
    
    name_file = pathfig+title.split('?')[0]+'_Semestre'+Sem_ch+suffix
    print(title,name_file)
#plt.show()
    _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# (27, 2)
#         Quelle formation avez-vous suivi ?
# 0                                  Mineure
# 1                           Double Majeure
# 2                                  Majeure
# 3                           Double Majeure
# 4   Monodisciplinaire Sciences de la Terre
# 5   Monodisciplinaire Sciences de la Terre
# 6                           Double Majeure
# 7   Monodisciplinaire Sciences de la Terre
# 8   Monodisciplinaire Sciences de la Terre
# 9   Monodisciplinaire Sciences de la Terre
# 10  Monodisciplinaire Sciences de la Terre
# 11                                 Majeure
# 12                                 Majeure
# 13                                      L4
# 14  Monodisciplinaire Sciences de la Terre
# 15  Monodisciplinaire Sciences de la Terre
# 16                                 Mineure
# 17  Monodisciplinaire Sciences de la Terre
# 18  Monodisciplinaire Sciences de la Terre
# 19  Monodisciplinaire Sciences de la Terre
# 20  Monodisciplinaire Sciences de la Terre
# 21                                 Majeure
# 22                                 Mineure
# 23  Monodisciplinaire Sciences de la Terre
# 24                          Double Majeure
# 25                                 Majeure
# 26  Monodisciplinaire Sciences de la Terre
# (27,)
# <class 'pandas.core.series.Series'>
# ['Mineure' 'Double Majeure' 'Majeure'
#  'Monodisciplinaire Sciences de la Terre' 'L4']
# Monodisciplinaire Sciences de la Terre    14
# Majeure                                    5
# Double Majeure                             4
# Mineure                                    3
# L4                                         1
# Name: Quelle formation avez-vous suivi ?, dtype: int64
# Monodisciplinaire    14
# Majeure               5
# Double                4
# Mineure               3
# L4                    1
# Name: Quelle formation avez-vous suivi ?, dtype: int64
# Index(['Monodisciplinaire', 'Majeure', 'Double', 'Mineure', 'L4'], dtype='object') Index(['Monodisciplinaire', 'Majeure', 'Double', 'Mineure', 'L4'], dtype='object')
# 0 Monodisciplinaire
# 1 Majeure
# 2 Double
# 3 Mineure
# 4 L4
# {'Monodisciplinaire': 'royalblue', 'Majeure': 'red', 'Double': 'gold', 'Mineure': 'green', 'L4': 'purple'}
# ['Monodisciplinaire', 'Majeure', 'Double', 'Mineure', 'L4']
# Text(0.5, 0, '')
# Formation? /home/fbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S6/d_figures/Formation_Semestre6

# %%
#Find UEs
UEs = [(ij,question.replace(' ?','').split(' ')[-1]) for ij,question in enumerate(questions) if 'Avez-vous suivi' in question]
print(UEs)

# Make a selection (Subset of the poll)
#said_yes = df[df[questions[2]] == 'Oui']
#print(questions[5],said_yes)

subset = False
if subset:
  # Impose this selection
    pathfig = pathfig+'d_subset/'
    df      = said_yes
# Out:
# [(2, '(LU3ST613)'), (15, '(LU3ST609)'), (26, '(LU3ST607)'), (37, '(LU3ST605)'), (48, '(LU3ST604)'), (59, '(LU3ST606)'), (70, '(LU3ST614)'), (81, '(LU3ST608)'), (92, '(LU3ST621)'), (103, '(LU3ST603)'), (118, '(LU3ST061)?'), (129, '(LU3ST063)'), (140, '(LU3ST068)'), (151, '(LU3ST060)'), (164, '(LU3ST066)'), (175, '(LU3ST069)'), (186, '(LU3ST602)')]

# %%
UE_idx   = [ij[0] for ij in UEs] #[1,2,3,4,5,6,8,17,18]
UE_names = [ij[1].strip("()?") for ij in UEs] #['Profession?', 'Permanent?', 'Site?', 'Climaction?','Stratégie?','Quel objectif?',
            #'Individuel ou collectif?','Calculateur?','Influence recherche?'].replace('(','').replace(')','')

print(UE_idx,UE_names)
#colors2 = ['red', 'blue']
#a       = np.random.random(4)
#cs      = cm.Set1(np.arange(4)/4.)

keys1 = ['Oui','Non']
keys2 = ['Tout à fait d\'accord','Plutôt d\'accord','Plutôt pas d\'accord','Pas du tout d\'accord']

# Changing key for specific question
Idx_change = [9]
tabword = ['cohérence','lien entre']
keys3 = ['Bonne','Plutôt bonne','Plutôt mauvaise','Mauvaise']

# Changing answers for specific question
UE_change  = ['LU2ST034','LU2ST303','LU2ST044','LU2ST402','LU3ST603','LU3ST602']
keys4 = ['Très clair','Assez clair','Assez flou','Très flou']

# Changing answers for S1
tabword2 = ['capsules']
keys5 = ['Oui, beaucoup (> 10 vidéos)','Oui, certaines (5-10 vidéos)',\
'Quelques unes (1-4 vidéos)','Non, mais je sais qu\'elles existaient',\
'Non, car je ne savais pas qu\'il y avait des capsules vidéos de soutien']
tabword3 = ['Ces vidéos']
keys6 = ['Oui, le plus souvent','Oui, certaines',\
         'Non, même si je les ai visionnées','Non, car pas visionnées']

# Changing answers for S6
tabword4 = ['Vous sentez-vous','lien existant entre disciplines']
keys7 = ['Oui','Pas d\'avis','Non']

#keys6 = ['Oui, beaucoup (> 10 vidéos)','Oui, certaines (5-10 vidéos)',\
#'Quelques unes (1-4 vidéos)','Non, mais je sais qu\'elles existaient',\
#'Non, car je ne savais pas qu\'il y avait des capsules vidéos de soutien']

print(tabword)
#c1 = '#1f77b4' #blue
#c2 = 'red' #green
#colors2 = [colorFader(c1,c2,x/2)for x in range(2)]
#colors4 = [colorFader(c1,c2,x/4)for x in range(4)]

# 12 questions !
Nb_questions = 10 #(UE_idx[1]-UE_idx[0])-1
if Semestre == 1:
    Nb_questions = 19
if Semestre == 6:
    Nb_questions = 13
print(Nb_questions)

figsize = (8, 5)

#UE_idx=[UE_idx[ij] for ij in range(len(UE_idx)) if UE_names[ij]=='LU2ST045']
#print(UE_idx)

for ij,idx in enumerate(UE_idx):
    UE = UE_names[ij]
    print('UE : ',UE)
    
    path_file = pathfig+UE+'/'
    print(path_file)
    _mkdir(path_file)
    
    for ik in range(Nb_questions):
      fig, ax = plt.subplots(1,figsize=figsize)

      data = df[questions[idx+ik]]
       
      #data = data.replace('’','\'')
      data = data.replace('Tout à fait d’accord','Tout à fait d\'accord')
      data = data.replace('Plutôt pas d’accord','Plutôt pas d\'accord')
      #data = data.replace('d’accord','d\'accord')
      data = data.replace('è','\'e')
      #data = data.replace('Très','Tr\'es')
      print(ik,data)
      data = data.value_counts() #normalize=True) 
                
      #colors = colors2 ; 
      changecolor = 0
      keys = keys1
      if ('Oui' in data.keys()):
        keys = keys1
      else:
        keys = keys2
        #if ik in Idx_change:
        if any([ii in questions[idx+ik] for ii in tabword]):
        #if 'cohérence' in questions[idx+ik]:
            keys = keys3
            if UE in UE_change:
                keys = keys4
        elif any([ii in questions[idx+ik] for ii in tabword2]):
            keys = keys5
        elif any([ii in questions[idx+ik] for ii in tabword3]):
            keys = keys6
      if any([ii in questions[idx+ik] for ii in tabword4]):
            keys = keys7
      print(UE,idx,keys,data.index)
    
      cmap = plt.cm.bwr
      colors = cmap(np.linspace(0., 0.95, len(keys)))
      #if changecolor:
      #    colors = colors_save 
  
          
    
      gcolors=dict()
      for ij,key in enumerate(keys):
        gcolors[key]=colors[ij]
      labels = [ij for ij in gcolors if ij in data.index]
      data   = data.reindex(labels)
      print(labels)
        
      wedges, texts, autotexts = ax.pie(data,autopct=lambda pct: func(pct, data)\
                                            ,colors=[gcolors[i] for i in data.index]\
                                            ,textprops=dict(color="w") #, colors=color
                                            ,startangle=0)
    
      ax.legend(wedges, data.index,loc="best",bbox_to_anchor=(1, 1, 0.5, -0.5))
      plt.setp(autotexts, size=10, weight="bold")
    
      title = questions[idx+ik].split('.')[0]
      ax.set_title(title)
      print(title)
    
      name_file = 'Question_'+str(ik)
      name_file = path_file + name_file
      print(name_file)
      _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# [2, 15, 26, 37, 48, 59, 70, 81, 92, 103, 118, 129, 140, 151, 164, 175, 186] ['LU3ST613', 'LU3ST609', 'LU3ST607', 'LU3ST605', 'LU3ST604', 'LU3ST606', 'LU3ST614', 'LU3ST608', 'LU3ST621', 'LU3ST603', 'LU3ST061', 'LU3ST063', 'LU3ST068', 'LU3ST060', 'LU3ST066', 'LU3ST069', 'LU3ST602']
# ['cohérence', 'lien entre']
# 13
# UE :  LU3ST613
# /home/fbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S6/d_figures/LU3ST613/
# path :  /home/fbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S6/d_figures/LU3ST613/
# True
# 0 0     Non
# 1     Non
# 2     Oui
# 3     Non
# 4     Non
# 5     Oui
# 6     Oui
# 7     Non
# 8     Oui
# 9     Oui
# 10    Oui
# 11    Oui
# 12    Oui
# 13    Non
# 14    Oui
# 15    Oui
# 16    Non
# 17    Oui
# 18    Oui
# 19    Oui
# 20    Oui
# 21    Non
# 22    Non
# 23    Oui
# 24    Non
# 25    Oui
# 26    Oui
# Name: Avez-vous suivi l'UE Approche Intégrée en Géosciences (AIG) (LU3ST613) ?, dtype: object
# LU3ST613 2 ['Oui', 'Non'] Index(['Oui', 'Non'], dtype='object')
# ['Oui', 'Non']
# Avez-vous suivi l'UE Approche Intégrée en Géosciences (AIG) (LU3ST613) ?
# /home/fbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S6/d_figures/LU3ST613/Question_0
# 1    Que diriez-vous des objectifs de cette UE ? [Ils vous ont été présentés]  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 Oui
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 Oui
# 6                                                 Oui
# 7                                                 NaN
# 8                                                 Oui
# 9                                                 Oui
# 10                                                Non
# 11                                                Oui
# 12                                                Oui
# 13                                                NaN
# 14                                                Oui
# 15                                                Oui
# 16                                                NaN
# 17                                                Oui
# 18                                                Oui
# 19                                                Oui
# 20                                                Oui
# 21                                                NaN
# 22                                                NaN
# 23                                                Oui
# 24                                                NaN
# 25                                                Oui
# 26                                                Oui
#
#    Que diriez-vous des objectifs de cette UE ? [Ils vous ont été présentés]
# 0                                                 Oui
# 1                                                 NaN
# 2                                                 Oui
# 3                                                 Oui
# 4                                                 NaN
# 5                                                 Oui
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                Oui
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-2be1ec473862> in <module>
#      76       #data = data.replace('Très','Tr\'es')
#      77       print(ik,data)
# ---> 78       data = data.value_counts() #normalize=True)
#      79
#      80       #colors = colors2 ;
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in value_counts(self, subset, normalize, sort, ascending)
#    5673             subset = self.columns.tolist()
#    5674
# -> 5675         counts = self.groupby(subset).grouper.size()
#    5676
#    5677         if sort:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     826         # allow us to passing the actual Grouping as the gpr
#     827         ping = (
# --> 828             Grouping(
#     829                 group_axis,
#     830                 gpr,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis, dropna)
#     541                 if getattr(self.grouper, "ndim", 1) != 1:
#     542                     t = self.name or str(type(self.grouper))
# --> 543                     raise ValueError(f"Grouper for '{t}' not 1-dimensional")
#     544                 self.grouper = self.index.map(self.grouper)
#     545                 if not (
#
# ValueError: Grouper for 'Que diriez-vous des objectifs de cette UE ? [Ils vous ont été présentés]' not 1-dimensional
