# %%
import matplotlib as mpl
from matplotlib import cm
import matplotlib.pyplot as plt
import pylab as plt
import pandas as pd
import numpy as np
import os


def colorFader(c1,c2,mix=0): #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1=np.array(mpl.colors.to_rgb(c1))
    c2=np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)

def _savefig(fig,ax,name='',title='',fts=10,xsize=(10,10),zmax=None):
    plt.xticks(size=fts)
    plt.yticks(size=fts)
    plt.title(title)
    fig.set_size_inches(xsize)
    fig.savefig(name + '.png')#,dpi='figure')
    fig.savefig(name + '.pdf', dpi=1000)
    plt.close()
    
def func(pct, allvals):
    absolute = int(round(pct/100.*np.sum(allvals)))
    return "{:.1f}%\n({:d} r)".format(pct, absolute)

def _mkdir(path):
    print('path : ',path)
    print(os.path.exists(path))
    if not(os.path.exists(path)):
      os.mkdir(path)

Semestre = 1 #5 #1
Sem_ch   = str(Semestre)

path   = '/Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S'+Sem_ch+'/'

fileadd = []
file    = 'Responses_S'+Sem_ch+'_2021_2022.xlsx' #'Sondage UE Sciences de la Terre - Semestre '+str(Semestre)+'.csv'

#if Semestre == 4:
#  file  = 'Sondage UE Sciences de la Terre - Semestre '+str(Semestre)+' - v2.csv'
#elif Semestre == 5: 
#  fileadd   = []
  #fileadd   = 'Sondage UE Sciences de la Terre - Ressources.csv'
  #fileadd   = 'Sondage UE Sciences de la Terre - Océanographie.csv'
#  fileadd   = 'Sondage UE Sciences de la Terre - Biodiversité et Paléobiodiversité.csv'
   #[ 'Sondage UE Sciences de la Terre - Ressources.csv'
             #,'Sondage UE Sciences de la Terre - Océanographie.csv'
             #,'Sondage UE Sciences de la Terre - Biodiversité et Paléobiodiversité.csv']
#elif Semestre == 6: 
#  fileadd   = 'Sondage UE Sciences de la Terre - Semestre 6 - Complementaires.csv'

suffix = ''
#if len(fileadd)>0:
#    suffix = '_'+fileadd.split(' ')[-1].split('.')[0] 
#    file   = fileadd
#print(file,fileadd,suffix)

file   = path+file
print('file : ',file)

pathfig0 = path #'/Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/'
pathfig  = pathfig0+'d_figures/'
_mkdir(pathfig)

#df1    = pd.read_csv(file)
df1    = pd.read_excel(file)
#print(type(df1))
#if len(fileadd)>0:
#    for tmp in fileadd:
#        df_tmp = pd.read_csv(path+tmp)
#        #print(df_tmp)
#        df1 = pd.concat([df1,df_tmp], axis=1) #, ignore_index=True, sort=False)

#df_eng = pd.read_excel('translate_FR.xlsx', header=1,encoding='latin1')
#df_eng = df_eng.set_axis(df_fr.columns.values.tolist(),axis='columns')
#df     = df_fr.append(df_eng, ignore_index=True, sort=False)

df     = df1
#print(df)

questions=df.columns.values
print(questions)
# Out:
# file :  /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/Responses_S1_2021_2022.xlsx
# path :  /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/
# True
# ['Horodateur'
#  "Avez-vous suivi l'UE Terre Climat Environnement (LU1ST021) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous ont été présentés]'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris]'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables]"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS]"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE]"
#  "Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.]"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?'
#  'Avez-vous visionné les capsules vidéos de soutien à certains cours ?'
#  'Ces vidéos vous ont-elles été utiles?'
#  'Les documents de cette UE vous semblent : [Utiles]'
#  'Les documents de cette UE vous semblent : [En quantité adaptée]'
#  'La présentation orale sur les énergies vous semble [Intéressante]'
#  'La présentation orale sur les énergies vous semble [Utile]'
#  'La présentation orale sur les énergies vous semble [Chronophage]'
#  'Le premier TD  comprenant les jeux "Fresque du Climat" et "Inventons nos vie Bas Carbone" vous semble [Instructif]'
#  'Le premier TD  comprenant les jeux "Fresque du Climat" et "Inventons nos vie Bas Carbone" vous semble [Utile]'
#  'Le premier TD  comprenant les jeux "Fresque du Climat" et "Inventons nos vie Bas Carbone" vous semble [Intéressant]'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?'
#  "Avez-vous une remarque sur l'ensemble du Semestre 1 de la licence Sciences de la Terre?"]
# /anaconda3/lib/python3.7/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
# Formation

pies     = [1]
New_name = ['Formation?']

c1='#1f77b4' #blue
c2='red' #green
n=4
colors2 = [colorFader(c1,c2,x/2)for x in range(2)]
colors4 = [colorFader(c1,c2,x/4)for x in range(4)]

formation = df[questions[pies[0]]]

labels0 = formation.unique()
print(labels0)
#['Majeure' 'Mineure Geosciences' 'Monodisciplinaire Sciences de la Terre'
# 'Bi-disciplinaire : Biologie - Mineure Sciences de la Terre (MEEF)']
    

colors  = ['royalblue','red','gold','green','purple']
colors_save = colors

figsize = (8, 5)

for ij,nbpie in enumerate(pies): 
    fig, ax = plt.subplots(1,figsize=figsize)

    data = df[questions[nbpie]].value_counts()#normalize=True)
    print(data)
    for ik in data.index:
       data = data.rename(index={ik:ik.split(' ')[0]})
    print(data)
    
    labels  = data.index #[ij.split(' ')[0] for ij in labels0 if ij in data.index]  
    print(labels,data.index)#,dcolors)
    
        
    gcolors = dict()
    keys    = labels
    for ik,key in enumerate(keys):
        print(ik, key)
        gcolors[key]=colors[ik]
    print(gcolors)
    labels = [ik for ik in gcolors if ik in data.index]
    data   = data.reindex(labels)
    print(labels)
    
    wedges, texts, autotexts = ax.pie(data,labels=labels
                                  ,autopct=lambda pct: func(pct, data)
                                  ,colors=[gcolors[i] for i in data.index]
                                  ,textprops=dict(color="k"),startangle=90
                                  ,pctdistance=0.7, labeldistance=1.2
                                 )
    print(ax.xaxis.get_label())
    ax.legend(wedges, labels,
          loc="upper right",
          bbox_to_anchor=(1, 1, 0.5, -0.5))
          #title=questions[1],
    plt.setp(autotexts, size=10, weight="bold")

    title = New_name[ij]
    ax.set_title(title)
    
    name_file = pathfig+title.split('?')[0]+'_Semestre'+Sem_ch+suffix
    print(title,name_file)
#plt.show()
    _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# [nan 'Oui' 'Non']
# Oui    199
# Non      2
# Name: Avez-vous suivi l'UE Terre Climat Environnement (LU1ST021) ?, dtype: int64
# Oui    199
# Non      2
# Name: Avez-vous suivi l'UE Terre Climat Environnement (LU1ST021) ?, dtype: int64
# Index(['Oui', 'Non'], dtype='object') Index(['Oui', 'Non'], dtype='object')
# 0 Oui
# 1 Non
# {'Oui': 'royalblue', 'Non': 'red'}
# ['Oui', 'Non']
# Text(0.5, 0, '')
# Formation? /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/Formation_Semestre1

# %%
#Find UEs
UEs = [(ij,question.replace(' ?','').split(' ')[-1]) for ij,question in enumerate(questions) if 'Avez-vous suivi' in question]
print(UEs)

# Make a selection (Subset of the poll)
#said_yes = df[df[questions[2]] == 'Oui']
#print(questions[5],said_yes)

subset = False
if subset:
  # Impose this selection
    pathfig = pathfig+'d_subset/'
    df      = said_yes
# Out:
# [(1, '(LU1ST021)')]

# %%
UE_idx   = [ij[0] for ij in UEs] #[1,2,3,4,5,6,8,17,18]
UE_names = [ij[1].strip("()?") for ij in UEs] #['Profession?', 'Permanent?', 'Site?', 'Climaction?','Stratégie?','Quel objectif?',
            #'Individuel ou collectif?','Calculateur?','Influence recherche?'].replace('(','').replace(')','')

print(UE_idx,UE_names)
#colors2 = ['red', 'blue']
#a       = np.random.random(4)
#cs      = cm.Set1(np.arange(4)/4.)

keys1 = ['Oui','Non']
keys2 = ['Tout à fait d\'accord','Plutôt d\'accord','Plutôt pas d\'accord','Pas du tout d\'accord']

# Changing key for specific question
Idx_change = [9]
tabword = ['cohérence','lien entre']
keys3 = ['Bonne','Plutôt bonne','Plutôt mauvaise','Mauvaise']

# Changing answers for specific question
UE_change  = ['LU2ST034','LU2ST303','LU2ST044','LU2ST402','LU3ST603','LU3ST602']
keys4 = ['Très clair','Assez clair','Assez flou','Très flou']

# Changing answers for S1
tabword2 = ['capsules']
keys5 = ['Oui, beaucoup (> 10 vidéos)','Oui, certaines (5-10 vidéos)',\
'Quelques unes (1-4 vidéos)','Non, mais je sais qu\'elles existaient',\
'Non, car je ne savais pas qu\'il y avait des capsules vidéos de soutien']
tabword3 = ['Ces vidéos']
keys6 = ['Oui, le plus souvent','Oui, certaines',\
         'Non, même si je les ai visionnées','Non, car pas visionnées']


#keys6 = ['Oui, beaucoup (> 10 vidéos)','Oui, certaines (5-10 vidéos)',\
#'Quelques unes (1-4 vidéos)','Non, mais je sais qu\'elles existaient',\
#'Non, car je ne savais pas qu\'il y avait des capsules vidéos de soutien']

print(tabword)
#c1 = '#1f77b4' #blue
#c2 = 'red' #green
#colors2 = [colorFader(c1,c2,x/2)for x in range(2)]
#colors4 = [colorFader(c1,c2,x/4)for x in range(4)]

# 12 questions !
Nb_questions = 10 #(UE_idx[1]-UE_idx[0])-1
if Semestre == 1:
    Nb_questions = 19
print(Nb_questions)

figsize = (8, 5)

#UE_idx=[UE_idx[ij] for ij in range(len(UE_idx)) if UE_names[ij]=='LU2ST045']
#print(UE_idx)

for ij,idx in enumerate(UE_idx):
    UE = UE_names[ij]
    print('UE : ',UE)
    
    path_file = pathfig+UE+'/'
    print(path_file)
    _mkdir(path_file)
    
    for ik in range(Nb_questions):
      fig, ax = plt.subplots(1,figsize=figsize)

      data = df[questions[idx+ik]]
       
      #data = data.replace('’','\'')
      data = data.replace('Tout à fait d’accord','Tout à fait d\'accord')
      data = data.replace('Plutôt pas d’accord','Plutôt pas d\'accord')
      #data = data.replace('d’accord','d\'accord')
      data = data.replace('è','\'e')
      #data = data.replace('Très','Tr\'es')
      print(data)
      data = data.value_counts() #normalize=True) 
                
      #colors = colors2 ; 
      changecolor = 0
      keys = keys1
      if ('Oui' in data.keys()):
        keys = keys1
      else:
        keys = keys2
        #if ik in Idx_change:
        if any([ii in questions[idx+ik] for ii in tabword]):
        #if 'cohérence' in questions[idx+ik]:
            keys = keys3
            if UE in UE_change:
                keys = keys4
        elif any([ii in questions[idx+ik] for ii in tabword2]):
            keys = keys5
        elif any([ii in questions[idx+ik] for ii in tabword3]):
            keys = keys6
      print(UE,idx,keys,data.index)
    
      cmap = plt.cm.bwr
      colors = cmap(np.linspace(0., 0.95, len(keys)))
      #if changecolor:
      #    colors = colors_save 
  
          
    
      gcolors=dict()
      for ij,key in enumerate(keys):
        gcolors[key]=colors[ij]
      labels = [ij for ij in gcolors if ij in data.index]
      data   = data.reindex(labels)
      print(labels)
        
      wedges, texts, autotexts = ax.pie(data,autopct=lambda pct: func(pct, data)\
                                            ,colors=[gcolors[i] for i in data.index]\
                                            ,textprops=dict(color="w") #, colors=color
                                            ,startangle=0)
    
      ax.legend(wedges, data.index,loc="best",bbox_to_anchor=(1, 1, 0.5, -0.5))
      plt.setp(autotexts, size=10, weight="bold")
    
      title = questions[idx+ik].split('.')[0]
      ax.set_title(title)
      print(title)
    
      name_file = 'Question_'+str(ik)
      name_file = path_file + name_file
      print(name_file)
      _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# [1] ['LU1ST021']
# ['cohérence', 'lien entre']
# 16
# UE :  LU1ST021
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/
# path :  /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/
# True
# 0      NaN
# 1      NaN
# 2      Oui
# 3      Oui
# 4      Oui
#       ...
# 198    Oui
# 199    Oui
# 200    Oui
# 201    Non
# 202    Oui
# Name: Avez-vous suivi l'UE Terre Climat Environnement (LU1ST021) ?, Length: 203, dtype: object
# LU1ST021 1 ['Oui', 'Non'] Index(['Oui', 'Non'], dtype='object')
# ['Oui', 'Non']
# Avez-vous suivi l'UE Terre Climat Environnement (LU1ST021) ?
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/Question_0
# 0      NaN
# 1      NaN
# 2      Oui
# 3      Oui
# 4      Oui
#       ...
# 198    Non
# 199    Oui
# 200    Non
# 201    NaN
# 202    Oui
# Name: Que diriez-vous des objectifs de cette UE ? [Ils vous ont été présentés], Length: 203, dtype: object
# LU1ST021 1 ['Oui', 'Non'] Index(['Oui', 'Non'], dtype='object')
# ['Oui', 'Non']
# Que diriez-vous des objectifs de cette UE ? [Ils vous ont été présentés]
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/Question_1
# 0      NaN
# 1      NaN
# 2      Oui
# 3      Non
# 4      Oui
#       ...
# 198    Non
# 199    Oui
# 200    Non
# 201    NaN
# 202    Oui
# Name: Que diriez-vous des objectifs de cette UE ? [Vous les avez compris], Length: 203, dtype: object
# LU1ST021 1 ['Oui', 'Non'] Index(['Oui', 'Non'], dtype='object')
# ['Oui', 'Non']
# Que diriez-vous des objectifs de cette UE ? [Vous les avez compris]
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/Question_2
# 0                       NaN
# 1                       NaN
# 2       Plutôt pas d'accord
# 3       Plutôt pas d'accord
# 4           Plutôt d'accord
#                ...
# 198         Plutôt d'accord
# 199    Tout à fait d'accord
# 200     Plutôt pas d'accord
# 201                     NaN
# 202         Plutôt d'accord
# Name: Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables], Length: 203, dtype: object
# LU1ST021 1 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord', 'Plutôt pas d'accord',
#        'Pas du tout d'accord'],
#       dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables]
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/Question_3
# 0                       NaN
# 1                       NaN
# 2      Tout à fait d'accord
# 3       Plutôt pas d'accord
# 4           Plutôt d'accord
#                ...
# 198     Plutôt pas d'accord
# 199    Tout à fait d'accord
# 200     Plutôt pas d'accord
# 201                     NaN
# 202         Plutôt d'accord
# Name: Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS], Length: 203, dtype: object
# LU1ST021 1 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord', 'Plutôt pas d'accord',
#        'Pas du tout d'accord'],
#       dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS]
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/Question_4
# 0                       NaN
# 1                       NaN
# 2           Plutôt d'accord
# 3           Plutôt d'accord
# 4      Tout à fait d'accord
#                ...
# 198         Plutôt d'accord
# 199    Tout à fait d'accord
# 200    Pas du tout d'accord
# 201                     NaN
# 202         Plutôt d'accord
# Name: Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE], Length: 203, dtype: object
# LU1ST021 1 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord', 'Plutôt pas d'accord',
#        'Pas du tout d'accord'],
#       dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE]
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/Question_5
# 0                       NaN
# 1                       NaN
# 2           Plutôt d'accord
# 3           Plutôt d'accord
# 4           Plutôt d'accord
#                ...
# 198         Plutôt d'accord
# 199    Tout à fait d'accord
# 200     Plutôt pas d'accord
# 201                     NaN
# 202         Plutôt d'accord
# Name: Contenu de l'UE [Les enseignements de cette UE vous ont intéressé.], Length: 203, dtype: object
# LU1ST021 1 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Plutôt pas d'accord', 'Tout à fait d'accord',
#        'Pas du tout d'accord'],
#       dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE [Les enseignements de cette UE vous ont intéressé
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/Question_6
# 0                  NaN
# 1                  NaN
# 2         Plutôt bonne
# 3         Plutôt bonne
# 4         Plutôt bonne
#             ...
# 198       Plutôt bonne
# 199              Bonne
# 200    Plutôt mauvaise
# 201                NaN
# 202       Plutôt bonne
# Name: La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?, Length: 203, dtype: object
# LU1ST021 1 ['Bonne', 'Plutôt bonne', 'Plutôt mauvaise', 'Mauvaise'] Index(['Plutôt bonne', 'Bonne', 'Plutôt mauvaise', 'Mauvaise'], dtype='object')
# ['Bonne', 'Plutôt bonne', 'Plutôt mauvaise', 'Mauvaise']
# La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/Question_7
# 0                                                    NaN
# 1                                                    NaN
# 2                           Oui, certaines (5-10 vidéos)
# 3      Non, car je ne savais pas qu'il y avait des ca...
# 4                           Oui, certaines (5-10 vidéos)
#                              ...
# 198                           Quelques unes (1-4 vidéos)
# 199                         Oui, certaines (5-10 vidéos)
# 200    Non, car je ne savais pas qu'il y avait des ca...
# 201                                                  NaN
# 202                          Oui, beaucoup (> 10 vidéos)
# Name: Avez-vous visionné les capsules vidéos de soutien à certains cours ?, Length: 203, dtype: object
# LU1ST021 1 ['Oui, beaucoup (> 10 vidéos)', 'Oui, certaines (5-10 vidéos)', 'Quelques unes (1-4 vidéos)', "Non, mais je sais qu'elles existaient", "Non, car je ne savais pas qu'il y avait des capsules vidéos de soutien"] Index(['Quelques unes (1-4 vidéos)',
#        'Non, car je ne savais pas qu'il y avait des capsules vidéos de soutien',
#        'Oui, certaines (5-10 vidéos)', 'Non, mais je sais qu'elles existaient',
#        'Oui, beaucoup (> 10 vidéos)'],
#       dtype='object')
# ['Oui, beaucoup (> 10 vidéos)', 'Oui, certaines (5-10 vidéos)', 'Quelques unes (1-4 vidéos)', "Non, mais je sais qu'elles existaient", "Non, car je ne savais pas qu'il y avait des capsules vidéos de soutien"]
# Avez-vous visionné les capsules vidéos de soutien à certains cours ?
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/Question_8
# 0                          NaN
# 1                          NaN
# 2               Oui, certaines
# 3      Non, car pas visionnées
# 4               Oui, certaines
#                 ...
# 198             Oui, certaines
# 199       Oui, le plus souvent
# 200    Non, car pas visionnées
# 201                        NaN
# 202       Oui, le plus souvent
# Name: Ces vidéos vous ont-elles été utiles?, Length: 203, dtype: object
# LU1ST021 1 ['Oui, le plus souvent', 'Oui, certaines', 'Non, même si je les ai visionnées', 'Non, car pas visionnées'] Index(['Non, car pas visionnées', 'Oui, le plus souvent', 'Oui, certaines',
#        'Non, même si je les ai visionnées'],
#       dtype='object')
# ['Oui, le plus souvent', 'Oui, certaines', 'Non, même si je les ai visionnées', 'Non, car pas visionnées']
# Ces vidéos vous ont-elles été utiles?
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/Question_9
# 0                       NaN
# 1                       NaN
# 2      Tout à fait d'accord
# 3           Plutôt d'accord
# 4      Tout à fait d'accord
#                ...
# 198     Plutôt pas d'accord
# 199    Tout à fait d'accord
# 200         Plutôt d'accord
# 201                     NaN
# 202         Plutôt d'accord
# Name: Les documents de cette UE vous semblent : [Utiles], Length: 203, dtype: object
# LU1ST021 1 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord', 'Plutôt pas d'accord',
#        'Pas du tout d'accord'],
#       dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Les documents de cette UE vous semblent : [Utiles]
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/Question_10
# 0                       NaN
# 1                       NaN
# 2       Plutôt pas d'accord
# 3           Plutôt d'accord
# 4           Plutôt d'accord
#                ...
# 198     Plutôt pas d'accord
# 199    Tout à fait d'accord
# 200     Plutôt pas d'accord
# 201                     NaN
# 202         Plutôt d'accord
# Name: Les documents de cette UE vous semblent : [En quantité adaptée], Length: 203, dtype: object
# LU1ST021 1 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Plutôt pas d'accord', 'Tout à fait d'accord',
#        'Pas du tout d'accord'],
#       dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Les documents de cette UE vous semblent : [En quantité adaptée]
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/Question_11
# 0                       NaN
# 1                       NaN
# 2      Tout à fait d'accord
# 3           Plutôt d'accord
# 4      Tout à fait d'accord
#                ...
# 198         Plutôt d'accord
# 199    Tout à fait d'accord
# 200         Plutôt d'accord
# 201                     NaN
# 202         Plutôt d'accord
# Name: La présentation orale sur les énergies vous semble [Intéressante], Length: 203, dtype: object
# LU1ST021 1 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord',
#        'Pas du tout d'accord'],
#       dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# La présentation orale sur les énergies vous semble [Intéressante]
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/Question_12
# 0                       NaN
# 1                       NaN
# 2      Tout à fait d'accord
# 3           Plutôt d'accord
# 4      Tout à fait d'accord
#                ...
# 198     Plutôt pas d'accord
# 199    Tout à fait d'accord
# 200     Plutôt pas d'accord
# 201                     NaN
# 202     Plutôt pas d'accord
# Name: La présentation orale sur les énergies vous semble [Utile], Length: 203, dtype: object
# LU1ST021 1 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord', 'Plutôt pas d'accord',
#        'Pas du tout d'accord'],
#       dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# La présentation orale sur les énergies vous semble [Utile]
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/Question_13
# 0                       NaN
# 1                       NaN
# 2       Plutôt pas d'accord
# 3       Plutôt pas d'accord
# 4      Tout à fait d'accord
#                ...
# 198     Plutôt pas d'accord
# 199     Plutôt pas d'accord
# 200    Pas du tout d'accord
# 201                     NaN
# 202         Plutôt d'accord
# Name: La présentation orale sur les énergies vous semble [Chronophage], Length: 203, dtype: object
# LU1ST021 1 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Plutôt pas d'accord', 'Tout à fait d'accord',
#        'Pas du tout d'accord'],
#       dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# La présentation orale sur les énergies vous semble [Chronophage]
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/Question_14
# 0                       NaN
# 1                       NaN
# 2       Plutôt pas d'accord
# 3           Plutôt d'accord
# 4      Tout à fait d'accord
#                ...
# 198         Plutôt d'accord
# 199    Tout à fait d'accord
# 200         Plutôt d'accord
# 201                     NaN
# 202         Plutôt d'accord
# Name: Le premier TD  comprenant les jeux "Fresque du Climat" et "Inventons nos vie Bas Carbone" vous semble [Instructif], Length: 203, dtype: object
# LU1ST021 1 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord',
#        'Pas du tout d'accord'],
#       dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Le premier TD  comprenant les jeux "Fresque du Climat" et "Inventons nos vie Bas Carbone" vous semble [Instructif]
# /Users/florentbrient/Dropbox/Enseignements/2021_2022/Resp_eval/Resultats/S1/d_figures/LU1ST021/Question_15
