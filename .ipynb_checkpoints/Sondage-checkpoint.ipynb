# %%
import matplotlib as mpl
from matplotlib import cm
import matplotlib.pyplot as plt
import pylab as plt
import pandas as pd
import numpy as np
import os


def colorFader(c1,c2,mix=0): #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1=np.array(mpl.colors.to_rgb(c1))
    c2=np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)

def _savefig(fig,ax,name='',title='',fts=10,xsize=(10,10),zmax=None):
    plt.xticks(size=fts)
    plt.yticks(size=fts)
    plt.title(title)
    fig.set_size_inches(xsize)
    fig.savefig(name + '.png')#,dpi='figure')
    fig.savefig(name + '.pdf', dpi=1000)
    plt.close()
    
def func(pct, allvals):
    absolute = int(round(pct/100.*np.sum(allvals)))
    return "{:.1f}%\n({:d} r)".format(pct, absolute)

def _mkdir(path):
    print('path : ',path)
    print(os.path.exists(path))
    if not(os.path.exists(path)):
      os.mkdir(path)

Semestre = 6 #1

path   = '/Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/Reponses/'

fileadd = []
file    = 'Sondage UE Sciences de la Terre - Semestre '+str(Semestre)+'.csv'
if Semestre == 4:
  file  = 'Sondage UE Sciences de la Terre - Semestre '+str(Semestre)+' - v2.csv'
elif Semestre == 5: 
  fileadd   = []
  #fileadd   = 'Sondage UE Sciences de la Terre - Ressources.csv'
  #fileadd   = 'Sondage UE Sciences de la Terre - Océanographie.csv'
  fileadd   = 'Sondage UE Sciences de la Terre - Biodiversité et Paléobiodiversité.csv'
   #[ 'Sondage UE Sciences de la Terre - Ressources.csv'
             #,'Sondage UE Sciences de la Terre - Océanographie.csv'
             #,'Sondage UE Sciences de la Terre - Biodiversité et Paléobiodiversité.csv']
#elif Semestre == 6: 
#  fileadd   = 'Sondage UE Sciences de la Terre - Semestre 6 - Complementaires.csv'

suffix = ''
if len(fileadd)>0:
    suffix = '_'+fileadd.split(' ')[-1].split('.')[0] 
    file   = fileadd
print(file,fileadd,suffix)
file   = path+file

pathfig0 = '/Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/'
pathfig  = pathfig0+'d_figures/'
_mkdir(pathfig)

df1    = pd.read_csv(file)
#print(type(df1))
#if len(fileadd)>0:
#    for tmp in fileadd:
#        df_tmp = pd.read_csv(path+tmp)
#        #print(df_tmp)
#        df1 = pd.concat([df1,df_tmp], axis=1) #, ignore_index=True, sort=False)

#df_eng = pd.read_excel('translate_FR.xlsx', header=1,encoding='latin1')
#df_eng = df_eng.set_axis(df_fr.columns.values.tolist(),axis='columns')
#df     = df_fr.append(df_eng, ignore_index=True, sort=False)

df     = df1
#print(df)

questions=df.columns.values
print(questions)
# Out:
# Sondage UE Sciences de la Terre - Semestre 6 - Complementaires.csv Sondage UE Sciences de la Terre - Semestre 6 - Complementaires.csv _Complementaires
# path :  /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/
# True
# ['Horodateur' 'Quelle formation avez-vous suivi ?'
#  "Avez-vous suivi l'UE Biogéochimie Océan - Atmosphère (LU3ST061)?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous ont été présentés]'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris]'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables]"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS]"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE]"
#  "Intérêt de l'UE [Les enseignements de cette UE vous ont intéressé.]"
#  "Intérêt de l'UE [Les changements des activités liés à la crise sanitaire vous ont affectés ]"
#  "Intérêt de l'UE [Vous avez apprécié les activités distancielles mises en place]"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?'
#  'Les documents de cette UE vous semblent : [Utiles]'
#  'Les documents de cette UE vous semblent : [En quantité suffisante]'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?'
#  "Avez-vous suivi l'UE Projet informatique (LU3ST063) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés]'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].1'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.]"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].1"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].1"
#  "Intérêt de l'UE [Les enseignements de cette UE vous ont intéressé.].1"
#  "Intérêt de l'UE [Les changements des activités liés à la crise sanitaire vous ont affecté ]"
#  "Intérêt de l'UE [Vous avez apprécié les activités distancielles mises en place].1"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.1'
#  'Les documents de cette UE vous semblent : [Utiles].1'
#  'Les documents de cette UE vous semblent : [En quantité suffisante].1'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.1'
#  "Avez-vous suivi l'UE Développement des idées en géosciences (LU3ST068) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].1'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].2'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].1"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].2"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].2"
#  "Intérêt de l'UE [Les enseignements de cette UE vous ont intéressé.].2"
#  "Intérêt de l'UE [Les changements des activités liés à la crise sanitaire vous ont affecté ].1"
#  "Intérêt de l'UE [Vous avez apprécié les activités distancielles mises en place].2"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.2'
#  'Les documents de cette UE vous semblent : [Utiles].2'
#  'Les documents de cette UE vous semblent : [En quantité suffisante].2'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.2'
#  "Avez-vous suivi l'UE Climats et Paléoclimats (LU3ST060) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].2'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].3'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].2"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].3"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].3"
#  "Intérêt de l'UE [Les enseignements de cette UE vous ont intéressé.].3"
#  "Intérêt de l'UE [Les changements des activités liés à la crise sanitaire vous ont affecté ].2"
#  "Intérêt de l'UE [Vous avez apprécié les activités distancielles mises en place].3"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.3'
#  'Les documents de cette UE vous semblent : [Utiles].3'
#  'Les documents de cette UE vous semblent : [En quantité suffisante].3'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.3'
#  "Avez-vous suivi l'UE Paléontologie & évolution (LU3ST066) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].3'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].4'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].3"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].4"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].4"
#  "Intérêt de l'UE [Les enseignements de cette UE vous ont intéressé.].4"
#  "Intérêt de l'UE [Les changements des activités liés à la crise sanitaire vous ont affecté ].3"
#  "Intérêt de l'UE [Vous avez apprécié les activités distancielles mises en place].4"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.4'
#  'Les documents de cette UE vous semblent : [Utiles].4'
#  'Les documents de cette UE vous semblent : [En quantité suffisante].4'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.4'
#  "Avez-vous suivi l'UE Géophysique : Outils & Applications (LU3ST069) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].4'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].5'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].4"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].5"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].5"
#  "Intérêt de l'UE [Les enseignements de cette UE vous ont intéressé.].5"
#  "Intérêt de l'UE [Les changements des activités liés à la crise sanitaire vous ont affecté ].4"
#  "Intérêt de l'UE [Vous avez apprécié les activités distancielles mises en place].5"
#  'La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.5'
#  'Les documents de cette UE vous semblent : [Utiles].5'
#  'Les documents de cette UE vous semblent : [En quantité suffisante].5'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.5'
#  "Avez-vous suivi l'UE Stage Fablab (LU3ST602) ?"
#  'Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].5'
#  'Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].6'
#  "Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].5"
#  "Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].6"
#  "Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].6"
#  "Intérêt de l'UE [Les enseignements de cette UE vous ont intéressé.].6"
#  "Intérêt de l'UE [Les changements des activités liés à la crise sanitaire vous ont affecté ].5"
#  "Intérêt de l'UE [Vous avez apprécié les activités distancielles mises en place].6"
#  "Le lien entre l'UE Stage Fablab et les autres enseignements du semestre vous parait-t-il?"
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.6'
#  'Avez-vous une remarque sur les UE complémentaires du Semestre 6 de la licence Sciences de la Terre?']

# %%
# Formation

pies     = [1]
New_name = ['Formation?']

c1='#1f77b4' #blue
c2='red' #green
n=4
colors2 = [colorFader(c1,c2,x/2)for x in range(2)]
colors4 = [colorFader(c1,c2,x/4)for x in range(4)]

formation = df[questions[pies[0]]]

labels0 = formation.unique()
print(labels0)
#['Majeure' 'Mineure Geosciences' 'Monodisciplinaire Sciences de la Terre'
# 'Bi-disciplinaire : Biologie - Mineure Sciences de la Terre (MEEF)']
    

colors  = ['royalblue','red','gold','green','purple']

figsize = (8, 5)

for ij,nbpie in enumerate(pies): 
    fig, ax = plt.subplots(1,figsize=figsize)

    data = df[questions[nbpie]].value_counts()#normalize=True)
    print(data)
    for ik in data.index:
       data = data.rename(index={ik:ik.split(' ')[0]})
    print(data)
    
    labels  = data.index #[ij.split(' ')[0] for ij in labels0 if ij in data.index]  
    print(labels,data.index)#,dcolors)
    
        
    gcolors = dict()
    keys    = labels
    for ik,key in enumerate(keys):
        print(ik, key)
        gcolors[key]=colors[ik]
    print(gcolors)
    labels = [ik for ik in gcolors if ik in data.index]
    data   = data.reindex(labels)
    print(labels)
    
    wedges, texts, autotexts = ax.pie(data,labels=labels
                                  ,autopct=lambda pct: func(pct, data)
                                  ,colors=[gcolors[i] for i in data.index]
                                  ,textprops=dict(color="k"),startangle=90
                                  ,pctdistance=0.7, labeldistance=1.2
                                 )
    print(ax.xaxis.get_label())
    ax.legend(wedges, labels,
          loc="upper right",
          bbox_to_anchor=(1, 1, 0.5, -0.5))
          #title=questions[1],
    plt.setp(autotexts, size=10, weight="bold")

    title = New_name[ij]
    ax.set_title(title)
    
    name_file = pathfig+title.split('?')[0]+'_Semestre'+str(Semestre)+suffix
    print(title,name_file)
#plt.show()
    _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# ['Bi-disciplinaire : Biologie - Mineure Sciences de la Terre (MEEF)'
#  'Mineure Geosciences' 'Monodisciplinaire Sciences de la Terre'
#  'Majeure ou Double Majeure' 'L4']
# Monodisciplinaire Sciences de la Terre                               13
# Mineure Geosciences                                                   8
# Majeure ou Double Majeure                                             5
# Bi-disciplinaire : Biologie - Mineure Sciences de la Terre (MEEF)     4
# L4                                                                    2
# Name: Quelle formation avez-vous suivi ?, dtype: int64
# Monodisciplinaire    13
# Mineure               8
# Majeure               5
# Bi-disciplinaire      4
# L4                    2
# Name: Quelle formation avez-vous suivi ?, dtype: int64
# Index(['Monodisciplinaire', 'Mineure', 'Majeure', 'Bi-disciplinaire', 'L4'], dtype='object') Index(['Monodisciplinaire', 'Mineure', 'Majeure', 'Bi-disciplinaire', 'L4'], dtype='object')
# 0 Monodisciplinaire
# 1 Mineure
# 2 Majeure
# 3 Bi-disciplinaire
# 4 L4
# {'Monodisciplinaire': 'royalblue', 'Mineure': 'red', 'Majeure': 'gold', 'Bi-disciplinaire': 'green', 'L4': 'purple'}
# ['Monodisciplinaire', 'Mineure', 'Majeure', 'Bi-disciplinaire', 'L4']
# Text(0.5, 0, '')
# Formation? /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/Formation_Semestre6_Complementaires

# %%
#Find UEs
UEs = [(ij,question.replace(' ?','').split(' ')[-1]) for ij,question in enumerate(questions) if 'Avez-vous suivi' in question]
print(UEs)

# Make a selection (Subset of the poll)
#said_yes = df[df[questions[2]] == 'Oui']
#print(questions[5],said_yes)

subset = False
if subset:
  # Impose this selection
    pathfig = pathfig+'d_subset/'
    df      = said_yes
# Out:
# [(2, '(LU3ST061)?'), (15, '(LU3ST063)'), (28, '(LU3ST068)'), (41, '(LU3ST060)'), (54, '(LU3ST066)'), (67, '(LU3ST069)'), (80, '(LU3ST602)')]

# %%
UE_idx   = [ij[0] for ij in UEs] #[1,2,3,4,5,6,8,17,18]
UE_names = [ij[1].strip("()?") for ij in UEs] #['Profession?', 'Permanent?', 'Site?', 'Climaction?','Stratégie?','Quel objectif?',
            #'Individuel ou collectif?','Calculateur?','Influence recherche?'].replace('(','').replace(')','')

print(UE_idx,UE_names)
#colors2 = ['red', 'blue']
#a       = np.random.random(4)
#cs      = cm.Set1(np.arange(4)/4.)

keys1 = ['Oui','Non']
keys2 = ['Tout à fait d\'accord','Plutôt d\'accord','Plutôt pas d\'accord','Pas du tout d\'accord']
# Changing key for specific question
Idx_change = [9]
tabword = ['cohérence','lien entre']
keys3 = ['Bonne','Plutôt bonne','Plutôt mauvaise','Mauvaise']
# Changing answers for specific question
UE_change  = ['LU2ST034','LU2ST303','LU2ST044','LU2ST402','LU3ST603','LU3ST602']
keys4 = ['Très clair','Assez clair','Assez flou','Très flou']

#c1 = '#1f77b4' #blue
#c2 = 'red' #green
#colors2 = [colorFader(c1,c2,x/2)for x in range(2)]
#colors4 = [colorFader(c1,c2,x/4)for x in range(4)]

# 12 questions !
Nb_questions = 12 #(UE_idx[1]-UE_idx[0])-1
print(Nb_questions)

figsize = (8, 5)

#UE_idx=[UE_idx[ij] for ij in range(len(UE_idx)) if UE_names[ij]=='LU2ST045']
#print(UE_idx)

for ij,idx in enumerate(UE_idx):
    UE = UE_names[ij]
    print('UE : ',UE)
    
    path_file = pathfig+UE+'/'
    print(path_file)
    _mkdir(path_file)
    
    for ik in range(Nb_questions):
      fig, ax = plt.subplots(1,figsize=figsize)

      data = df[questions[idx+ik]].replace('Tout à fait d’accord','Tout à fait d\'accord')
      data = data.replace('Plutôt pas d’accord','Plutôt pas d\'accord')
      #data = data.replace('d’accord','d\'accord')
      data = data.replace('Très','Tr\'es')
      print(data)
      data = data.value_counts() #normalize=True) 
                
      #colors = colors2 ; 
      keys = keys1
      if ('Oui' in data.keys()):
        keys = keys1
      else:
        keys = keys2
        #if ik in Idx_change:
        if any([ii in questions[idx+ik] for ii in tabword]):
        #if 'cohérence' in questions[idx+ik]:
            keys = keys3
            if UE in UE_change:
                keys = keys4    
      print(UE,idx,keys,data.index)
    
      cmap = plt.cm.bwr
      colors = cmap(np.linspace(0., 1., len(keys)))
    
      gcolors=dict()
      for ij,key in enumerate(keys):
        gcolors[key]=colors[ij]
      labels = [ij for ij in gcolors if ij in data.index]
      data   = data.reindex(labels)
      print(labels)
        
      wedges, texts, autotexts = ax.pie(data,autopct=lambda pct: func(pct, data)\
                                            ,colors=[gcolors[i] for i in data.index]\
                                            ,textprops=dict(color="w") #, colors=color
                                            ,startangle=0)
    
      ax.legend(wedges, data.index,loc="center",bbox_to_anchor=(1, 1, 0.5, -0.5))
      plt.setp(autotexts, size=10, weight="bold")
    
      title = questions[idx+ik].split('.')[0]
      ax.set_title(title)
      print(title)
    
      name_file = 'Question_'+str(ik)
      name_file = path_file + name_file
      print(name_file)
      _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# [2, 15, 28, 41, 54, 67, 80] ['LU3ST061', 'LU3ST063', 'LU3ST068', 'LU3ST060', 'LU3ST066', 'LU3ST069', 'LU3ST602']
# 12
# UE :  LU3ST061
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST061/
# path :  /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST061/
# False
# 0     Non
# 1     Non
# 2     Non
# 3     Oui
# 4     Oui
# 5     Non
# 6     Non
# 7     Oui
# 8     Non
# 9     Non
# 10    Non
# 11    Non
# 12    Non
# 13    Non
# 14    Non
# 15    Oui
# 16    Non
# 17    Non
# 18    Non
# 19    Non
# 20    Non
# 21    Non
# 22    Non
# 23    Non
# 24    Oui
# 25    Non
# 26    Oui
# 27    Non
# 28    Oui
# 29    Non
# 30    Non
# 31    Non
# Name: Avez-vous suivi l'UE Biogéochimie Océan - Atmosphère (LU3ST061)?, dtype: object
# LU3ST061 2 ['Oui', 'Non'] Index(['Non', 'Oui'], dtype='object')
# ['Oui', 'Non']
# Avez-vous suivi l'UE Biogéochimie Océan - Atmosphère (LU3ST061)?
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST061/Question_0
# 0     NaN
# 1     NaN
# 2     NaN
# 3     Oui
# 4     Oui
# 5     NaN
# 6     NaN
# 7     Oui
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    Oui
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    Non
# 25    NaN
# 26    Oui
# 27    NaN
# 28    Oui
# 29    NaN
# 30    NaN
# 31    NaN
# Name: Que diriez-vous des objectifs de cette UE ? [Ils vous ont été présentés], dtype: object
# LU3ST061 2 ['Oui', 'Non'] Index(['Oui', 'Non'], dtype='object')
# ['Oui', 'Non']
# Que diriez-vous des objectifs de cette UE ? [Ils vous ont été présentés]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST061/Question_1
# 0     NaN
# 1     NaN
# 2     NaN
# 3     Non
# 4     Oui
# 5     NaN
# 6     NaN
# 7     Oui
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    Oui
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    Oui
# 25    NaN
# 26    Oui
# 27    NaN
# 28    Oui
# 29    NaN
# 30    NaN
# 31    NaN
# Name: Que diriez-vous des objectifs de cette UE ? [Vous les avez compris], dtype: object
# LU3ST061 2 ['Oui', 'Non'] Index(['Oui', 'Non'], dtype='object')
# ['Oui', 'Non']
# Que diriez-vous des objectifs de cette UE ? [Vous les avez compris]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST061/Question_2
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3          Plutôt d'accord
# 4      Plutôt pas d'accord
# 5                      NaN
# 6                      NaN
# 7          Plutôt d'accord
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15    Tout à fait d'accord
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24    Tout à fait d'accord
# 25                     NaN
# 26    Tout à fait d'accord
# 27                     NaN
# 28     Plutôt pas d'accord
# 29                     NaN
# 30                     NaN
# 31                     NaN
# Name: Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables], dtype: object
# LU3ST061 2 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST061/Question_3
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3      Plutôt pas d'accord
# 4          Plutôt d'accord
# 5                      NaN
# 6                      NaN
# 7     Tout à fait d'accord
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15    Tout à fait d'accord
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24    Tout à fait d'accord
# 25                     NaN
# 26    Tout à fait d'accord
# 27                     NaN
# 28     Plutôt pas d'accord
# 29                     NaN
# 30                     NaN
# 31                     NaN
# Name: Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS], dtype: object
# LU3ST061 2 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt pas d'accord', 'Plutôt d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST061/Question_4
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3          Plutôt d'accord
# 4          Plutôt d'accord
# 5                      NaN
# 6                      NaN
# 7      Plutôt pas d'accord
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15    Tout à fait d'accord
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24    Tout à fait d'accord
# 25                     NaN
# 26    Tout à fait d'accord
# 27                     NaN
# 28     Plutôt pas d'accord
# 29                     NaN
# 30                     NaN
# 31                     NaN
# Name: Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE], dtype: object
# LU3ST061 2 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST061/Question_5
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3     Tout à fait d'accord
# 4          Plutôt d'accord
# 5                      NaN
# 6                      NaN
# 7     Tout à fait d'accord
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15    Tout à fait d'accord
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24    Tout à fait d'accord
# 25                     NaN
# 26    Tout à fait d'accord
# 27                     NaN
# 28         Plutôt d'accord
# 29                     NaN
# 30                     NaN
# 31                     NaN
# Name: Intérêt de l'UE [Les enseignements de cette UE vous ont intéressé.], dtype: object
# LU3ST061 2 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Intérêt de l'UE [Les enseignements de cette UE vous ont intéressé
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST061/Question_6
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3     Tout à fait d'accord
# 4     Tout à fait d'accord
# 5                      NaN
# 6                      NaN
# 7      Plutôt pas d'accord
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15     Plutôt pas d'accord
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24         Plutôt d'accord
# 25                     NaN
# 26     Plutôt pas d'accord
# 27                     NaN
# 28    Tout à fait d'accord
# 29                     NaN
# 30                     NaN
# 31                     NaN
# Name: Intérêt de l'UE [Les changements des activités liés à la crise sanitaire vous ont affectés ], dtype: object
# LU3ST061 2 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt pas d'accord', 'Tout à fait d'accord', 'Plutôt d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Intérêt de l'UE [Les changements des activités liés à la crise sanitaire vous ont affectés ]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST061/Question_7
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3      Plutôt pas d'accord
# 4          Plutôt d'accord
# 5                      NaN
# 6                      NaN
# 7      Plutôt pas d'accord
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15    Tout à fait d'accord
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24         Plutôt d'accord
# 25                     NaN
# 26    Tout à fait d'accord
# 27                     NaN
# 28     Plutôt pas d'accord
# 29                     NaN
# 30                     NaN
# 31                     NaN
# Name: Intérêt de l'UE [Vous avez apprécié les activités distancielles mises en place], dtype: object
# LU3ST061 2 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt pas d'accord', 'Plutôt d'accord', 'Tout à fait d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Intérêt de l'UE [Vous avez apprécié les activités distancielles mises en place]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST061/Question_8
# 0              NaN
# 1              NaN
# 2              NaN
# 3     Plutôt bonne
# 4     Plutôt bonne
# 5              NaN
# 6              NaN
# 7            Bonne
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15           Bonne
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24           Bonne
# 25             NaN
# 26    Plutôt bonne
# 27             NaN
# 28    Plutôt bonne
# 29             NaN
# 30             NaN
# 31             NaN
# Name: La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?, dtype: object
# LU3ST061 2 ['Bonne', 'Plutôt bonne', 'Plutôt mauvaise', 'Mauvaise'] Index(['Plutôt bonne', 'Bonne'], dtype='object')
# ['Bonne', 'Plutôt bonne']
# La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST061/Question_9
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3          Plutôt d'accord
# 4          Plutôt d'accord
# 5                      NaN
# 6                      NaN
# 7     Tout à fait d'accord
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15    Tout à fait d'accord
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24    Tout à fait d'accord
# 25                     NaN
# 26    Tout à fait d'accord
# 27                     NaN
# 28         Plutôt d'accord
# 29                     NaN
# 30                     NaN
# 31                     NaN
# Name: Les documents de cette UE vous semblent : [Utiles], dtype: object
# LU3ST061 2 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Les documents de cette UE vous semblent : [Utiles]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST061/Question_10
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3      Plutôt pas d'accord
# 4      Plutôt pas d'accord
# 5                      NaN
# 6                      NaN
# 7          Plutôt d'accord
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15    Tout à fait d'accord
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24    Tout à fait d'accord
# 25                     NaN
# 26         Plutôt d'accord
# 27                     NaN
# 28         Plutôt d'accord
# 29                     NaN
# 30                     NaN
# 31                     NaN
# Name: Les documents de cette UE vous semblent : [En quantité suffisante], dtype: object
# LU3ST061 2 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Plutôt pas d'accord', 'Tout à fait d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Les documents de cette UE vous semblent : [En quantité suffisante]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST061/Question_11
# UE :  LU3ST063
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST063/
# path :  /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST063/
# False
# 0     Non
# 1     Non
# 2     Non
# 3     Non
# 4     Non
# 5     Non
# 6     Non
# 7     Non
# 8     Non
# 9     Non
# 10    Non
# 11    Non
# 12    Non
# 13    Non
# 14    Non
# 15    Non
# 16    Non
# 17    Non
# 18    Non
# 19    Non
# 20    Non
# 21    Non
# 22    Non
# 23    Non
# 24    Non
# 25    Oui
# 26    Non
# 27    Non
# 28    Non
# 29    Oui
# 30    Oui
# 31    Non
# Name: Avez-vous suivi l'UE Projet informatique (LU3ST063) ?, dtype: object
# LU3ST063 15 ['Oui', 'Non'] Index(['Non', 'Oui'], dtype='object')
# ['Oui', 'Non']
# Avez-vous suivi l'UE Projet informatique (LU3ST063) ?
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST063/Question_0
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    Oui
# 26    NaN
# 27    NaN
# 28    NaN
# 29    Oui
# 30    Oui
# 31    NaN
# Name: Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés], dtype: object
# LU3ST063 15 ['Oui', 'Non'] Index(['Oui'], dtype='object')
# ['Oui']
# Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST063/Question_1
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    Oui
# 26    NaN
# 27    NaN
# 28    NaN
# 29    Oui
# 30    Oui
# 31    NaN
# Name: Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].1, dtype: object
# LU3ST063 15 ['Oui', 'Non'] Index(['Oui'], dtype='object')
# ['Oui']
# Que diriez-vous des objectifs de cette UE ? [Vous les avez compris]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST063/Question_2
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25         Plutôt d'accord
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29    Pas du tout d'accord
# 30         Plutôt d'accord
# 31                     NaN
# Name: Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.], dtype: object
# LU3ST063 15 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Pas du tout d'accord'], dtype='object')
# ["Plutôt d'accord", "Pas du tout d'accord"]
# Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST063/Question_3
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25         Plutôt d'accord
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29    Tout à fait d'accord
# 30         Plutôt d'accord
# 31                     NaN
# Name: Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].1, dtype: object
# LU3ST063 15 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST063/Question_4
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25         Plutôt d'accord
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29    Pas du tout d'accord
# 30    Tout à fait d'accord
# 31                     NaN
# Name: Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].1, dtype: object
# LU3ST063 15 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Pas du tout d'accord', 'Tout à fait d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Pas du tout d'accord"]
# Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST063/Question_5
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25         Plutôt d'accord
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29    Pas du tout d'accord
# 30    Tout à fait d'accord
# 31                     NaN
# Name: Intérêt de l'UE [Les enseignements de cette UE vous ont intéressé.].1, dtype: object
# LU3ST063 15 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Pas du tout d'accord', 'Tout à fait d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Pas du tout d'accord"]
# Intérêt de l'UE [Les enseignements de cette UE vous ont intéressé
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST063/Question_6
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25     Plutôt pas d'accord
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29    Tout à fait d'accord
# 30    Tout à fait d'accord
# 31                     NaN
# Name: Intérêt de l'UE [Les changements des activités liés à la crise sanitaire vous ont affecté ], dtype: object
# LU3ST063 15 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt pas d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt pas d'accord"]
# Intérêt de l'UE [Les changements des activités liés à la crise sanitaire vous ont affecté ]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST063/Question_7
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25         Plutôt d'accord
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29    Pas du tout d'accord
# 30         Plutôt d'accord
# 31                     NaN
# Name: Intérêt de l'UE [Vous avez apprécié les activités distancielles mises en place].1, dtype: object
# LU3ST063 15 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Pas du tout d'accord'], dtype='object')
# ["Plutôt d'accord", "Pas du tout d'accord"]
# Intérêt de l'UE [Vous avez apprécié les activités distancielles mises en place]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST063/Question_8
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25    Plutôt bonne
# 26             NaN
# 27             NaN
# 28             NaN
# 29        Mauvaise
# 30    Plutôt bonne
# 31             NaN
# Name: La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.1, dtype: object
# LU3ST063 15 ['Bonne', 'Plutôt bonne', 'Plutôt mauvaise', 'Mauvaise'] Index(['Plutôt bonne', 'Mauvaise'], dtype='object')
# ['Plutôt bonne', 'Mauvaise']
# La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST063/Question_9
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25         Plutôt d'accord
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29         Plutôt d'accord
# 30    Tout à fait d'accord
# 31                     NaN
# Name: Les documents de cette UE vous semblent : [Utiles].1, dtype: object
# LU3ST063 15 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Les documents de cette UE vous semblent : [Utiles]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST063/Question_10
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25     Plutôt pas d'accord
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29    Pas du tout d'accord
# 30         Plutôt d'accord
# 31                     NaN
# Name: Les documents de cette UE vous semblent : [En quantité suffisante].1, dtype: object
# LU3ST063 15 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Plutôt pas d'accord', 'Pas du tout d'accord'], dtype='object')
# ["Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Les documents de cette UE vous semblent : [En quantité suffisante]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST063/Question_11
# UE :  LU3ST068
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST068/
# path :  /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST068/
# False
# 0     Oui
# 1     Non
# 2     Oui
# 3     Non
# 4     Non
# 5     Oui
# 6     Oui
# 7     Non
# 8     Oui
# 9     Oui
# 10    Non
# 11    Oui
# 12    Oui
# 13    Oui
# 14    Non
# 15    Non
# 16    Oui
# 17    Oui
# 18    Non
# 19    Oui
# 20    Non
# 21    Oui
# 22    Oui
# 23    Non
# 24    Non
# 25    Non
# 26    Non
# 27    Oui
# 28    Non
# 29    Non
# 30    Non
# 31    Oui
# Name: Avez-vous suivi l'UE Développement des idées en géosciences (LU3ST068) ?, dtype: object
# LU3ST068 28 ['Oui', 'Non'] Index(['Non', 'Oui'], dtype='object')
# ['Oui', 'Non']
# Avez-vous suivi l'UE Développement des idées en géosciences (LU3ST068) ?
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST068/Question_0
# 0     Oui
# 1     NaN
# 2     Oui
# 3     NaN
# 4     NaN
# 5     Oui
# 6     Oui
# 7     NaN
# 8     Oui
# 9     Oui
# 10    NaN
# 11    Oui
# 12    Oui
# 13    Oui
# 14    NaN
# 15    NaN
# 16    Oui
# 17    Oui
# 18    NaN
# 19    Non
# 20    NaN
# 21    Oui
# 22    Oui
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    Oui
# 28    NaN
# 29    NaN
# 30    NaN
# 31    Oui
# Name: Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].1, dtype: object
# LU3ST068 28 ['Oui', 'Non'] Index(['Oui', 'Non'], dtype='object')
# ['Oui', 'Non']
# Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST068/Question_1
# 0     Oui
# 1     NaN
# 2     Oui
# 3     NaN
# 4     NaN
# 5     Oui
# 6     Oui
# 7     NaN
# 8     Oui
# 9     Oui
# 10    NaN
# 11    Non
# 12    Oui
# 13    Oui
# 14    NaN
# 15    NaN
# 16    Oui
# 17    Oui
# 18    NaN
# 19    Non
# 20    NaN
# 21    Oui
# 22    Oui
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    Oui
# 28    NaN
# 29    NaN
# 30    NaN
# 31    Oui
# Name: Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].2, dtype: object
# LU3ST068 28 ['Oui', 'Non'] Index(['Oui', 'Non'], dtype='object')
# ['Oui', 'Non']
# Que diriez-vous des objectifs de cette UE ? [Vous les avez compris]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST068/Question_2
# 0     Tout à fait d'accord
# 1                      NaN
# 2          Plutôt d'accord
# 3                      NaN
# 4                      NaN
# 5          Plutôt d'accord
# 6          Plutôt d'accord
# 7                      NaN
# 8     Tout à fait d'accord
# 9     Tout à fait d'accord
# 10                     NaN
# 11     Plutôt pas d'accord
# 12         Plutôt d'accord
# 13         Plutôt d'accord
# 14                     NaN
# 15                     NaN
# 16         Plutôt d'accord
# 17         Plutôt d'accord
# 18                     NaN
# 19         Plutôt d'accord
# 20                     NaN
# 21    Tout à fait d'accord
# 22    Tout à fait d'accord
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27         Plutôt d'accord
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31    Tout à fait d'accord
# Name: Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].1, dtype: object
# LU3ST068 28 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord', 'Plutôt pas d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST068/Question_3
# 0     Tout à fait d'accord
# 1                      NaN
# 2     Tout à fait d'accord
# 3                      NaN
# 4                      NaN
# 5          Plutôt d'accord
# 6          Plutôt d'accord
# 7                      NaN
# 8     Tout à fait d'accord
# 9     Tout à fait d'accord
# 10                     NaN
# 11     Plutôt pas d'accord
# 12         Plutôt d'accord
# 13         Plutôt d'accord
# 14                     NaN
# 15                     NaN
# 16    Tout à fait d'accord
# 17         Plutôt d'accord
# 18                     NaN
# 19    Tout à fait d'accord
# 20                     NaN
# 21    Tout à fait d'accord
# 22    Tout à fait d'accord
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27         Plutôt d'accord
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31    Tout à fait d'accord
# Name: Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].2, dtype: object
# LU3ST068 28 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST068/Question_4
# 0     Tout à fait d'accord
# 1                      NaN
# 2     Tout à fait d'accord
# 3                      NaN
# 4                      NaN
# 5     Pas du tout d'accord
# 6          Plutôt d'accord
# 7                      NaN
# 8     Tout à fait d'accord
# 9     Tout à fait d'accord
# 10                     NaN
# 11    Pas du tout d'accord
# 12         Plutôt d'accord
# 13         Plutôt d'accord
# 14                     NaN
# 15                     NaN
# 16    Tout à fait d'accord
# 17         Plutôt d'accord
# 18                     NaN
# 19    Tout à fait d'accord
# 20                     NaN
# 21     Plutôt pas d'accord
# 22    Tout à fait d'accord
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27         Plutôt d'accord
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31    Tout à fait d'accord
# Name: Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].2, dtype: object
# LU3ST068 28 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Pas du tout d'accord',
#        'Plutôt pas d'accord'],
#       dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST068/Question_5
# 0          Plutôt d'accord
# 1                      NaN
# 2          Plutôt d'accord
# 3                      NaN
# 4                      NaN
# 5      Plutôt pas d'accord
# 6          Plutôt d'accord
# 7                      NaN
# 8     Tout à fait d'accord
# 9     Tout à fait d'accord
# 10                     NaN
# 11     Plutôt pas d'accord
# 12     Plutôt pas d'accord
# 13         Plutôt d'accord
# 14                     NaN
# 15                     NaN
# 16    Tout à fait d'accord
# 17         Plutôt d'accord
# 18                     NaN
# 19    Tout à fait d'accord
# 20                     NaN
# 21    Tout à fait d'accord
# 22    Tout à fait d'accord
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27    Tout à fait d'accord
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31         Plutôt d'accord
# Name: Intérêt de l'UE [Les enseignements de cette UE vous ont intéressé.].2, dtype: object
# LU3ST068 28 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Intérêt de l'UE [Les enseignements de cette UE vous ont intéressé
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST068/Question_6
# 0     Pas du tout d'accord
# 1                      NaN
# 2     Pas du tout d'accord
# 3                      NaN
# 4                      NaN
# 5          Plutôt d'accord
# 6          Plutôt d'accord
# 7                      NaN
# 8     Pas du tout d'accord
# 9          Plutôt d'accord
# 10                     NaN
# 11    Tout à fait d'accord
# 12         Plutôt d'accord
# 13         Plutôt d'accord
# 14                     NaN
# 15                     NaN
# 16         Plutôt d'accord
# 17    Pas du tout d'accord
# 18                     NaN
# 19         Plutôt d'accord
# 20                     NaN
# 21     Plutôt pas d'accord
# 22    Pas du tout d'accord
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27    Tout à fait d'accord
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31     Plutôt pas d'accord
# Name: Intérêt de l'UE [Les changements des activités liés à la crise sanitaire vous ont affecté ].1, dtype: object
# LU3ST068 28 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Pas du tout d'accord', 'Plutôt pas d'accord',
#        'Tout à fait d'accord'],
#       dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Intérêt de l'UE [Les changements des activités liés à la crise sanitaire vous ont affecté ]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST068/Question_7
# 0          Plutôt d'accord
# 1                      NaN
# 2          Plutôt d'accord
# 3                      NaN
# 4                      NaN
# 5      Plutôt pas d'accord
# 6      Plutôt pas d'accord
# 7                      NaN
# 8     Tout à fait d'accord
# 9          Plutôt d'accord
# 10                     NaN
# 11     Plutôt pas d'accord
# 12         Plutôt d'accord
# 13     Plutôt pas d'accord
# 14                     NaN
# 15                     NaN
# 16         Plutôt d'accord
# 17     Plutôt pas d'accord
# 18                     NaN
# 19         Plutôt d'accord
# 20                     NaN
# 21         Plutôt d'accord
# 22    Tout à fait d'accord
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27     Plutôt pas d'accord
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31         Plutôt d'accord
# Name: Intérêt de l'UE [Vous avez apprécié les activités distancielles mises en place].2, dtype: object
# LU3ST068 28 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Plutôt pas d'accord', 'Tout à fait d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Intérêt de l'UE [Vous avez apprécié les activités distancielles mises en place]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST068/Question_8
# 0        Plutôt bonne
# 1                 NaN
# 2        Plutôt bonne
# 3                 NaN
# 4                 NaN
# 5     Plutôt mauvaise
# 6        Plutôt bonne
# 7                 NaN
# 8               Bonne
# 9        Plutôt bonne
# 10                NaN
# 11           Mauvaise
# 12       Plutôt bonne
# 13       Plutôt bonne
# 14                NaN
# 15                NaN
# 16              Bonne
# 17       Plutôt bonne
# 18                NaN
# 19       Plutôt bonne
# 20                NaN
# 21    Plutôt mauvaise
# 22              Bonne
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27    Plutôt mauvaise
# 28                NaN
# 29                NaN
# 30                NaN
# 31       Plutôt bonne
# Name: La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?.2, dtype: object
# LU3ST068 28 ['Bonne', 'Plutôt bonne', 'Plutôt mauvaise', 'Mauvaise'] Index(['Plutôt bonne', 'Bonne', 'Plutôt mauvaise', 'Mauvaise'], dtype='object')
# ['Bonne', 'Plutôt bonne', 'Plutôt mauvaise', 'Mauvaise']
# La cohérence entre les enseignements (cours, TD, TP) de cette UE vous parait-t-elle?
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST068/Question_9
# 0      Plutôt pas d'accord
# 1                      NaN
# 2     Tout à fait d'accord
# 3                      NaN
# 4                      NaN
# 5      Plutôt pas d'accord
# 6          Plutôt d'accord
# 7                      NaN
# 8     Tout à fait d'accord
# 9     Tout à fait d'accord
# 10                     NaN
# 11     Plutôt pas d'accord
# 12     Plutôt pas d'accord
# 13         Plutôt d'accord
# 14                     NaN
# 15                     NaN
# 16         Plutôt d'accord
# 17         Plutôt d'accord
# 18                     NaN
# 19    Pas du tout d'accord
# 20                     NaN
# 21    Tout à fait d'accord
# 22    Tout à fait d'accord
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27    Tout à fait d'accord
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31    Tout à fait d'accord
# Name: Les documents de cette UE vous semblent : [Utiles].2, dtype: object
# LU3ST068 28 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord',
#        'Pas du tout d'accord'],
#       dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Les documents de cette UE vous semblent : [Utiles]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST068/Question_10
# 0          Plutôt d'accord
# 1                      NaN
# 2          Plutôt d'accord
# 3                      NaN
# 4                      NaN
# 5      Plutôt pas d'accord
# 6          Plutôt d'accord
# 7                      NaN
# 8     Tout à fait d'accord
# 9     Tout à fait d'accord
# 10                     NaN
# 11     Plutôt pas d'accord
# 12         Plutôt d'accord
# 13         Plutôt d'accord
# 14                     NaN
# 15                     NaN
# 16         Plutôt d'accord
# 17         Plutôt d'accord
# 18                     NaN
# 19         Plutôt d'accord
# 20                     NaN
# 21     Plutôt pas d'accord
# 22    Pas du tout d'accord
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27    Tout à fait d'accord
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31         Plutôt d'accord
# Name: Les documents de cette UE vous semblent : [En quantité suffisante].2, dtype: object
# LU3ST068 28 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Plutôt pas d'accord', 'Tout à fait d'accord',
#        'Pas du tout d'accord'],
#       dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Les documents de cette UE vous semblent : [En quantité suffisante]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST068/Question_11
# UE :  LU3ST060
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST060/
# path :  /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST060/
# False
# 0     Non
# 1     Non
# 2     Non
# 3     Non
# 4     Non
# 5     Non
# 6     Oui
# 7     Oui
# 8     Oui
# 9     Non
# 10    Oui
# 11    Oui
# 12    Non
# 13    Non
# 14    Oui
# 15    Non
# 16    Non
# 17    Non
# 18    Oui
# 19    Non
# 20    Non
# 21    Non
# 22    Non
# 23    Non
# 24    Non
# 25    Oui
# 26    Oui
# 27    Non
# 28    Oui
# 29    Oui
# 30    Non
# 31    Non
# Name: Avez-vous suivi l'UE Climats et Paléoclimats (LU3ST060) ?, dtype: object
# LU3ST060 41 ['Oui', 'Non'] Index(['Non', 'Oui'], dtype='object')
# ['Oui', 'Non']
# Avez-vous suivi l'UE Climats et Paléoclimats (LU3ST060) ?
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST060/Question_0
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     Oui
# 7     Oui
# 8     Oui
# 9     NaN
# 10    Oui
# 11    Oui
# 12    NaN
# 13    NaN
# 14    Oui
# 15    NaN
# 16    NaN
# 17    NaN
# 18    Oui
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    Oui
# 26    Oui
# 27    NaN
# 28    Oui
# 29    Oui
# 30    NaN
# 31    NaN
# Name: Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés].2, dtype: object
# LU3ST060 41 ['Oui', 'Non'] Index(['Oui'], dtype='object')
# ['Oui']
# Que diriez-vous des objectifs de cette UE ? [Ils vous été présentés]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST060/Question_1
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     Oui
# 7     Oui
# 8     Oui
# 9     NaN
# 10    Oui
# 11    Oui
# 12    NaN
# 13    NaN
# 14    Oui
# 15    NaN
# 16    NaN
# 17    NaN
# 18    Oui
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    Oui
# 26    Oui
# 27    NaN
# 28    Oui
# 29    Oui
# 30    NaN
# 31    NaN
# Name: Que diriez-vous des objectifs de cette UE ? [Vous les avez compris].3, dtype: object
# LU3ST060 41 ['Oui', 'Non'] Index(['Oui'], dtype='object')
# ['Oui']
# Que diriez-vous des objectifs de cette UE ? [Vous les avez compris]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST060/Question_2
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6      Plutôt pas d'accord
# 7     Tout à fait d'accord
# 8          Plutôt d'accord
# 9                      NaN
# 10    Tout à fait d'accord
# 11    Tout à fait d'accord
# 12                     NaN
# 13                     NaN
# 14    Tout à fait d'accord
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18    Tout à fait d'accord
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25    Tout à fait d'accord
# 26    Tout à fait d'accord
# 27                     NaN
# 28    Tout à fait d'accord
# 29    Tout à fait d'accord
# 30                     NaN
# 31                     NaN
# Name: Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].2, dtype: object
# LU3ST060 41 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST060/Question_3
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6          Plutôt d'accord
# 7     Tout à fait d'accord
# 8          Plutôt d'accord
# 9                      NaN
# 10    Tout à fait d'accord
# 11    Tout à fait d'accord
# 12                     NaN
# 13                     NaN
# 14    Tout à fait d'accord
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18    Tout à fait d'accord
# 19                     NaN
# ...
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10    Tout à fait d'accord
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14         Plutôt d'accord
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18    Tout à fait d'accord
# 19                     NaN
# 20    Tout à fait d'accord
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31                     NaN
# Name: Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables.].5, dtype: object
# LU3ST602 80 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE [Le cours est bien adapté à vos connaissances et compétences préalables
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST602/Question_3
# 0                      NaN
# 1          Plutôt d'accord
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10    Tout à fait d'accord
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14    Tout à fait d'accord
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18         Plutôt d'accord
# 19                     NaN
# 20    Tout à fait d'accord
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31                     NaN
# Name: Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS].6, dtype: object
# LU3ST602 80 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE [La charge de travail est adéquate par rapport au nombre de crédits ECTS]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST602/Question_4
# 0                      NaN
# 1     Tout à fait d'accord
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10    Tout à fait d'accord
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14    Tout à fait d'accord
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18         Plutôt d'accord
# 19                     NaN
# 20    Tout à fait d'accord
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31                     NaN
# Name: Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE].6, dtype: object
# LU3ST602 80 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST602/Question_5
# 0                      NaN
# 1     Tout à fait d'accord
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10    Tout à fait d'accord
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14    Tout à fait d'accord
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18         Plutôt d'accord
# 19                     NaN
# 20    Tout à fait d'accord
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31                     NaN
# Name: Intérêt de l'UE [Les enseignements de cette UE vous ont intéressé.].6, dtype: object
# LU3ST602 80 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Intérêt de l'UE [Les enseignements de cette UE vous ont intéressé
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST602/Question_6
# 0                      NaN
# 1      Plutôt pas d'accord
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10    Pas du tout d'accord
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14     Plutôt pas d'accord
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18     Plutôt pas d'accord
# 19                     NaN
# 20    Tout à fait d'accord
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31                     NaN
# Name: Intérêt de l'UE [Les changements des activités liés à la crise sanitaire vous ont affecté ].5, dtype: object
# LU3ST602 80 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt pas d'accord', 'Tout à fait d'accord', 'Pas du tout d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Intérêt de l'UE [Les changements des activités liés à la crise sanitaire vous ont affecté ]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST602/Question_7
# 0                      NaN
# 1          Plutôt d'accord
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10    Tout à fait d'accord
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14    Tout à fait d'accord
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18         Plutôt d'accord
# 19                     NaN
# 20    Tout à fait d'accord
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN
# 30                     NaN
# 31                     NaN
# Name: Intérêt de l'UE [Vous avez apprécié les activités distancielles mises en place].6, dtype: object
# LU3ST602 80 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Intérêt de l'UE [Vous avez apprécié les activités distancielles mises en place]
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST602/Question_8
# 0             NaN
# 1     Assez clair
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10     Très clair
# 11            NaN
# 12            NaN
# 13            NaN
# 14     Assez flou
# 15            NaN
# 16            NaN
# 17            NaN
# 18     Assez flou
# 19            NaN
# 20     Très clair
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# 30            NaN
# 31            NaN
# Name: Le lien entre l'UE Stage Fablab et les autres enseignements du semestre vous parait-t-il?, dtype: object
# LU3ST602 80 ['Très clair', 'Assez clair', 'Assez flou', 'Très flou'] Index(['Très clair', 'Assez flou', 'Assez clair'], dtype='object')
# ['Très clair', 'Assez clair', 'Assez flou']
# Le lien entre l'UE Stage Fablab et les autres enseignements du semestre vous parait-t-il?
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST602/Question_9
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10    Excellente idée de projet que nous avons pu ré...
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20    C’est une des meilleures UE que je n’ai jamais...
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# 30                                                  NaN
# 31                                                  NaN
# Name: Avez-vous des commentaires à rajouter au sujet de cette UE?.6, dtype: object
# LU3ST602 80 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Excellente idée de projet que nous avons pu réaliser, hâte qu'il soit repris l'année prochaine et que nous puissions suivre cela, très bonne UE merci :)', 'C’est une des meilleures UE que je n’ai jamais suivi ! '], dtype='object')
# []
# Avez-vous des commentaires à rajouter au sujet de cette UE?
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST602/Question_10
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:79: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:79: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                              La géol c'est trop bien
# 11                                                  NaN
# 12                                                  NaN
# 13    J'ai une remarque plus générale concernant les...
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19    Tres difficile a mon sens car j'avais 6 jours ...
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28    Malgré la crise sanitaire, les cours de sont d...
# 29                                                  NaN
# 30                                                  NaN
# 31                                                  NaN
# Name: Avez-vous une remarque sur les UE complémentaires du Semestre 6 de la licence Sciences de la Terre?, dtype: object
# LU3ST602 80 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Malgré la crise sanitaire, les cours de sont dans l'ensemble bien déroulés. Je vous remercie pour avoir mis en place les dispositifs nécessaires au suivi des cours malgré la fermeture de la faculté. Je suis également très heureux qu'il soit possible de choisir ses UEs en mineur, de sorte à pouvoir suivre des cours uniquement sur la Terre externe lorsque cela nous intéresse plus que le reste. J'aurai cependant aimé pouvoir choisir encore plus d'ues de la Terre externe, notamment au S5 mais cela est un peu hors-sujet pour ce questionnaire. \nLes UEs étaient très intéressantes, et restent intéressantes à suivre malgré le contexte dans lequel elles se sont déroulées. ',
#        'Tres difficile a mon sens car j'avais 6 jours de cours par semaine et qu'il fallait que je fournisse un travail personnel très important bien plus que pour toutes mes années de licence science de la vie',
#        'La géol c'est trop bien',
#        'J'ai une remarque plus générale concernant les consultations de copies qui nous ont été proposées : elles n'ont pas eu lieu en Géochimie et pour la partie Sédimentologie de l'UE Géodynamique et environnements sédimentaires au S5 et elles n'ont également pas eu lieu pour l'UE DIG au S6. \nC'est dommage pour nous de ne pas pouvoir regarder la correction de nos professeurs et comprendre nos notes !'],
#       dtype='object')
# []
# Avez-vous une remarque sur les UE complémentaires du Semestre 6 de la licence Sciences de la Terre?
# /Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/d_figures/LU3ST602/Question_11
