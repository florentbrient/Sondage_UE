# %%
import matplotlib as mpl
from matplotlib import cm
import matplotlib.pyplot as plt
import pylab as plt
import pandas as pd
import numpy as np
import os


def colorFader(c1,c2,mix=0): #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1=np.array(mpl.colors.to_rgb(c1))
    c2=np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)

def _savefig(fig,ax,name='',title='',fts=10,xsize=(10,10),zmax=None):
    plt.xticks(size=fts)
    plt.yticks(size=fts)
    plt.title(title)
    fig.set_size_inches(xsize)
    fig.savefig(name + '.png')#,dpi='figure')
    fig.savefig(name + '.pdf', dpi=1000)
    plt.close()
    
def func(pct, allvals):
    absolute = int(round(pct/100.*np.sum(allvals)))
    return "{:.1f}%\n({:d} r)".format(pct, absolute)


path   = '/Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/Reponses/'
file   = 'Sondage UE Sciences de la Terre - Semestre 3.csv'
file   = path+file

pathfig = 'd_figures/'

df1    = pd.read_csv(file)
#df_eng = pd.read_excel('translate_FR.xlsx', header=1,encoding='latin1')
#df_eng = df_eng.set_axis(df_fr.columns.values.tolist(),axis='columns')
#df     = df_fr.append(df_eng, ignore_index=True, sort=False)

df     = df1
print(df)

questions=df.columns.values
# Out:
#                       Horodateur  \
# 0    2021/04/06 5:41:01 PM UTC+2
# 1    2021/04/06 5:42:04 PM UTC+2
# 2    2021/04/06 5:43:45 PM UTC+2
# 3    2021/04/06 5:45:56 PM UTC+2
# 4    2021/04/06 5:47:16 PM UTC+2
# 5    2021/04/06 5:49:03 PM UTC+2
# 6    2021/04/06 5:52:15 PM UTC+2
# 7    2021/04/06 5:58:42 PM UTC+2
# 8    2021/04/06 5:59:03 PM UTC+2
# 9    2021/04/06 6:03:37 PM UTC+2
# 10   2021/04/06 6:07:31 PM UTC+2
# 11   2021/04/06 6:14:09 PM UTC+2
# 12   2021/04/06 6:16:04 PM UTC+2
# 13   2021/04/06 6:17:42 PM UTC+2
# 14   2021/04/06 6:17:49 PM UTC+2
# 15   2021/04/06 6:20:35 PM UTC+2
# 16   2021/04/06 6:20:56 PM UTC+2
# 17   2021/04/06 6:24:26 PM UTC+2
# 18   2021/04/06 6:24:37 PM UTC+2
# 19   2021/04/06 6:29:29 PM UTC+2
# 20   2021/04/06 6:34:17 PM UTC+2
# 21   2021/04/06 6:39:21 PM UTC+2
# 22   2021/04/06 6:43:44 PM UTC+2
# 23   2021/04/06 6:48:28 PM UTC+2
# 24   2021/04/06 7:18:31 PM UTC+2
# 25   2021/04/06 7:34:36 PM UTC+2
# 26   2021/04/06 7:46:35 PM UTC+2
# ...

# %%
# Formation

pies     = [1]
New_name = ['Formation?']

c1='#1f77b4' #blue
c2='red' #green
n=4
colors2 = [colorFader(c1,c2,x/2)for x in range(2)]
colors4 = [colorFader(c1,c2,x/4)for x in range(4)]

labels0 = df[questions[pies[0]]].unique()
#['Majeure' 'Mineure Geosciences' 'Monodisciplinaire Sciences de la Terre'
# 'Bi-disciplinaire : Biologie - Mineure Sciences de la Terre (MEEF)']
    
labels1 = [labels0[0],labels0[1],labels0[2],labels0[3]]

dcolors = {labels0[0]: 'royalblue', #Majeure
           labels0[1]: 'red', #Mineure
           labels0[2]: 'gold', #Mono
           labels0[3]: 'green', #Bi
           }

figsize = (8, 5)

for ij,nbpie in enumerate(pies): 
    fig, ax = plt.subplots(1,figsize=figsize)

    data = df[questions[nbpie]].value_counts()#normalize=True)
    labels  = [ij.split(' ')[0] for ij in labels1 if ij in data.index] 
    print(labels)
    
    color = colors2
    print(len(data.unique()))
    if (len(data.unique())==4):
        color = colors4 
    
#    wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data)\
#                                          ,textprops=dict(color="w"), colors=color,startangle=0)
    wedges, texts, autotexts = ax.pie(data,labels=labels
                                  ,autopct=lambda pct: func(pct, data)
                                  ,colors=[dcolors[i] for i in data.index]
                                  ,textprops=dict(color="k"),startangle=90
                                  ,pctdistance=0.7, labeldistance=1.2
                                 )
    
    ax.legend(wedges, labels,
          loc="upper right",
          bbox_to_anchor=(1, 1, 0.5, -0.5))
          #title=questions[1],
    plt.setp(autotexts, size=10, weight="bold")

    title = New_name[ij]
    ax.set_title(title)
    
    name_file = pathfig+title.split('?')[0]
    print(title,name_file)
#plt.show()
    _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# ['Majeure', 'Mineure', 'Monodisciplinaire', 'Bi-disciplinaire']
# 4
# Formation? d_figures/Formation

# %%
#Find UEs
UEs = [(ij,question.replace(' ?','').split(' ')[-1]) for ij,question in enumerate(questions) if 'Avez-vous suivi' in question]
print(UEs)

# Make a selection (Subset of the poll)
#said_yes = df[df[questions[2]] == 'Oui']
#print(questions[5],said_yes)

subset = False
if subset:
  # Impose this selection
    pathfig = pathfig+'d_subset/'
    df      = said_yes
# Out:
# [(2, '(LU2ST301)'), (15, '(LU2ST303)?'), (28, '(LU2ST032)'), (41, '(LU2ST035)'), (54, '(LU2ST302)'), (67, '(LU2ST304)'), (80, '(LU2ST031)'), (93, '(LU2ST033)'), (106, '(LU2ST034)')]

# %%
UE_idx   = [ij[0] for ij in UEs] #[1,2,3,4,5,6,8,17,18]
UE_names = [ij[1].strip("()?") for ij in UEs] #['Profession?', 'Permanent?', 'Site?', 'Climaction?','Stratégie?','Quel objectif?',
            #'Individuel ou collectif?','Calculateur?','Influence recherche?'].replace('(','').replace(')','')

print(UE_idx,UE_names)
#colors2 = ['red', 'blue']
#a       = np.random.random(4)
#cs      = cm.Set1(np.arange(4)/4.)

c1='#1f77b4' #blue
c2='red' #green
n=4
colors2 = [colorFader(c1,c2,x/2)for x in range(2)]
colors4 = [colorFader(c1,c2,x/4)for x in range(4)]

Nb_questions = (UE_idx[1]-UE_idx[0])-1
print(Nb_questions)

figsize = (8, 5)

def _mkdir(path):
    print('path : ',path)
    print(os.path.exists(path))
    if not(os.path.exists(path)):
      os.mkdir(path)


for ij,idx in enumerate(UE_idx):
    UE = UE_names[ij]
    print('UE : ',UE)
    
    path_file = pathfig+UE+'/'
    print(path_file)
    _mkdir(path_file)
    
    for ik in range(Nb_questions):
      fig, ax = plt.subplots(1,figsize=figsize)

      data = df[questions[idx+ik]].value_counts() #normalize=True)        
      wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data)\
                                          ,textprops=dict(color="w"), colors=color,startangle=0)
    
      ax.legend(wedges, data.index,loc="center",bbox_to_anchor=(1, 1, 0.5, -0.5))
      plt.setp(autotexts, size=10, weight="bold")
    
      title = questions[idx+ik]
      ax.set_title(title)
      print(title)
    
      name_file = 'Question_'+str(ik)
      name_file = path_file + name_file
      print(name_file)
      _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# [2, 15, 28, 41, 54, 67, 80, 93, 106] ['LU2ST301', 'LU2ST303', 'LU2ST032', 'LU2ST035', 'LU2ST302', 'LU2ST304', 'LU2ST031', 'LU2ST033', 'LU2ST034']
# 12
# UE :  LU2ST301
# d_figures/LU2ST301/
# path :  d_figures/LU2ST301/
# Avez-vous suivi l'UE Cartographie/SIG (LU2ST301) ?
# d_figures/LU2ST301/Question_0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-3d3eaff0c951> in <module>
#      51       name_file = path_file + name_file
#      52       print(name_file)
# ---> 53       _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
#      54
#      55
#
# <ipython-input-1-44b50ecc4fbe> in _savefig(fig, ax, name, title, fts, xsize, zmax)
#      18     plt.title(title)
#      19     fig.set_size_inches(xsize)
# ---> 20     fig.savefig(name + '.png')#,dpi='figure')
#      21     fig.savefig(name + '.pdf', dpi=1000)
#      22     plt.close()
#
# ...

# %%
pies     = [7]
new_df = df[questions[pies[0]]].str.split(';', expand=True)
nb     = new_df.shape
print('Nb réponses : ',new_df.shape[0])
print(df[questions[pies[0]]].value_counts())
action = new_df.stack().value_counts()/new_df.shape[0]

figsize2 = (12, 5)
fig, ax  = plt.subplots(1,figsize=figsize2)
#action[:2].plot(kind='barh', figsize=(7,7), color="#61d199")

print(action[:2])
ax.barh(action.index[:2],100.*action[:2], color="#61d199")

#plt.setp(autotexts, size=10, weight="bold")
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Pourcentage (%)')

title=questions[pies[0]]
name_file=pathfig+'Moyens_Modalites'
_savefig(fig,ax,title=title,name=name_file,xsize=figsize2)

#plt.show()
# Out:
# Nb réponses :  48
# Plutôt d'accord         18
# Plutôt pas d'accord     17
# Tout à fait d'accord     7
# Pas du tout d'accord     6
# Name: Contenu de l'UE [Les modalités d’évaluation sont adaptées avec les objectifs de l’UE], dtype: int64
# Plutôt d'accord        0.375000
# Plutôt pas d'accord    0.354167
# dtype: float64

# %%
print(df[questions[10]].str.contains('Missions').value_counts())
print(df[questions[10]].str.contains('Campagnes').value_counts())
print(df[questions[10]].str.contains('Calcul').value_counts())
print(df[questions[10]].str.contains('Achats').value_counts())
print(df[questions[10]].str.contains('Déplacements').value_counts())
print(df[questions[10]])

# %%
new_df   = df[questions[10]].str.split(';', expand=True)
emission = new_df.stack().value_counts()
data     = emission 
data     = data[data>1]
print(data.index)

labels0 = ['Missions (hors campagnes de terrain)',
       'Bâtiments/chauffage/climatisation', 'Calcul et stockage numérique',
       'Campagnes de terrain', 'Déplacements domicile/travail', 'Achats']
#labels1 = [data.index[5],data.index[2],data.index[3]
#          ,data.index[0],data.index[4],data.index[1]]
labels1 = [labels0[5],labels0[2],labels0[3]
          ,labels0[0],labels0[4],labels0[1]]

labels  = [ij for ij in labels1 if ij in data.index]
#[data.index[5],data.index[2],data.index[3]
#          ,data.index[0],data.index[4],data.index[1]]

dcolors = {labels0[0]: 'royalblue', #Mission
           labels0[1]: 'sandybrown', #Batiments
           labels0[2]: 'violet', #Calcul
           labels0[3]: 'magenta', #Campagnes
           labels0[4]: 'deepskyblue', #dom/travail
           labels0[5]: 'green', #achats
           }

fig, ax = plt.subplots(1,figsize=figsize2) #, subplot_kw=dict(aspect="equal"))
wedges, texts, autotexts = ax.pie(data,labels=labels
                                  ,autopct=lambda pct: func(pct, data)
                                  ,colors=[dcolors[i] for i in data.index]
                                  ,textprops=dict(color="w"),startangle=90
                                  ,pctdistance=0.7, labeldistance=1.2
                                 )

centre_circle = plt.Circle((0,0),0.50,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

ax.legend(wedges, data.index,
      loc="center",
      bbox_to_anchor=(1, 1, 0.5, -0.5))
plt.setp(autotexts, size=10, weight="bold")

ax.axis('equal') 

title = questions[10]
ax.set_title(title)
plt.tight_layout()


name_file = pathfig+'Postes_Emetteurs'
print(title,name_file)

_savefig(fig,ax,title=title,name=name_file,xsize=figsize)

# %%
pies     = [11,12,13,14,15,16]

#fig, ax = plt.subplots(len(pies),figsize=(30, 35), subplot_kw=dict(aspect="equal"))

keys = ['Ne pas toucher','Plutôt pas d\'accord','Plutôt d\'accord','Priorité']
sizes=len(keys)

cmap = plt.cm.RdYlGn
colors = cmap(np.linspace(0., 1., sizes))
print(colors)

gcolors=dict()
for ij,key in enumerate(keys):
    gcolors[key]=colors[ij]

#gcolors = {'Ne pas toucher': 'firebrick', 'Plutôt pas d\'accord': 'tomato'
#          ,'Plutôt d\'accord': 'lightgreen', 'Priorité': 'forestgreen'}
print(gcolors)

for ij,nbpie in enumerate(pies):
    fig, ax = plt.subplots(1, 1, figsize=figsize)
    fig.subplots_adjust(hspace = .5, wspace=.001)
#    ax = ax.ravel()

    data = df[questions[nbpie]].value_counts()#.sort_index(key=lambda x: [x for x in gcolors.keys()])#normalize=True)

    name = data.name.split('[')[1][:-1]
    labels=[ij for ij in gcolors if ij in data.index]
    
    data = data.reindex(labels) #gcolors.keys())
    wedges, texts, autotexts = ax.pie(data
                                          ,autopct=lambda pct: func(pct, data)
                                          ,colors=[gcolors[i] for i in data.index]
                                          ,textprops=dict(color="w"), startangle=0)
                                          #,wedgeprops={'alpha':0.8}) #,explode=(0, 0, 0.1, 0))
    #if ij==2:
    ax.legend(wedges, data.index,
            loc="center",
            bbox_to_anchor=(1, 1, 0.5, -0.5))
    plt.setp(autotexts, size=10, weight="bold")
    
    title = name
    ax.set_title(title)
    name_file = pathfig+'Strategie'+title.split('?')[0].split('/')[0]
    
    print(title,name_file)
    _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
    
#plt.show()
