# %%
import matplotlib as mpl
from matplotlib import cm
import matplotlib.pyplot as plt
import pylab as plt
import pandas as pd
import numpy as np
import os


def colorFader(c1,c2,mix=0): #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1=np.array(mpl.colors.to_rgb(c1))
    c2=np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)

def _savefig(fig,ax,name='',title='',fts=10,xsize=(10,10),zmax=None):
    plt.xticks(size=fts)
    plt.yticks(size=fts)
    plt.title(title)
    fig.set_size_inches(xsize)
    fig.savefig(name + '.png')#,dpi='figure')
    fig.savefig(name + '.pdf', dpi=1000)
    plt.close()
    
def func(pct, allvals):
    absolute = int(round(pct/100.*np.sum(allvals)))
    return "{:.1f}%\n({:d} r)".format(pct, absolute)

def _mkdir(path):
    print('path : ',path)
    print(os.path.exists(path))
    if not(os.path.exists(path)):
      os.mkdir(path)

Semestre = 5 #4 #5 #1
Sem_ch   = str(Semestre)

#For S6 only
complementaire = True

pathini = '/Users/fbrient/'
#pathini = '/home/fbrient/'
path    = pathini+'Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S'+Sem_ch+'/'

fileadd = []
file    = 'Responses_S'+Sem_ch+'_2024_2025.xlsx' #'Sondage UE Sciences de la Terre - Semestre '+str(Semestre)+'.csv'


#if Semestre == 4:
#  file  = 'Sondage UE Sciences de la Terre - Semestre '+str(Semestre)+' - v2.csv'
#elif Semestre == 5: 
#  fileadd   = []
  #fileadd   = 'Sondage UE Sciences de la Terre - Ressources.csv'
  #fileadd   = 'Sondage UE Sciences de la Terre - Océanographie.csv'
#  fileadd   = 'Sondage UE Sciences de la Terre - Biodiversité et Paléobiodiversité.csv'
   #[ 'Sondage UE Sciences de la Terre - Ressources.csv'
             #,'Sondage UE Sciences de la Terre - Océanographie.csv'
             #,'Sondage UE Sciences de la Terre - Biodiversité et Paléobiodiversité.csv']
#if Semestre == 6 and complementaire: 
#    file   = 'Responses_S'+Sem_ch+'_2021_2022_complementaires.xlsx'

suffix = ''
#if len(fileadd)>0:
#    suffix = '_'+fileadd.split(' ')[-1].split('.')[0] 
#    file   = fileadd
#print(file,fileadd,suffix)

file   = path+file
print('file : ',file)

pathfig0 = path #'/Users/florentbrient/Dropbox/Enseignements/2020_2021/Responsable_Eval/Sondage/'
pathfig  = pathfig0+'d_figures/'
_mkdir(pathfig)

#df1    = pd.read_csv(file)
df1    = pd.read_excel(file)
#print(type(df1))
if len(fileadd)>0:
    for tmp in fileadd:
        print(tmp)
        df_tmp = pd.read_excel(path+tmp)
        #print(df_tmp)
        df1 = pd.concat([df1,df_tmp], axis=1) #, sort=False )#ignore_index=True) #, sort=False)
#df_eng = pd.read_excel('translate_FR.xlsx', header=1,encoding='latin1')
#df_eng = df_eng.set_axis(df_fr.columns.values.tolist(),axis='columns')
#df     = df_fr.append(df_eng, ignore_index=True, sort=False)

df     = df1
#print(df)

questions=df.columns.values
print(questions)
# Out:
# file :  /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/Responses_S3_2024_2025.xlsx
# path :  /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/
# True
# ['Submission Date' 'Quelle formation suivez-vous ?'
#  'Quel UE avez-vous suivi ?'
#  'Quel est votre ressenti général de ce semestre ?'
#  "Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés"
#  "Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante"
#  'Les enseignements de cette UE vous ont intéressé ?'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE ?'
#  "Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.1"
#  "Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.1"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.1"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.1"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.1"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.1"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.1"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.1"
#  'Les enseignements de cette UE vous ont intéressé'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE ?.1'
#  "Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.2"
#  "Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.2"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.2"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.2"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.2"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.2"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.2"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.2"
#  'Les enseignements de cette UE vous ont intéressé.1'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE ?.2'
#  "Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.3"
#  "Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.3"
#  "Contenu de l'UE >> Le terrain est adapté à vos connaissances et compétences préalables"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.3"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.3"
#  "Contenu de l'UE >> Le lien entre l'UE Escalade et les autres enseignements est clair"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.3"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.3"
#  'Les enseignements de cette UE vous ont intéressé.2'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?'
#  "Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés"
#  "Que diriez-vous des objectifs de l'UE? >> Vous les avez compris"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.3"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.4"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.4"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.3"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.4"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.4"
#  'Les enseignements de cette UE vous ont intéressé.3'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.1'
#  "Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés.1"
#  "Que diriez-vous des objectifs de l'UE? >> Vous les avez compris.1"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.4"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.5"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.5"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.4"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.5"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.5"
#  'Les enseignements de cette UE vous ont intéressé.4'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.2'
#  "Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés.2"
#  "Que diriez-vous des objectifs de l'UE? >> Vous les avez compris.2"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.5"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.6"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.6"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.5"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.6"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.6"
#  'Les enseignements de cette UE vous ont intéressé.5'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.3'
#  "Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés.3"
#  "Que diriez-vous des objectifs de l'UE? >> Vous les avez compris.3"
#  "Contenu de l'UE >> Le terrain est adapté à vos connaissances et compétences préalables.1"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.7"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.7"
#  "Contenu de l'UE >> Le lien entre l'UE Terrain et les autres enseignements est clair"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.7"
#  "Contenu de l'UE >> Ce stage ne présente pas de difficulté physique"
#  "Contenu de l'UE >> La séance de préparation au stage vous a été utile"
#  'Les enseignements de cette UE vous ont intéressé.6'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.4'
#  "Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés.4"
#  "Que diriez-vous des objectifs de l'UE? >> Vous les avez compris.4"
#  "Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.6"
#  "Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.8"
#  "Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.8"
#  "Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.6"
#  "Contenu de l'UE >> Les documents de l'UE sont utiles.8"
#  "Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.7"
#  'Les enseignements de cette UE vous ont intéressé.7'
#  'Avez-vous des commentaires à rajouter au sujet de cette UE?.5'
#  "Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Hydraulique et SIG >> Présentés ?"
#  "Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Hydraulique et SIG >> Compris ?"
#  "Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Microbiologie de l'eau >> Présentés ?"
#  "Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Microbiologie de l'eau >> Compris ?"
#  "Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> TRE (Tech. Rech. Entr.) >> Présentés ?"
#  "Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> TRE (Tech. Rech. Entr.) >> Compris ?"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> Le cours est adapté à vos connaissances et compétences préalables >> Hydraulique et SIG"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> Le cours est adapté à vos connaissances et compétences préalables >> Microbiologie de l'eau"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> Le cours est adapté à vos connaissances et compétences préalables >> TRE (Tech. Rech. Entr.)"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> La charge de travail est adéquate pour le nombre d'ECTS >> Hydraulique et SIG"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> La charge de travail est adéquate pour le nombre d'ECTS >> Microbiologie de l'eau"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> La charge de travail est adéquate pour le nombre d'ECTS >> TRE (Tech. Rech. Entr.)"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE >> Hydraulique et SIG"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE >> Microbiologie de l'eau"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE >> TRE (Tech. Rech. Entr.)"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> L'enseignement (cours, TP, TD) forme un tout cohérent >> Hydraulique et SIG"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> L'enseignement (cours, TP, TD) forme un tout cohérent >> Microbiologie de l'eau"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> L'enseignement (cours, TP, TD) forme un tout cohérent >> TRE (Tech. Rech. Entr.)"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> Les documents de l'UE sont utiles >> Hydraulique et SIG"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> Les documents de l'UE sont utiles >> Microbiologie de l'eau"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> Les documents de l'UE sont utiles >> TRE (Tech. Rech. Entr.)"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> Les documents de l'UE sont en quantité suffisante >> Hydraulique et SIG"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> Les documents de l'UE sont en quantité suffisante >> Microbiologie de l'eau"
#  "Contenus des UE (Cocher si vous êtes d'accord) >> Les documents de l'UE sont en quantité suffisante >> TRE (Tech. Rech. Entr.)"
#  "Les enseignements de l'UE Hydryalique et SIG vous ont intéressé"
#  "Les enseignements de l'UE Microbiologie de l'eau vous ont intéressé"
#  "Les enseignements de l'UE TRE (Tech. Rech. Entr.) vous ont intéressé"
#  'Avez-vous des commentaires à rajouter les UEs RQEE (Hydraulique, Microbiologie, TRE) ?'
#  'Avez-vous des commentaires à rajouter sur le semestre 3 de votre licence Sciences de la Terre ?']

# %%
# Formation

pies     = [1]
New_name = ['Formation?']

c1='#1f77b4' #blue
c2='red' #green
n=4
colors2 = [colorFader(c1,c2,x/2)for x in range(2)]
colors4 = [colorFader(c1,c2,x/4)for x in range(4)]

#print(df[questions[pies[0]]])
formation = df[questions[pies[0]]]#.squeeze(axis=1)
if len(formation.shape)>1:
    print(formation.shape)
    print(formation.iloc[:,[0]])
    formation=formation.iloc[:,[0]].squeeze()
print(formation.shape)

print(type(formation))
labels0 = formation.unique()
print(labels0)
#['Majeure' 'Mineure Geosciences' 'Monodisciplinaire Sciences de la Terre'
# 'Bi-disciplinaire : Biologie - Mineure Sciences de la Terre (MEEF)']
    

colors  = ['royalblue','red','gold','green','purple','cyan']
colors_save = colors

figsize = (8, 5)

for ij,nbpie in enumerate(pies): 
    fig, ax = plt.subplots(1,figsize=figsize)

    #data = df[questions[nbpie]].value_counts()#normalize=True)
    data = formation.value_counts()#normalize=True)
    print(data)
    for ik in data.index:
       data = data.rename(index={ik:ik.split(' ')[0]})
    print(data)
    
    labels  = data.index #[ij.split(' ')[0] for ij in labels0 if ij in data.index]  
    print(labels,data.index)#,dcolors)
    
        
    gcolors = dict()
    keys    = labels
    for ik,key in enumerate(keys):
        print(ik, key)
        gcolors[key]=colors[ik]
    print(gcolors)
    labels = [ik for ik in gcolors if ik in data.index]
    data   = data.reindex(labels)
    print(labels)
    
    wedges, texts, autotexts = ax.pie(data,labels=labels
                                  ,autopct=lambda pct: func(pct, data)
                                  ,colors=[gcolors[i] for i in data.index]
                                  ,textprops=dict(color="k"),startangle=90
                                  ,pctdistance=0.7, labeldistance=1.2
                                 )
    print(ax.xaxis.get_label())
    ax.legend(wedges, labels,
          loc="upper right",
          bbox_to_anchor=(1, 1, 0.5, -0.5))
          #title=questions[1],
    plt.setp(autotexts, size=10, weight="bold")

    title = New_name[ij]
    ax.set_title(title)
    
    name_file = pathfig+title.split('?')[0]+'_Semestre'+Sem_ch+suffix
    print(title,name_file)
#plt.show()
    _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# (39,)
# <class 'pandas.core.series.Series'>
# ['Majeure' 'Licence Pro RQEE' 'Mono' 'Mineure' 'Double Majeure' 'L4']
# Quelle formation suivez-vous ?
# Mono                15
# Majeure             10
# Mineure             10
# Licence Pro RQEE     2
# Double Majeure       1
# L4                   1
# Name: count, dtype: int64
# Quelle formation suivez-vous ?
# Mono       15
# Majeure    10
# Mineure    10
# Licence     2
# Double      1
# L4          1
# Name: count, dtype: int64
# Index(['Mono', 'Majeure', 'Mineure', 'Licence', 'Double', 'L4'], dtype='object', name='Quelle formation suivez-vous ?') Index(['Mono', 'Majeure', 'Mineure', 'Licence', 'Double', 'L4'], dtype='object', name='Quelle formation suivez-vous ?')
# 0 Mono
# 1 Majeure
# 2 Mineure
# 3 Licence
# 4 Double
# 5 L4
# {'Mono': 'royalblue', 'Majeure': 'red', 'Mineure': 'gold', 'Licence': 'green', 'Double': 'purple', 'L4': 'cyan'}
# ['Mono', 'Majeure', 'Mineure', 'Licence', 'Double', 'L4']
# Text(0.5, 0, '')
# Formation? /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/Formation_Semestre3

# %%
# Ressenti

pies     = [3]
New_name = ['Ressenti?']
colors5 = [colorFader(c1,c2,x/4)for x in range(5)]
colors  =  colors5 #['royalblue','red','gold','green','purple','cyan']


#print(df[questions[pies[0]]])
formation = df[questions[pies[0]]]#.squeeze(axis=1)
if len(formation.shape)>1:
    print(formation.shape)
    print(formation.iloc[:,[0]])
    formation=formation.iloc[:,[0]].squeeze()
print(formation.shape)

print(type(formation))
labels0 = formation.unique()
print(labels0)
    

#colors_save = colors
#ci1=c2
#ci2='green'
#colors_save = [colorFader(ci1,ci2,x/4)for x in range(5)]
#colors = colors_save

cmap = plt.cm.coolwarm_r
NL   = 5 
colors = cmap(np.linspace(0., 0.95, NL))
colors_save = colors

figsize = (8, 5)

for ij,nbpie in enumerate(pies): 
    fig, ax = plt.subplots(1,figsize=figsize)

    #data = df[questions[nbpie]].value_counts()#normalize=True)
    data = formation.value_counts()#normalize=True)
    print(data)
    #for ik in data.index:
    #   data = data.rename(index={ik:ik.split(' ')[0]})
    mean = formation.mean()
    
    labels  = data.index #[ij.split(' ')[0] for ij in labels0 if ij in data.index]  
    print(labels,data.index)#,dcolors)
    
        
    gcolors = dict()
    keys_ressenti = [1,2,3,4,5]
    keys    = keys_ressenti #labels
    for ik,key in enumerate(keys):
        print(ik, key)
        gcolors[key]=colors[ik]
    print(gcolors)
    labels = [ik for ik in gcolors if ik in data.index]
    data   = data.reindex(labels)
    print(labels)
    
    wedges, texts, autotexts = ax.pie(data,labels=labels
                                  ,autopct=lambda pct: func(pct, data)
                                  ,colors=[gcolors[i] for i in data.index]
                                  ,textprops=dict(color="k"),startangle=90
                                  ,pctdistance=0.7, labeldistance=1.2
                                 )
    print(ax.xaxis.get_label())
    ax.legend(wedges, labels,
          loc="upper right",
          bbox_to_anchor=(1, 1, 0.5, -0.5))
          #title=questions[1],
    plt.setp(autotexts, size=10, weight="bold")

    title = New_name[ij]+' ('+"{:.2f}".format(mean)+'/5)'
    ax.set_title(title)
    
    name_file = pathfig+title.split('?')[0]+'_Semestre'+Sem_ch+suffix
    print(title,name_file)
#plt.show()
    _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# (39,)
# <class 'pandas.core.series.Series'>
# [2 5 4 3]
# Quel est votre ressenti général de ce semestre ?
# 4    19
# 5     9
# 3     9
# 2     2
# Name: count, dtype: int64
# Index([4, 5, 3, 2], dtype='int64', name='Quel est votre ressenti général de ce semestre ?') Index([4, 5, 3, 2], dtype='int64', name='Quel est votre ressenti général de ce semestre ?')
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5
# {1: array([0.70567316, 0.01555616, 0.15023281, 1.        ]), 2: array([0.95125379, 0.57879939, 0.45940781, 1.        ]), 3: array([0.89181689, 0.85197328, 0.82908527, 1.        ]), 4: array([0.60316207, 0.73152748, 0.99956528, 1.        ]), 5: array([0.28527278, 0.38012942, 0.82346855, 1.        ])}
# [2, 3, 4, 5]
# Text(0.5, 0, '')
# Ressenti? (3.90/5) /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/Ressenti_Semestre3

# %%
#Find UEs
import itertools

if Semestre == 3:
    UEs = ['LU2ST031','LU2ST032','LU2ST033','LU2ST034',\
           'LU2ST035','LU2ST301','LU2ST302','LU2ST303',\
           'LU2ST304','RQEE']
if Semestre == 4:
    UEs = ['LU2ST041','LU2ST042','LU2ST043','LU2ST044',\
           'LU2ST045','LU2ST421','LU2ST401','LU2ST402',\
           'LU2ST403S','LU2ST403T','LU2ST404']
if Semestre == 5:
    UEs = ['LU3ST053','LU3ST055','LU3ST056','LU3ST057',\
           'LU3ST058','LU3ST059','LU3ST501','LU3ST502',\
           'LU3ST507','LU3STOIP']
if Semestre == 6:
    UEs = ['LU3ST060','LU3ST061','LU3ST062','LU3ST063',\
           'LU3ST066','LU3ST068','LU3ST069','LU3ST603',\
           'LU3ST605','LU3ST606','LU3ST607','LU3ST608',\
           'LU3ST609','LU3ST613','LU3ST614','LU3ST615',\
           'LU3ST621']
print(UEs)

# Find start of each UE
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présenté
sentence = "Que diriez-vous des objectifs de l'UE"
word     = "résenté" # Présenté ou présenté
UEs0 = [(ij,question.replace(' ?','').split(' ')[-1]) for ij,question in enumerate(questions) if ((sentence in question) and (word in question))]
print(UEs0)
# Out:
# ['LU2ST031', 'LU2ST032', 'LU2ST033', 'LU2ST034', 'LU2ST035', 'LU2ST301', 'LU2ST302', 'LU2ST303', 'LU2ST304', 'RQEE']
# [(4, 'présentés'), (14, 'présentés.1'), (24, 'présentés.2'), (34, 'présentés.3'), (44, 'présentés'), (54, 'présentés.1'), (64, 'présentés.2'), (74, 'présentés.3'), (85, 'présentés.4'), (95, 'Présentés'), (97, 'Présentés'), (99, 'Présentés')]

# %%
#UE_idx   = [ij[0] for ij in UEs] #[1,2,3,4,5,6,8,17,18]
#UE_names = [ij[1].strip("()?") for ij in UEs] #['Profession?', 'Permanent?', 'Site?', 'Climaction?','Stratégie?','Quel objectif?',
#            #'Individuel ou collectif?','Calculateur?','Influence recherche?'].replace('(','').replace(')','')

#UE_idx   = range(len(UEs))
UE_idx   = [ij[0] for ij in UEs0] 
UE_names = UEs

print(UE_idx,UE_names)
#colors2 = ['red', 'blue']
#a       = np.random.random(4)
#cs      = cm.Set1(np.arange(4)/4.)

keys1 = ['OUI','NON']
#keys2 = ['Tout à fait d\'accord','Plutôt d\'accord','Plutôt pas d\'accord','Pas du tout d\'accord']
keys2 = ['Tout à fait d\'accord','Plutôt d\'accord','Plutôt pas d\'accord','Pas du tout d\'accord']

# Changing key for specific question
tabword = ['intéressé']
keys3   = keys_ressenti

# Changing for Mineralogie
tabword2 = ['heures']
keys5    = ['< 1','De 1h à 2h', 'De 2h à 3h','> 3h']

#Idx_change = [9]
#tabword = ['cohérence','lien entre']
#keys3 = ['Bonne','Plutôt bonne','Plutôt mauvaise','Mauvaise']

# Changing answers for specific question
#UE_change  = ['LU2ST034','LU2ST303','LU2ST352','LU2ST044','LU2ST402','LU3ST603','LU3ST602']
#keys4 = ['Très clair','Assez clair','Assez flou','Très flou']

# Changing answers for S1
#tabword2 = ['capsules']
#keys5 = ['Oui, beaucoup (> 10 vidéos)','Oui, certaines (5-10 vidéos)',\
#'Quelques unes (1-4 vidéos)','Non, mais je sais qu\'elles existaient',\
#'Non, car je ne savais pas qu\'il y avait des capsules vidéos de soutien']
#tabword3 = ['Ces vidéos']
#keys6 = ['Oui, le plus souvent','Oui, certaines',\
#         'Non, même si je les ai visionnées','Non, car pas visionnées']

# Changing answers for S6
#tabword4 = ['Vous sentez-vous','lien existant entre disciplines']
#keys7 = ['Oui','Pas d\'avis','Non']

#tabword5 = ['davantage de TP']
#keys8 = ['Davantage de TD et exercices “sur papier” encadrés',\
#         'Je ne changerais rien',\
#         'Davantage de TP en salle informatique',\
#        ]

# Changing answers for S5 (OIP)
tabword6 = ['avenir professionnel']
keys9 = ['Utile','Pas d\'avis particulier', 'Pas utile']

#keys6 = ['Oui, beaucoup (> 10 vidéos)','Oui, certaines (5-10 vidéos)',\
#'Quelques unes (1-4 vidéos)','Non, mais je sais qu\'elles existaient',\
#'Non, car je ne savais pas qu\'il y avait des capsules vidéos de soutien']

print(tabword)

# 9 questions !
Nb_questions = 15 #(UE_idx[1]-UE_idx[0])-1
ofs          = 4 # Nombre de questions non UE (avis general Licence, parcours, UE suivis)
if Semestre == 1:
    Nb_questions = 19
if Semestre == 5:
    Nb_questions = 17
if Semestre == 6:
    Nb_questions = 10
print(Nb_questions)

figsize = (8, 5)

for ij,idx in enumerate(UE_idx):
    UE = UE_names[ij]
    print('UE : ',UE)
    
    path_file = pathfig+UE+'/'
    print(path_file)
    _mkdir(path_file)
    
    for ik in range(Nb_questions):
      fig, ax = plt.subplots(1,figsize=figsize)

      # Offset + (NumUE*(NB questions+1)) +ik
      #idx1    = ofs+(idx*(Nb_questions+1))+ik
      idx1    = idx+ik
      data    = df[questions[idx1]]

      #data = data.replace('\\','')
      data = data.replace('Tout à fait d\\\'accord','Tout à fait d\'accord')
      data = data.replace('Plutôt d\\\'accord','Plutôt d\'accord')
      data = data.replace('Plutôt pas d\\\'accord','Plutôt pas d\'accord')
      data = data.replace('Pas du tout d\\\'accord','Pas du tout d\'accord')
      data = data.replace('Pas d\\\'avis particulier','Pas d\'avis particulier')

        
      #data = data.replace('d\\\'accord','d\\\'accord')
      #data = data.replace('è','\'e')
      #data = data.replace('Très','Tr\'es')
      data0 = data.value_counts() #normalize=True) 
                
      print('Data : ',data0)
      #colors = colors2 ; 
      changecolor = 0
      keys = keys1
      if ('OUI' in data0.keys()):
        keys = keys1
      else:
        keys = keys2
        #if ik in Idx_change:
        #print('tabword ',tabword,questions[idx1])
        print('tabword ',[ii in questions[idx1] for ii in tabword])
        if (any([ii in questions[idx1] for ii in tabword]) 
           and not(any([ii in questions[idx1] for ii in ['laboratoire'] ])) ):
        #if 'cohérence' in questions[idx+ik]:
            keys = keys3
            changecolor = 1 # cas intéressé
            #if UE in UE_change:
            #    keys = keys4
        elif any([ii in questions[idx1] for ii in tabword2]):
            keys = keys5
        #elif any([ii in questions[idx1] for ii in tabword3]):
        #    keys = keys6
      #if any([ii in questions[idx1] for ii in tabword4]):
      #      keys = keys7
      #if any([ii in questions[idx1] for ii in tabword5]):
      #      keys = keys8
      if any([ii in questions[idx1] for ii in tabword6]):
            keys = keys9
      print(UE,idx,keys,data0.index)

      #import difflib
      #output_list = [li for li in difflib.ndiff('c\'e','ce') if li[0] != ' ']
      #print(output_list)
        
      cmap = plt.cm.bwr
      colors = cmap(np.linspace(0., 0.95, len(keys)))
      if changecolor:
          colors = colors_save 
  
      gcolors=dict()
      for ij,key in enumerate(keys):
        gcolors[key]=colors[ij]
      labels = [ij for ij in gcolors if ij in data0.index]
      data0   = data0.reindex(labels)
      print(labels)
        
      wedges, texts, autotexts = ax.pie(data0,autopct=lambda pct: func(pct, data0)\
                                            ,colors=[gcolors[i] for i in data0.index]\
                                            ,textprops=dict(color="w") #, colors=color
                                            ,startangle=0)
    
      ax.legend(wedges, data0.index,loc="best",bbox_to_anchor=(1, 1, 0.5, -0.5))
      plt.setp(autotexts, size=10, weight="bold")
    
      title = questions[idx1].split('.')[0]
      if any([ii in questions[idx1] for ii in tabword]): # intéressé
          try:
            mean   = np.nanmean(data)
            title += ' ('+"{:.2f}".format(mean)+'/5)'
          except:
            pass

      ax.set_title(title)
      print(title)
    
      name_file = 'Question_'+str(ik)
      name_file = path_file + name_file
      print(name_file)
      _savefig(fig,ax,title=title,name=name_file,xsize=figsize)
# Out:
# [4, 14, 24, 34, 44, 54, 64, 74, 85, 95, 97, 99] ['LU2ST031', 'LU2ST032', 'LU2ST033', 'LU2ST034', 'LU2ST035', 'LU2ST301', 'LU2ST302', 'LU2ST303', 'LU2ST304', 'RQEE']
# ['intéressé']
# 15
# UE :  LU2ST031
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/
# path :  /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/
# False
# Data :  Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# OUI    13
# NON     1
# Name: count, dtype: int64
# LU2ST031 4 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/Question_0
# Data :  Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# OUI    10
# NON     4
# Name: count, dtype: int64
# LU2ST031 4 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/Question_1
# Data :  Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# Plutôt d'accord         8
# Plutôt pas d'accord     4
# Tout à fait d'accord    1
# Pas du tout d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST031 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Plutôt pas d'accord', 'Tout à fait d'accord',
#        'Pas du tout d'accord'],
#       dtype='object', name='Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/Question_2
# Data :  Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# Plutôt pas d'accord     5
# Plutôt d'accord         4
# Pas du tout d'accord    3
# Tout à fait d'accord    2
# Name: count, dtype: int64
# tabword  [False]
# LU2ST031 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt pas d'accord', 'Plutôt d'accord', 'Pas du tout d'accord',
#        'Tout à fait d'accord'],
#       dtype='object', name='Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/Question_3
# Data :  Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# Plutôt pas d'accord     4
# Pas du tout d'accord    4
# Plutôt d'accord         3
# Tout à fait d'accord    3
# Name: count, dtype: int64
# tabword  [False]
# LU2ST031 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt pas d'accord', 'Pas du tout d'accord', 'Plutôt d'accord',
#        'Tout à fait d'accord'],
#       dtype='object', name='Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/Question_4
# Data :  Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# Plutôt d'accord         6
# Plutôt pas d'accord     4
# Tout à fait d'accord    3
# Pas du tout d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST031 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Plutôt pas d'accord', 'Tout à fait d'accord',
#        'Pas du tout d'accord'],
#       dtype='object', name='Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/Question_5
# Data :  Contenu de l'UE >> Les documents de l'UE sont utiles
# Tout à fait d'accord    5
# Plutôt pas d'accord     4
# Plutôt d'accord         3
# Pas du tout d'accord    2
# Name: count, dtype: int64
# tabword  [False]
# LU2ST031 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt pas d'accord', 'Plutôt d'accord',
#        'Pas du tout d'accord'],
#       dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont utiles')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont utiles
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/Question_6
# Data :  Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# Tout à fait d'accord    6
# Plutôt d'accord         4
# Pas du tout d'accord    2
# Plutôt pas d'accord     2
# Name: count, dtype: int64
# tabword  [False]
# LU2ST031 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Pas du tout d'accord',
#        'Plutôt pas d'accord'],
#       dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/Question_7
# Data :  Les enseignements de cette UE vous ont intéressé ?
# 3.0    5
# 5.0    3
# 2.0    3
# 4.0    2
# 1.0    1
# Name: count, dtype: int64
# tabword  [True]
# LU2ST031 4 [1, 2, 3, 4, 5] Index([3.0, 5.0, 2.0, 4.0, 1.0], dtype='float64', name='Les enseignements de cette UE vous ont intéressé ?')
# [1, 2, 3, 4, 5]
# Les enseignements de cette UE vous ont intéressé ? (3.21/5)
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/Question_8
# Data :  Avez-vous des commentaires à rajouter au sujet de cette UE ?
# Le partiel de fin de semestre avait un niveau beaucoup plus élevé que les interrogations de contrôle continu. La difficulté tient je pense au fait qu'il y avait beaucoup d'exercice complexe et très peu de temps pour les réaliser.    1
# Le gap est trop fort entre les cours théoriques et ce qu'on nous demande de résoudre à l'examen et il n'y a pas assez d'explications, corrections                                                                                        1
# Donner les corrections des contrôles avant le suivant.                                                                                                                                                                                   1
# Je pense qu'il faudrait passer nettement plus de temps sur la façon de raisonner face à un problème complexe.                                                                                                                            1
# C'est un peu dur pour les personnes qui n'ont jamais fait d'informatique il faut vraiment s'accrocher ! Mais sinon l'UE est bien faite                                                                                                   1
# Pour améliorer les travaux pratiques :  Rajouter des corrections aux TP ou des indications, par exemple.                                                                                                                                 1
# Il y a un grand écart de difficulté entre les cours et les TP et contrôles.                                                                                                                                                              1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST031 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Le partiel de fin de semestre avait un niveau beaucoup plus élevé que les interrogations de contrôle continu. La difficulté tient je pense au fait qu'il y avait beaucoup d'exercice complexe et très peu de temps pour les réaliser.',
#        'Le gap est trop fort entre les cours théoriques et ce qu'on nous demande de résoudre à l'examen et il n'y a pas assez d'explications, corrections',
#        'Donner les corrections des contrôles avant le suivant.',
#        'Je pense qu'il faudrait passer nettement plus de temps sur la façon de raisonner face à un problème complexe.',
#        'C'est un peu dur pour les personnes qui n'ont jamais fait d'informatique il faut vraiment s'accrocher ! Mais sinon l'UE est bien faite',
#        'Pour améliorer les travaux pratiques :  Rajouter des corrections aux TP ou des indications, par exemple.',
#        'Il y a un grand écart de difficulté entre les cours et les TP et contrôles.'],
#       dtype='object', name='Avez-vous des commentaires à rajouter au sujet de cette UE ?')
# []
# Avez-vous des commentaires à rajouter au sujet de cette UE ?
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/Question_9
# Data :  Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.1
# OUI    21
# Name: count, dtype: int64
# LU2ST031 4 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.1')
# ['OUI']
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/Question_10
# Data :  Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.1
# OUI    21
# Name: count, dtype: int64
# LU2ST031 4 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.1')
# ['OUI']
# Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/Question_11
# Data :  Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.1
# Tout à fait d'accord    13
# Plutôt d'accord          8
# Name: count, dtype: int64
# tabword  [False]
# LU2ST031 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.1')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/Question_12
# Data :  Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.1
# Tout à fait d'accord    10
# Plutôt d'accord          9
# Plutôt pas d'accord      2
# Name: count, dtype: int64
# tabword  [False]
# LU2ST031 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.1')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/Question_13
# Data :  Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.1
# Tout à fait d'accord    10
# Plutôt d'accord          8
# Plutôt pas d'accord      3
# Name: count, dtype: int64
# tabword  [False]
# LU2ST031 4 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.1')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST031/Question_14
# UE :  LU2ST032
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/
# path :  /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/
# False
# Data :  Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.1
# OUI    21
# Name: count, dtype: int64
# LU2ST032 14 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.1')
# ['OUI']
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/Question_0
# Data :  Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.1
# OUI    21
# Name: count, dtype: int64
# LU2ST032 14 ['OUI', 'NON'] Index(['OUI'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.1')
# ['OUI']
# Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/Question_1
# Data :  Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.1
# Tout à fait d'accord    13
# Plutôt d'accord          8
# Name: count, dtype: int64
# tabword  [False]
# LU2ST032 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.1')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/Question_2
# Data :  Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.1
# Tout à fait d'accord    10
# Plutôt d'accord          9
# Plutôt pas d'accord      2
# Name: count, dtype: int64
# tabword  [False]
# LU2ST032 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.1')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/Question_3
# Data :  Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.1
# Tout à fait d'accord    10
# Plutôt d'accord          8
# Plutôt pas d'accord      3
# Name: count, dtype: int64
# tabword  [False]
# LU2ST032 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.1')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/Question_4
# Data :  Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.1
# Tout à fait d'accord    12
# Plutôt d'accord          9
# Name: count, dtype: int64
# tabword  [False]
# LU2ST032 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.1')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/Question_5
# Data :  Contenu de l'UE >> Les documents de l'UE sont utiles.1
# Tout à fait d'accord    17
# Plutôt d'accord          4
# Name: count, dtype: int64
# tabword  [False]
# LU2ST032 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont utiles.1')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont utiles
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/Question_6
# Data :  Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.1
# Tout à fait d'accord    16
# Plutôt d'accord          5
# Name: count, dtype: int64
# tabword  [False]
# LU2ST032 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.1')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/Question_7
# Data :  Les enseignements de cette UE vous ont intéressé
# 5.0    11
# 4.0     6
# 2.0     2
# 3.0     2
# Name: count, dtype: int64
# tabword  [True]
# LU2ST032 14 [1, 2, 3, 4, 5] Index([5.0, 4.0, 2.0, 3.0], dtype='float64', name='Les enseignements de cette UE vous ont intéressé')
# [2, 3, 4, 5]
# Les enseignements de cette UE vous ont intéressé (4.24/5)
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/Question_8
# Data :  Avez-vous des commentaires à rajouter au sujet de cette UE ?.1
# J'ai beaucoup apprécié les quizz nous permettant de découvrir les notions abordées en TP.                        1
# L'UE est super intéressante mais les évaluations peuvent être trop complexe (comme les QCM à points négatifs)    1
# Il serait approprié de rajouter des annales de CC sur le Moodle de l'UE.                                         1
# Pas assez d'annales pour les différentes évaluations.                                                            1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST032 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['J'ai beaucoup apprécié les quizz nous permettant de découvrir les notions abordées en TP.',
#        'L'UE est super intéressante mais les évaluations peuvent être trop complexe (comme les QCM à points négatifs)',
#        'Il serait approprié de rajouter des annales de CC sur le Moodle de l'UE.',
#        'Pas assez d'annales pour les différentes évaluations.'],
#       dtype='object', name='Avez-vous des commentaires à rajouter au sujet de cette UE ?.1')
# []
# Avez-vous des commentaires à rajouter au sujet de cette UE ?
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/Question_9
# Data :  Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.2
# OUI    3
# NON    1
# Name: count, dtype: int64
# LU2ST032 14 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.2')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/Question_10
# Data :  Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.2
# OUI    3
# NON    1
# Name: count, dtype: int64
# LU2ST032 14 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.2')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/Question_11
# Data :  Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.2
# Tout à fait d'accord    2
# Plutôt d'accord         2
# Name: count, dtype: int64
# tabword  [False]
# LU2ST032 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.2')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/Question_12
# Data :  Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.2
# Tout à fait d'accord    3
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST032 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.2')
# ["Tout à fait d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/Question_13
# Data :  Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.2
# Tout à fait d'accord    2
# Plutôt pas d'accord     1
# Plutôt d'accord         1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST032 14 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt pas d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.2')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST032/Question_14
# UE :  LU2ST033
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/
# path :  /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/
# False
# Data :  Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.2
# OUI    3
# NON    1
# Name: count, dtype: int64
# LU2ST033 24 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.2')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/Question_0
# Data :  Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.2
# OUI    3
# NON    1
# Name: count, dtype: int64
# LU2ST033 24 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.2')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/Question_1
# Data :  Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.2
# Tout à fait d'accord    2
# Plutôt d'accord         2
# Name: count, dtype: int64
# tabword  [False]
# LU2ST033 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.2')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/Question_2
# Data :  Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.2
# Tout à fait d'accord    3
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST033 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.2')
# ["Tout à fait d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/Question_3
# Data :  Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.2
# Tout à fait d'accord    2
# Plutôt pas d'accord     1
# Plutôt d'accord         1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST033 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt pas d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.2')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/Question_4
# Data :  Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.2
# Tout à fait d'accord    2
# Plutôt d'accord         1
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST033 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.2')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/Question_5
# Data :  Contenu de l'UE >> Les documents de l'UE sont utiles.2
# Plutôt d'accord         3
# Tout à fait d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST033 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord'], dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont utiles.2')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont utiles
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/Question_6
# Data :  Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.2
# Plutôt pas d'accord     3
# Tout à fait d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST033 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt pas d'accord', 'Tout à fait d'accord'], dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.2')
# ["Tout à fait d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/Question_7
# Data :  Les enseignements de cette UE vous ont intéressé.1
# 4.0    2
# 5.0    1
# 3.0    1
# Name: count, dtype: int64
# tabword  [True]
# LU2ST033 24 [1, 2, 3, 4, 5] Index([4.0, 5.0, 3.0], dtype='float64', name='Les enseignements de cette UE vous ont intéressé.1')
# [3, 4, 5]
# Les enseignements de cette UE vous ont intéressé (4.00/5)
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/Question_8
# Data :  Avez-vous des commentaires à rajouter au sujet de cette UE ?.2
# Cette UE a un potentiel excellent mais pas assez exploitée, les cours de lettre sont très intéressant mais ne tombe pas à l'évaluation ce qui perd un peu de l'intêret de l'UE qui est sensée regrouper science et lettre. Les TD sont par contre super et la visite de l'église est une chouette sortie.    1
# Il serait approprié de rajouter des annales de CC sur le Moodle de l'UE.                                                                                                                                                                                                                                     1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST033 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Cette UE a un potentiel excellent mais pas assez exploitée, les cours de lettre sont très intéressant mais ne tombe pas à l'évaluation ce qui perd un peu de l'intêret de l'UE qui est sensée regrouper science et lettre. Les TD sont par contre super et la visite de l'église est une chouette sortie.', 'Il serait approprié de rajouter des annales de CC sur le Moodle de l'UE.'], dtype='object', name='Avez-vous des commentaires à rajouter au sujet de cette UE ?.2')
# []
# Avez-vous des commentaires à rajouter au sujet de cette UE ?
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/Question_9
# Data :  Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.3
# OUI    7
# NON    2
# Name: count, dtype: int64
# LU2ST033 24 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.3')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/Question_10
# Data :  Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.3
# OUI    6
# NON    3
# Name: count, dtype: int64
# LU2ST033 24 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.3')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/Question_11
# Data :  Contenu de l'UE >> Le terrain est adapté à vos connaissances et compétences préalables
# Tout à fait d'accord    4
# Plutôt d'accord         3
# Plutôt pas d'accord     2
# Name: count, dtype: int64
# tabword  [False]
# LU2ST033 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Le terrain est adapté à vos connaissances et compétences préalables')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Le terrain est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/Question_12
# Data :  Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.3
# Tout à fait d'accord    6
# Plutôt d'accord         3
# Name: count, dtype: int64
# tabword  [False]
# LU2ST033 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.3')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/Question_13
# Data :  Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.3
# Tout à fait d'accord    5
# Plutôt pas d'accord     2
# Plutôt d'accord         2
# Name: count, dtype: int64
# tabword  [False]
# LU2ST033 24 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt pas d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.3')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST033/Question_14
# UE :  LU2ST034
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/
# path :  /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/
# False
# Data :  Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.3
# OUI    7
# NON    2
# Name: count, dtype: int64
# LU2ST034 34 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés.3')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE ? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/Question_0
# Data :  Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.3
# OUI    6
# NON    3
# Name: count, dtype: int64
# LU2ST034 34 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris.3')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE ? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/Question_1
# Data :  Contenu de l'UE >> Le terrain est adapté à vos connaissances et compétences préalables
# Tout à fait d'accord    4
# Plutôt d'accord         3
# Plutôt pas d'accord     2
# Name: count, dtype: int64
# tabword  [False]
# LU2ST034 34 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Le terrain est adapté à vos connaissances et compétences préalables')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Le terrain est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/Question_2
# Data :  Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.3
# Tout à fait d'accord    6
# Plutôt d'accord         3
# Name: count, dtype: int64
# tabword  [False]
# LU2ST034 34 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.3')
# ["Tout à fait d'accord", "Plutôt d'accord"]
# Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/Question_3
# Data :  Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.3
# Tout à fait d'accord    5
# Plutôt pas d'accord     2
# Plutôt d'accord         2
# Name: count, dtype: int64
# tabword  [False]
# LU2ST034 34 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt pas d'accord', 'Plutôt d'accord'], dtype='object', name='Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.3')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/Question_4
# Data :  Contenu de l'UE >> Le lien entre l'UE Escalade et les autres enseignements est clair
# Tout à fait d'accord    4
# Plutôt d'accord         4
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST034 34 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Le lien entre l'UE Escalade et les autres enseignements est clair')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Le lien entre l'UE Escalade et les autres enseignements est clair
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/Question_5
# Data :  Contenu de l'UE >> Les documents de l'UE sont utiles.3
# Tout à fait d'accord    4
# Plutôt d'accord         3
# Plutôt pas d'accord     1
# Pas du tout d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST034 34 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord',
#        'Pas du tout d'accord'],
#       dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont utiles.3')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont utiles
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/Question_6
# Data :  Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.3
# Tout à fait d'accord    4
# Plutôt d'accord         2
# Plutôt pas d'accord     2
# Pas du tout d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST034 34 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord',
#        'Pas du tout d'accord'],
#       dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.3')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/Question_7
# Data :  Les enseignements de cette UE vous ont intéressé.2
# 5.0    4
# 4.0    4
# 3.0    1
# Name: count, dtype: int64
# tabword  [True]
# LU2ST034 34 [1, 2, 3, 4, 5] Index([5.0, 4.0, 3.0], dtype='float64', name='Les enseignements de cette UE vous ont intéressé.2')
# [3, 4, 5]
# Les enseignements de cette UE vous ont intéressé (4.33/5)
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/Question_8
# Data :  Avez-vous des commentaires à rajouter au sujet de cette UE?
# UE très enrichissante et intéressante !                                                                                   1
# J'ai adoré cette UE notamment de par sa pédagogie : faire de l'escalade sur des blocs tout en apprenant leur histoire.    1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST034 34 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['UE très enrichissante et intéressante !', 'J'ai adoré cette UE notamment de par sa pédagogie : faire de l'escalade sur des blocs tout en apprenant leur histoire.'], dtype='object', name='Avez-vous des commentaires à rajouter au sujet de cette UE?')
# []
# Avez-vous des commentaires à rajouter au sujet de cette UE?
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/Question_9
# Data :  Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés
# OUI    14
# NON     2
# Name: count, dtype: int64
# LU2ST034 34 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/Question_10
# Data :  Que diriez-vous des objectifs de l'UE? >> Vous les avez compris
# OUI    15
# NON     1
# Name: count, dtype: int64
# LU2ST034 34 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE? >> Vous les avez compris')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/Question_11
# Data :  Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.3
# Plutôt d'accord         8
# Tout à fait d'accord    5
# Plutôt pas d'accord     3
# Name: count, dtype: int64
# tabword  [False]
# LU2ST034 34 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.3')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/Question_12
# Data :  Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.4
# Tout à fait d'accord    8
# Plutôt d'accord         6
# Plutôt pas d'accord     2
# Name: count, dtype: int64
# tabword  [False]
# LU2ST034 34 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.4')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/Question_13
# Data :  Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.4
# Tout à fait d'accord    9
# Plutôt d'accord         6
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST034 34 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.4')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST034/Question_14
# UE :  LU2ST035
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST035/
# path :  /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST035/
# False
# Data :  Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés
# OUI    14
# NON     2
# Name: count, dtype: int64
# LU2ST035 44 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE? >> Ils vous ont été présentés
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST035/Question_0
# Data :  Que diriez-vous des objectifs de l'UE? >> Vous les avez compris
# OUI    15
# NON     1
# Name: count, dtype: int64
# LU2ST035 44 ['OUI', 'NON'] Index(['OUI', 'NON'], dtype='object', name='Que diriez-vous des objectifs de l'UE? >> Vous les avez compris')
# ['OUI', 'NON']
# Que diriez-vous des objectifs de l'UE? >> Vous les avez compris
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST035/Question_1
# Data :  Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.3
# Plutôt d'accord         8
# Tout à fait d'accord    5
# Plutôt pas d'accord     3
# Name: count, dtype: int64
# tabword  [False]
# LU2ST035 44 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Plutôt d'accord', 'Tout à fait d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables.3')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Le cours est adapté à vos connaissances et compétences préalables
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST035/Question_2
# Data :  Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.4
# Tout à fait d'accord    8
# Plutôt d'accord         6
# Plutôt pas d'accord     2
# Name: count, dtype: int64
# tabword  [False]
# LU2ST035 44 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS.4')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> La charge de travail est adéquate pour le nombre d'ECTS
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST035/Question_3
# Data :  Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.4
# Tout à fait d'accord    9
# Plutôt d'accord         6
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST035 44 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE.4')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST035/Question_4
# Data :  Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.3
# Tout à fait d'accord    8
# Plutôt d'accord         6
# Plutôt pas d'accord     2
# Name: count, dtype: int64
# tabword  [False]
# LU2ST035 44 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent.3')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> L'enseignement (cours, TP, TD) forme un tout cohérent
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST035/Question_5
# Data :  Contenu de l'UE >> Les documents de l'UE sont utiles.4
# Tout à fait d'accord    8
# Plutôt d'accord         5
# Plutôt pas d'accord     2
# Pas du tout d'accord    1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST035 44 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord',
#        'Pas du tout d'accord'],
#       dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont utiles.4')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont utiles
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST035/Question_6
# Data :  Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.4
# Tout à fait d'accord    8
# Plutôt d'accord         7
# Plutôt pas d'accord     1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST035 44 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Tout à fait d'accord', 'Plutôt d'accord', 'Plutôt pas d'accord'], dtype='object', name='Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante.4')
# ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord"]
# Contenu de l'UE >> Les documents de l'UE sont en quantité suffisante
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST035/Question_7
# ...
# Je possédais déjà les connaissances nécessaires donc le cours ne m'a pas particulièrement intéressé                                                                                                                                                                                                                                                                                                                                                                           1
# Tous les étudiants devraient avoir accès aux annales.                                                                                                                                                                                                                                                                                                                                                                                                                         1
# Name: count, dtype: int64
# tabword  [False]
# LU2ST304 85 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Le programme porte sur des notions déjà vues l'an dernier tout en condensant ce qui à été fait sur une année entière en seulement un semestre, je ne voit pas bien l'intérêt.',
#        'Pareil que pour la cartographie, des CM d'une heure c'est trop court. Comme l'UE ne compte pas pour beaucoup d'ECTS, des CM de 1h30 me semblerait beaucoup plus adaptés, ou alors il faut moins de chapitres. On a à peine le temps de se pencher sur chaque notions et les TD s'enchainent à la vitesse de l'éclair, ce qui les rends très peu interactifs et les fait plus ressembler à une extension de CM, où on doit noter plus que réfléchir. Le comble pour un TD !',
#        'Le fait de reprendre vraiment les bases des notions abordées m'a beaucoup aidée. Merci beaucoup pour cela !',
#        'L'UE est super, les connaissances abordée sont hyper intéressantes ! Par contre les TD sont bien plus durs que les évaluations.',
#        'Je possédais déjà les connaissances nécessaires donc le cours ne m'a pas particulièrement intéressé',
#        'Tous les étudiants devraient avoir accès aux annales.'],
#       dtype='object', name='Avez-vous des commentaires à rajouter au sujet de cette UE?.5')
# []
# Avez-vous des commentaires à rajouter au sujet de cette UE?
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST304/Question_9
# Data :  Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Hydraulique et SIG >> Présentés ?
# Présentés ?    3
# Name: count, dtype: int64
# tabword  [False]
# LU2ST304 85 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Présentés ?'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Hydraulique et SIG >> Présentés ?')
# []
# Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Hydraulique et SIG >> Présentés ?
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST304/Question_10
# Data :  Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Hydraulique et SIG >> Compris ?
# Compris ?    2
# Name: count, dtype: int64
# tabword  [False]
# LU2ST304 85 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Compris ?'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Hydraulique et SIG >> Compris ?')
# []
# Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Hydraulique et SIG >> Compris ?
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST304/Question_11
# Data :  Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Microbiologie de l'eau >> Présentés ?
# Présentés ?    3
# Name: count, dtype: int64
# tabword  [False]
# LU2ST304 85 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Présentés ?'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Microbiologie de l'eau >> Présentés ?')
# []
# Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Microbiologie de l'eau >> Présentés ?
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST304/Question_12
# Data :  Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Microbiologie de l'eau >> Compris ?
# Compris ?    2
# Name: count, dtype: int64
# tabword  [False]
# LU2ST304 85 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Compris ?'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Microbiologie de l'eau >> Compris ?')
# []
# Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Microbiologie de l'eau >> Compris ?
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST304/Question_13
# Data :  Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> TRE (Tech. Rech. Entr.) >> Présentés ?
# Présentés ?    3
# Name: count, dtype: int64
# tabword  [False]
# LU2ST304 85 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Présentés ?'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> TRE (Tech. Rech. Entr.) >> Présentés ?')
# []
# Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> TRE (Tech
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/LU2ST304/Question_14
# UE :  RQEE
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/
# path :  /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/
# False
# Data :  Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Hydraulique et SIG >> Présentés ?
# Présentés ?    3
# Name: count, dtype: int64
# tabword  [False]
# RQEE 95 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Présentés ?'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Hydraulique et SIG >> Présentés ?')
# []
# Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Hydraulique et SIG >> Présentés ?
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/Question_0
# Data :  Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Hydraulique et SIG >> Compris ?
# Compris ?    2
# Name: count, dtype: int64
# tabword  [False]
# RQEE 95 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Compris ?'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Hydraulique et SIG >> Compris ?')
# []
# Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Hydraulique et SIG >> Compris ?
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/Question_1
# Data :  Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Microbiologie de l'eau >> Présentés ?
# Présentés ?    3
# Name: count, dtype: int64
# tabword  [False]
# RQEE 95 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Présentés ?'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Microbiologie de l'eau >> Présentés ?')
# []
# Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Microbiologie de l'eau >> Présentés ?
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/Question_2
# Data :  Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Microbiologie de l'eau >> Compris ?
# Compris ?    2
# Name: count, dtype: int64
# tabword  [False]
# RQEE 95 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Compris ?'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Microbiologie de l'eau >> Compris ?')
# []
# Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> Microbiologie de l'eau >> Compris ?
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/Question_3
# Data :  Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> TRE (Tech. Rech. Entr.) >> Présentés ?
# Présentés ?    3
# Name: count, dtype: int64
# tabword  [False]
# RQEE 95 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Présentés ?'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> TRE (Tech. Rech. Entr.) >> Présentés ?')
# []
# Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> TRE (Tech
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/Question_4
# Data :  Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> TRE (Tech. Rech. Entr.) >> Compris ?
# Compris ?    2
# Name: count, dtype: int64
# tabword  [False]
# RQEE 95 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Compris ?'], dtype='object', name='Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> TRE (Tech. Rech. Entr.) >> Compris ?')
# []
# Que diriez-vous des objectifs de l'UE ? (cocher si Oui) >> TRE (Tech
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/Question_5
# Data :  Contenus des UE (Cocher si vous êtes d'accord) >> Le cours est adapté à vos connaissances et compétences préalables >> Hydraulique et SIG
# Hydraulique et SIG    3
# Name: count, dtype: int64
# tabword  [False]
# RQEE 95 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Hydraulique et SIG'], dtype='object', name='Contenus des UE (Cocher si vous êtes d'accord) >> Le cours est adapté à vos connaissances et compétences préalables >> Hydraulique et SIG')
# []
# Contenus des UE (Cocher si vous êtes d'accord) >> Le cours est adapté à vos connaissances et compétences préalables >> Hydraulique et SIG
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/Question_6
# Data :  Series([], Name: count, dtype: int64)
# tabword  [False]
# RQEE 95 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index([], dtype='float64', name='Contenus des UE (Cocher si vous êtes d'accord) >> Le cours est adapté à vos connaissances et compétences préalables >> Microbiologie de l'eau')
# []
# Contenus des UE (Cocher si vous êtes d'accord) >> Le cours est adapté à vos connaissances et compétences préalables >> Microbiologie de l'eau
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/Question_7
# Data :  Contenus des UE (Cocher si vous êtes d'accord) >> Le cours est adapté à vos connaissances et compétences préalables >> TRE (Tech. Rech. Entr.)
# TRE (Tech. Rech. Entr.)    3
# Name: count, dtype: int64
# tabword  [False]
# RQEE 95 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['TRE (Tech. Rech. Entr.)'], dtype='object', name='Contenus des UE (Cocher si vous êtes d'accord) >> Le cours est adapté à vos connaissances et compétences préalables >> TRE (Tech. Rech. Entr.)')
# []
# Contenus des UE (Cocher si vous êtes d'accord) >> Le cours est adapté à vos connaissances et compétences préalables >> TRE (Tech
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/Question_8
# Data :  Contenus des UE (Cocher si vous êtes d'accord) >> La charge de travail est adéquate pour le nombre d'ECTS >> Hydraulique et SIG
# Hydraulique et SIG    2
# Name: count, dtype: int64
# tabword  [False]
# RQEE 95 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Hydraulique et SIG'], dtype='object', name='Contenus des UE (Cocher si vous êtes d'accord) >> La charge de travail est adéquate pour le nombre d'ECTS >> Hydraulique et SIG')
# []
# Contenus des UE (Cocher si vous êtes d'accord) >> La charge de travail est adéquate pour le nombre d'ECTS >> Hydraulique et SIG
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/Question_9
# Data :  Series([], Name: count, dtype: int64)
# tabword  [False]
# RQEE 95 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index([], dtype='float64', name='Contenus des UE (Cocher si vous êtes d'accord) >> La charge de travail est adéquate pour le nombre d'ECTS >> Microbiologie de l'eau')
# []
# Contenus des UE (Cocher si vous êtes d'accord) >> La charge de travail est adéquate pour le nombre d'ECTS >> Microbiologie de l'eau
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/Question_10
# Data :  Contenus des UE (Cocher si vous êtes d'accord) >> La charge de travail est adéquate pour le nombre d'ECTS >> TRE (Tech. Rech. Entr.)
# TRE (Tech. Rech. Entr.)    3
# Name: count, dtype: int64
# tabword  [False]
# RQEE 95 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['TRE (Tech. Rech. Entr.)'], dtype='object', name='Contenus des UE (Cocher si vous êtes d'accord) >> La charge de travail est adéquate pour le nombre d'ECTS >> TRE (Tech. Rech. Entr.)')
# []
# Contenus des UE (Cocher si vous êtes d'accord) >> La charge de travail est adéquate pour le nombre d'ECTS >> TRE (Tech
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/Question_11
# Data :  Contenus des UE (Cocher si vous êtes d'accord) >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE >> Hydraulique et SIG
# Hydraulique et SIG    2
# Name: count, dtype: int64
# tabword  [False]
# RQEE 95 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['Hydraulique et SIG'], dtype='object', name='Contenus des UE (Cocher si vous êtes d'accord) >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE >> Hydraulique et SIG')
# []
# Contenus des UE (Cocher si vous êtes d'accord) >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE >> Hydraulique et SIG
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/Question_12
# Data :  Series([], Name: count, dtype: int64)
# tabword  [False]
# RQEE 95 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index([], dtype='float64', name='Contenus des UE (Cocher si vous êtes d'accord) >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE >> Microbiologie de l'eau')
# []
# Contenus des UE (Cocher si vous êtes d'accord) >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE >> Microbiologie de l'eau
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/Question_13
# Data :  Contenus des UE (Cocher si vous êtes d'accord) >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE >> TRE (Tech. Rech. Entr.)
# TRE (Tech. Rech. Entr.)    3
# Name: count, dtype: int64
# tabword  [False]
# RQEE 95 ["Tout à fait d'accord", "Plutôt d'accord", "Plutôt pas d'accord", "Pas du tout d'accord"] Index(['TRE (Tech. Rech. Entr.)'], dtype='object', name='Contenus des UE (Cocher si vous êtes d'accord) >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE >> TRE (Tech. Rech. Entr.)')
# []
# Contenus des UE (Cocher si vous êtes d'accord) >> Les modalités d’évaluation sont adaptées aux objectifs de l’UE >> TRE (Tech
# /Users/fbrient/Dropbox/Enseignements/2024_2025/Resp_Eval/Resultats/S3/d_figures/RQEE/Question_14
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 77
#      74 figsize = (8, 5)
#      76 for ij,idx in enumerate(UE_idx):
# ---> 77     UE = UE_names[ij]
#      78     print('UE : ',UE)
#      80     path_file = pathfig+UE+'/'
#
# IndexError: list index out of range
